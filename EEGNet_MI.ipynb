# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import ShuffleSplit, cross_val_score
from sklearn.pipeline import Pipeline

from EEGModels import EEGNet
from mne import Epochs, pick_types
from mne.channels import make_standard_montage
from mne.datasets import eegbci
from mne.decoding import CSP
from mne.io import concatenate_raws, read_raw_edf

print(__doc__)
# Out:
#  ARL_EEGModels - A collection of Convolutional Neural Network models for EEG
#  Signal Processing and Classification, using Keras and Tensorflow
#
#  Requirements:
#     (1) tensorflow == 2.X (as of this writing, 2.0 - 2.3 have been verified
#         as working)
#
#  To run the EEG/MEG ERP classification sample script, you will also need
#
#     (4) mne >= 0.17.1
#     (5) PyRiemann >= 0.2.5
#     (6) scikit-learn >= 0.20.1
#     (7) matplotlib >= 2.2.3
#
#  To use:
#
#     (1) Place this file in the PYTHONPATH variable in your IDE (i.e.: Spyder)
#     (2) Import the model as
#
#         from EEGModels import EEGNet
#
#         model = EEGNet(nb_classes = ..., Chans = ..., Samples = ...)
#
#     (3) Then compile and fit the model
#
#         model.compile(loss = ..., optimizer = ..., metrics = ...)
#         fitted    = model.fit(...)
#         predicted = model.predict(...)
#
#  Portions of this project are works of the United States Government and are not
#  subject to domestic copyright protection under 17 USC Sec. 105.  Those
#  portions are released world-wide under the terms of the Creative Commons Zero
#  1.0 (CC0) license.
#
#  Other portions of this project are subject to domestic copyright protection
#  under 17 USC Sec. 105.  Those portions are licensed under the Apache 2.0
#  license.  The complete text of the license governing this material is in
#  the file labeled LICENSE.TXT that is a part of this project's official
#  distribution.

# %%
import h5py

# %%
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K

# %%
# #############################################################################
# # Set parameters and read data

# avoid classification of evoked responses by using epochs that start 1s after
# cue onset.
tmin, tmax = -1.0, 4.0
subjects = range(1,10)
runs = [6, 10, 14]  # motor imagery: hands vs feet

raw_fnames = eegbci.load_data(subjects, runs)
raw = concatenate_raws([read_raw_edf(f, preload=True) for f in raw_fnames])
eegbci.standardize(raw)  # set channel names
montage = make_standard_montage("standard_1005")
raw.set_montage(montage)
raw.annotations.rename(dict(T1="hands", T2="feet"))  # as documented on PhysioNet
raw.set_eeg_reference(projection=True)

# Apply band-pass filter
raw.filter(7.0, 30.0, fir_design="firwin", skip_by_annotation="edge")

picks = pick_types(raw.info, meg=False, eeg=True, stim=False, eog=False, exclude="bads")

# Read epochs (train will be done only between 1 and 2s)
# Testing will be done with a running classifier
epochs = Epochs(
    raw,
    event_id=["hands", "feet"],
    tmin=tmin,
    tmax=tmax,
    proj=True,
    picks=picks,
    baseline=None,
    preload=True,
)
epochs_train = epochs.copy().crop(tmin=1.0, tmax=2.0)
labels = epochs.events[:, -1] - 2
# Out:
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S001/S001R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S001/S001R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S001/S001R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S002/S002R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S002/S002R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S002/S002R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S003/S003R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S003/S003R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S003/S003R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S004/S004R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S004/S004R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S004/S004R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S005/S005R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S005/S005R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S005/S005R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S006/S006R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S006/S006R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S006/S006R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S007/S007R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S007/S007R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S007/S007R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S008/S008R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S008/S008R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S008/S008R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S009/S009R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S009/S009R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S009/S009R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 7 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 7.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 6.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 265 samples (1.656 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Used Annotations descriptions: ['T0', 'feet', 'hands']
# Ignoring annotation durations and creating fixed-duration epochs around annotation onsets.
# Not setting metadata
# 405 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 405 events and 801 original time points ...
# 0 bad epochs dropped

# %%
# extract raw data. scale by 1000 due to scaling sensitivity in deep learning
X = epochs.get_data()*1000 # format is in (trials, channels, samples)
y = labels

kernels, chans, samples = 1, 64, 801

# %%
print(X.shape, y.shape)
# Out:
# (405, 64, 801) (405,)

# %%
X_train      = X[0:224,]
Y_train      = y[0:224]
X_validate   = X[224:320,]
Y_validate   = y[224:320]
X_test       = X[320:416]
Y_test       = y[320:416]

# %%
X_train      = X_train.reshape(X_train.shape[0], chans, samples, kernels)
X_validate   = X_validate.reshape(X_validate.shape[0], chans, samples, kernels)
X_test       = X_test.reshape(X_test.shape[0], chans, samples, kernels)
   
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# X_train shape: (224, 64, 801, 1)
# 224 train samples
# 85 test samples

# %%
# configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
# model configurations may do better, but this is a good starting point)
model = EEGNet(nb_classes = 2, Chans = chans, Samples = samples, 
               dropoutRate = 0.5, kernLength = 32, F1 = 8, D = 2, F2 = 16, 
               dropoutType = 'Dropout')

# compile the model and set the optimizers
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', 
              metrics = ['accuracy'])

# count number of parameters in the model
numParams    = model.count_params()    

# set a valid path for your system to record model checkpoints
with h5py.File('./tmp/mi_checkpoint.h5', 'w') as f:
    # This creates 2 attributes of arrays of different np.float types:
    arr_in = np.array([1.0,2.0,3.0])
    f.attrs['as_float64'] = arr_in
    # arr_in.dtype = np.float128
    # f.attrs['as_float128'] = arr_in
checkpointer = ModelCheckpoint(filepath='./tmp/mi_checkpoint.h5', verbose=1,
                               save_best_only=True)

###############################################################################
# if the classification task was imbalanced (significantly more trials in one
# class versus the others) you can assign a weight to each class during 
# optimization to balance it out. This data is approximately balanced so we 
# don't need to do this, but is shown here for illustration/completeness. 
###############################################################################

# the syntax is {class_1:weight_1, class_2:weight_2,...}. Here just setting
# the weights all to be 1
class_weights = {0:1, 1:1}

################################################################################
# fit the model. Due to very small sample sizes this can get
# pretty noisy run-to-run, but most runs should be comparable to xDAWN + 
# Riemannian geometry classification (below)
################################################################################
fittedModel = model.fit(X_train, Y_train, batch_size = 16, epochs = 100, 
                        verbose = 2, validation_data=(X_validate, Y_validate),
                        # callbacks=[checkpointer], 
                        class_weight = class_weights)
# Out:
# Epoch 1/100
# 14/14 - 1s - loss: 0.7198 - accuracy: 0.4375 - val_loss: 0.6930 - val_accuracy: 0.5104 - 1s/epoch - 77ms/step
# Epoch 2/100
# 14/14 - 1s - loss: 0.6918 - accuracy: 0.5179 - val_loss: 0.6930 - val_accuracy: 0.5104 - 898ms/epoch - 64ms/step
# Epoch 3/100
# 14/14 - 1s - loss: 0.6894 - accuracy: 0.5536 - val_loss: 0.6930 - val_accuracy: 0.5104 - 887ms/epoch - 63ms/step
# Epoch 4/100
# 14/14 - 1s - loss: 0.6855 - accuracy: 0.5357 - val_loss: 0.6930 - val_accuracy: 0.5104 - 924ms/epoch - 66ms/step
# Epoch 5/100
# 14/14 - 1s - loss: 0.6843 - accuracy: 0.5402 - val_loss: 0.6931 - val_accuracy: 0.5104 - 917ms/epoch - 65ms/step
# Epoch 6/100
# 14/14 - 1s - loss: 0.6715 - accuracy: 0.6429 - val_loss: 0.6931 - val_accuracy: 0.5104 - 911ms/epoch - 65ms/step
# Epoch 7/100
# 14/14 - 1s - loss: 0.6669 - accuracy: 0.6652 - val_loss: 0.6930 - val_accuracy: 0.5104 - 903ms/epoch - 64ms/step
# Epoch 8/100
# 14/14 - 1s - loss: 0.6632 - accuracy: 0.6295 - val_loss: 0.6930 - val_accuracy: 0.5104 - 907ms/epoch - 65ms/step
# Epoch 9/100
# 14/14 - 1s - loss: 0.6655 - accuracy: 0.6295 - val_loss: 0.6929 - val_accuracy: 0.5104 - 910ms/epoch - 65ms/step
# Epoch 10/100
# 14/14 - 1s - loss: 0.6557 - accuracy: 0.6429 - val_loss: 0.6929 - val_accuracy: 0.5104 - 914ms/epoch - 65ms/step
# Epoch 11/100
# 14/14 - 1s - loss: 0.6461 - accuracy: 0.6473 - val_loss: 0.6929 - val_accuracy: 0.5104 - 910ms/epoch - 65ms/step
# Epoch 12/100
# 14/14 - 1s - loss: 0.6670 - accuracy: 0.5982 - val_loss: 0.6929 - val_accuracy: 0.5104 - 902ms/epoch - 64ms/step
# Epoch 13/100
# 14/14 - 1s - loss: 0.6379 - accuracy: 0.6875 - val_loss: 0.6938 - val_accuracy: 0.5104 - 929ms/epoch - 66ms/step
# Epoch 14/100
# 14/14 - 1s - loss: 0.6299 - accuracy: 0.6696 - val_loss: 0.6940 - val_accuracy: 0.5104 - 914ms/epoch - 65ms/step
# Epoch 15/100
# 14/14 - 1s - loss: 0.6376 - accuracy: 0.6161 - val_loss: 0.6948 - val_accuracy: 0.5104 - 925ms/epoch - 66ms/step
# Epoch 16/100
# 14/14 - 1s - loss: 0.6123 - accuracy: 0.6875 - val_loss: 0.6956 - val_accuracy: 0.5104 - 908ms/epoch - 65ms/step
# Epoch 17/100
# 14/14 - 1s - loss: 0.6197 - accuracy: 0.6607 - val_loss: 0.6966 - val_accuracy: 0.5104 - 917ms/epoch - 65ms/step
# Epoch 18/100
# 14/14 - 1s - loss: 0.6252 - accuracy: 0.6696 - val_loss: 0.6966 - val_accuracy: 0.5104 - 915ms/epoch - 65ms/step
# Epoch 19/100
# 14/14 - 1s - loss: 0.6164 - accuracy: 0.7098 - val_loss: 0.6956 - val_accuracy: 0.5104 - 923ms/epoch - 66ms/step
# Epoch 20/100
# 14/14 - 1s - loss: 0.6099 - accuracy: 0.6786 - val_loss: 0.6966 - val_accuracy: 0.5104 - 917ms/epoch - 66ms/step
# Epoch 21/100
# 14/14 - 1s - loss: 0.6001 - accuracy: 0.6920 - val_loss: 0.6953 - val_accuracy: 0.5104 - 919ms/epoch - 66ms/step
# Epoch 22/100
# 14/14 - 1s - loss: 0.5928 - accuracy: 0.6964 - val_loss: 0.6929 - val_accuracy: 0.5104 - 923ms/epoch - 66ms/step
# Epoch 23/100
# 14/14 - 1s - loss: 0.5612 - accuracy: 0.7455 - val_loss: 0.6912 - val_accuracy: 0.5104 - 915ms/epoch - 65ms/step
# Epoch 24/100
# 14/14 - 1s - loss: 0.5760 - accuracy: 0.7188 - val_loss: 0.6870 - val_accuracy: 0.5104 - 915ms/epoch - 65ms/step
# Epoch 25/100
# 14/14 - 1s - loss: 0.5708 - accuracy: 0.6875 - val_loss: 0.6881 - val_accuracy: 0.4896 - 917ms/epoch - 65ms/step
# Epoch 26/100
# 14/14 - 1s - loss: 0.5527 - accuracy: 0.7009 - val_loss: 0.6885 - val_accuracy: 0.4896 - 919ms/epoch - 66ms/step
# Epoch 27/100
# 14/14 - 1s - loss: 0.5735 - accuracy: 0.6964 - val_loss: 0.6916 - val_accuracy: 0.4896 - 916ms/epoch - 65ms/step
# Epoch 28/100
# 14/14 - 1s - loss: 0.5233 - accuracy: 0.7411 - val_loss: 0.6769 - val_accuracy: 0.6771 - 917ms/epoch - 66ms/step
# Epoch 29/100
# 14/14 - 1s - loss: 0.5208 - accuracy: 0.7455 - val_loss: 0.6712 - val_accuracy: 0.5833 - 913ms/epoch - 65ms/step
# Epoch 30/100
# 14/14 - 1s - loss: 0.5294 - accuracy: 0.7589 - val_loss: 0.6808 - val_accuracy: 0.4896 - 938ms/epoch - 67ms/step
# Epoch 31/100
# 14/14 - 1s - loss: 0.5453 - accuracy: 0.7188 - val_loss: 0.6873 - val_accuracy: 0.4896 - 942ms/epoch - 67ms/step
# Epoch 32/100
# 14/14 - 1s - loss: 0.5296 - accuracy: 0.7455 - val_loss: 0.6894 - val_accuracy: 0.4896 - 990ms/epoch - 71ms/step
# Epoch 33/100
# 14/14 - 1s - loss: 0.5205 - accuracy: 0.7188 - val_loss: 0.7076 - val_accuracy: 0.4896 - 928ms/epoch - 66ms/step
# Epoch 34/100
# 14/14 - 1s - loss: 0.5113 - accuracy: 0.7366 - val_loss: 0.7076 - val_accuracy: 0.4896 - 923ms/epoch - 66ms/step
# Epoch 35/100
# 14/14 - 1s - loss: 0.4989 - accuracy: 0.7500 - val_loss: 0.7099 - val_accuracy: 0.4896 - 900ms/epoch - 64ms/step
# Epoch 36/100
# 14/14 - 1s - loss: 0.4924 - accuracy: 0.7679 - val_loss: 0.6886 - val_accuracy: 0.4896 - 923ms/epoch - 66ms/step
# Epoch 37/100
# 14/14 - 1s - loss: 0.4959 - accuracy: 0.7679 - val_loss: 0.7222 - val_accuracy: 0.4896 - 919ms/epoch - 66ms/step
# Epoch 38/100
# 14/14 - 1s - loss: 0.4921 - accuracy: 0.7768 - val_loss: 0.7450 - val_accuracy: 0.4896 - 923ms/epoch - 66ms/step
# Epoch 39/100
# 14/14 - 1s - loss: 0.4971 - accuracy: 0.7500 - val_loss: 0.7494 - val_accuracy: 0.4896 - 917ms/epoch - 65ms/step
# Epoch 40/100
# 14/14 - 1s - loss: 0.4786 - accuracy: 0.7812 - val_loss: 0.7744 - val_accuracy: 0.4896 - 923ms/epoch - 66ms/step
# Epoch 41/100
# 14/14 - 1s - loss: 0.4812 - accuracy: 0.7634 - val_loss: 0.7379 - val_accuracy: 0.4896 - 929ms/epoch - 66ms/step
# Epoch 42/100
# 14/14 - 1s - loss: 0.4868 - accuracy: 0.7634 - val_loss: 0.6957 - val_accuracy: 0.4896 - 923ms/epoch - 66ms/step
# Epoch 43/100
# 14/14 - 1s - loss: 0.4873 - accuracy: 0.7768 - val_loss: 0.6802 - val_accuracy: 0.5000 - 914ms/epoch - 65ms/step
# Epoch 44/100
# 14/14 - 1s - loss: 0.4982 - accuracy: 0.7679 - val_loss: 0.6346 - val_accuracy: 0.5625 - 923ms/epoch - 66ms/step
# Epoch 45/100
# 14/14 - 1s - loss: 0.4445 - accuracy: 0.7946 - val_loss: 0.6230 - val_accuracy: 0.5729 - 941ms/epoch - 67ms/step
# Epoch 46/100
# 14/14 - 1s - loss: 0.4408 - accuracy: 0.8170 - val_loss: 0.6344 - val_accuracy: 0.5938 - 950ms/epoch - 68ms/step
# Epoch 47/100
# 14/14 - 1s - loss: 0.4527 - accuracy: 0.7902 - val_loss: 0.6270 - val_accuracy: 0.6458 - 927ms/epoch - 66ms/step
# Epoch 48/100
# 14/14 - 1s - loss: 0.4774 - accuracy: 0.7634 - val_loss: 0.6180 - val_accuracy: 0.6458 - 942ms/epoch - 67ms/step
# Epoch 49/100
# 14/14 - 1s - loss: 0.4490 - accuracy: 0.7812 - val_loss: 0.7120 - val_accuracy: 0.5729 - 931ms/epoch - 67ms/step
# Epoch 50/100
# 14/14 - 1s - loss: 0.4070 - accuracy: 0.8438 - val_loss: 0.6399 - val_accuracy: 0.5521 - 919ms/epoch - 66ms/step
# Epoch 51/100
# 14/14 - 1s - loss: 0.4235 - accuracy: 0.8036 - val_loss: 0.5925 - val_accuracy: 0.6458 - 913ms/epoch - 65ms/step
# Epoch 52/100
# 14/14 - 1s - loss: 0.4467 - accuracy: 0.7946 - val_loss: 0.6348 - val_accuracy: 0.6146 - 917ms/epoch - 66ms/step
# Epoch 53/100
# 14/14 - 1s - loss: 0.4310 - accuracy: 0.8036 - val_loss: 0.5910 - val_accuracy: 0.6562 - 945ms/epoch - 67ms/step
# Epoch 54/100
# 14/14 - 1s - loss: 0.4132 - accuracy: 0.8259 - val_loss: 0.6682 - val_accuracy: 0.5833 - 947ms/epoch - 68ms/step
# Epoch 55/100
# 14/14 - 1s - loss: 0.4438 - accuracy: 0.8036 - val_loss: 0.6112 - val_accuracy: 0.6667 - 912ms/epoch - 65ms/step
# Epoch 56/100
# 14/14 - 1s - loss: 0.3982 - accuracy: 0.8259 - val_loss: 0.6026 - val_accuracy: 0.6562 - 915ms/epoch - 65ms/step
# Epoch 57/100
# 14/14 - 1s - loss: 0.4206 - accuracy: 0.8036 - val_loss: 0.6603 - val_accuracy: 0.6250 - 910ms/epoch - 65ms/step
# Epoch 58/100
# 14/14 - 1s - loss: 0.3968 - accuracy: 0.8080 - val_loss: 0.6138 - val_accuracy: 0.6562 - 921ms/epoch - 66ms/step
# Epoch 59/100
# 14/14 - 1s - loss: 0.3795 - accuracy: 0.8259 - val_loss: 0.5947 - val_accuracy: 0.6875 - 914ms/epoch - 65ms/step
# Epoch 60/100
# 14/14 - 1s - loss: 0.3768 - accuracy: 0.8571 - val_loss: 0.8005 - val_accuracy: 0.5417 - 937ms/epoch - 67ms/step
# Epoch 61/100
# 14/14 - 1s - loss: 0.4158 - accuracy: 0.7812 - val_loss: 0.6240 - val_accuracy: 0.6562 - 927ms/epoch - 66ms/step
# Epoch 62/100
# 14/14 - 1s - loss: 0.3443 - accuracy: 0.8795 - val_loss: 0.7723 - val_accuracy: 0.6146 - 923ms/epoch - 66ms/step
# Epoch 63/100
# 14/14 - 1s - loss: 0.3546 - accuracy: 0.8393 - val_loss: 0.6120 - val_accuracy: 0.7083 - 909ms/epoch - 65ms/step
# Epoch 64/100
# 14/14 - 1s - loss: 0.3829 - accuracy: 0.8571 - val_loss: 0.5770 - val_accuracy: 0.6771 - 901ms/epoch - 64ms/step
# Epoch 65/100
# 14/14 - 1s - loss: 0.3687 - accuracy: 0.8616 - val_loss: 0.5811 - val_accuracy: 0.6667 - 964ms/epoch - 69ms/step
# Epoch 66/100
# 14/14 - 1s - loss: 0.3476 - accuracy: 0.8616 - val_loss: 0.5746 - val_accuracy: 0.6562 - 933ms/epoch - 67ms/step
# Epoch 67/100
# 14/14 - 1s - loss: 0.3865 - accuracy: 0.8259 - val_loss: 0.5677 - val_accuracy: 0.6875 - 924ms/epoch - 66ms/step
# Epoch 68/100
# 14/14 - 1s - loss: 0.3268 - accuracy: 0.8929 - val_loss: 0.5631 - val_accuracy: 0.6875 - 930ms/epoch - 66ms/step
# Epoch 69/100
# 14/14 - 1s - loss: 0.3798 - accuracy: 0.8214 - val_loss: 0.7595 - val_accuracy: 0.5521 - 926ms/epoch - 66ms/step
# Epoch 70/100
# 14/14 - 1s - loss: 0.3745 - accuracy: 0.8438 - val_loss: 0.5938 - val_accuracy: 0.6667 - 920ms/epoch - 66ms/step
# Epoch 71/100
# 14/14 - 1s - loss: 0.3297 - accuracy: 0.8839 - val_loss: 0.6247 - val_accuracy: 0.6250 - 918ms/epoch - 66ms/step
# Epoch 72/100
# 14/14 - 1s - loss: 0.3436 - accuracy: 0.8527 - val_loss: 0.7743 - val_accuracy: 0.5833 - 921ms/epoch - 66ms/step
# Epoch 73/100
# 14/14 - 1s - loss: 0.3825 - accuracy: 0.8393 - val_loss: 0.6254 - val_accuracy: 0.6042 - 910ms/epoch - 65ms/step
# Epoch 74/100
# 14/14 - 1s - loss: 0.3241 - accuracy: 0.8795 - val_loss: 0.5612 - val_accuracy: 0.6667 - 915ms/epoch - 65ms/step
# Epoch 75/100
# 14/14 - 1s - loss: 0.3392 - accuracy: 0.8527 - val_loss: 0.7874 - val_accuracy: 0.5625 - 914ms/epoch - 65ms/step
# Epoch 76/100
# 14/14 - 1s - loss: 0.3357 - accuracy: 0.8661 - val_loss: 0.7391 - val_accuracy: 0.5729 - 961ms/epoch - 69ms/step
# Epoch 77/100
# 14/14 - 1s - loss: 0.3361 - accuracy: 0.8571 - val_loss: 0.7547 - val_accuracy: 0.5417 - 919ms/epoch - 66ms/step
# Epoch 78/100
# 14/14 - 1s - loss: 0.3070 - accuracy: 0.8795 - val_loss: 0.5963 - val_accuracy: 0.6771 - 938ms/epoch - 67ms/step
# Epoch 79/100
# 14/14 - 1s - loss: 0.3215 - accuracy: 0.8750 - val_loss: 0.7530 - val_accuracy: 0.5833 - 916ms/epoch - 65ms/step
# Epoch 80/100
# 14/14 - 1s - loss: 0.3042 - accuracy: 0.8616 - val_loss: 0.7040 - val_accuracy: 0.5521 - 915ms/epoch - 65ms/step
# Epoch 81/100
# 14/14 - 1s - loss: 0.2673 - accuracy: 0.8929 - val_loss: 0.6634 - val_accuracy: 0.5938 - 924ms/epoch - 66ms/step
# Epoch 82/100
# 14/14 - 1s - loss: 0.3070 - accuracy: 0.8839 - val_loss: 0.7491 - val_accuracy: 0.5938 - 893ms/epoch - 64ms/step
# Epoch 83/100
# 14/14 - 1s - loss: 0.3262 - accuracy: 0.8438 - val_loss: 0.6035 - val_accuracy: 0.6146 - 950ms/epoch - 68ms/step
# Epoch 84/100
# 14/14 - 1s - loss: 0.2955 - accuracy: 0.8839 - val_loss: 0.6071 - val_accuracy: 0.6250 - 927ms/epoch - 66ms/step
# Epoch 85/100
# 14/14 - 1s - loss: 0.3325 - accuracy: 0.8304 - val_loss: 1.0641 - val_accuracy: 0.5312 - 909ms/epoch - 65ms/step
# Epoch 86/100
# 14/14 - 1s - loss: 0.2836 - accuracy: 0.8973 - val_loss: 0.7011 - val_accuracy: 0.6146 - 910ms/epoch - 65ms/step
# Epoch 87/100
# 14/14 - 1s - loss: 0.2583 - accuracy: 0.9286 - val_loss: 0.9708 - val_accuracy: 0.5417 - 929ms/epoch - 66ms/step
# Epoch 88/100
# 14/14 - 1s - loss: 0.2787 - accuracy: 0.8795 - val_loss: 0.6265 - val_accuracy: 0.6875 - 919ms/epoch - 66ms/step
# Epoch 89/100
# 14/14 - 1s - loss: 0.2570 - accuracy: 0.9196 - val_loss: 0.9388 - val_accuracy: 0.5312 - 901ms/epoch - 64ms/step
# Epoch 90/100
# 14/14 - 1s - loss: 0.2960 - accuracy: 0.8929 - val_loss: 0.7295 - val_accuracy: 0.5938 - 900ms/epoch - 64ms/step
# Epoch 91/100
# 14/14 - 1s - loss: 0.2710 - accuracy: 0.8839 - val_loss: 1.0422 - val_accuracy: 0.5104 - 921ms/epoch - 66ms/step
# Epoch 92/100
# 14/14 - 1s - loss: 0.2671 - accuracy: 0.9062 - val_loss: 0.7852 - val_accuracy: 0.5417 - 926ms/epoch - 66ms/step
# Epoch 93/100
# 14/14 - 1s - loss: 0.2717 - accuracy: 0.9107 - val_loss: 1.2710 - val_accuracy: 0.4896 - 919ms/epoch - 66ms/step
# Epoch 94/100
# 14/14 - 1s - loss: 0.2562 - accuracy: 0.8973 - val_loss: 1.0220 - val_accuracy: 0.5521 - 922ms/epoch - 66ms/step
# Epoch 95/100
# 14/14 - 1s - loss: 0.2475 - accuracy: 0.9107 - val_loss: 1.0130 - val_accuracy: 0.5625 - 909ms/epoch - 65ms/step
# Epoch 96/100
# 14/14 - 1s - loss: 0.2923 - accuracy: 0.8616 - val_loss: 0.9738 - val_accuracy: 0.5417 - 922ms/epoch - 66ms/step
# Epoch 97/100
# 14/14 - 1s - loss: 0.2660 - accuracy: 0.9107 - val_loss: 0.8546 - val_accuracy: 0.5729 - 939ms/epoch - 67ms/step
# Epoch 98/100
# 14/14 - 1s - loss: 0.2893 - accuracy: 0.9107 - val_loss: 0.9767 - val_accuracy: 0.5312 - 925ms/epoch - 66ms/step
# Epoch 99/100
# 14/14 - 1s - loss: 0.2456 - accuracy: 0.9152 - val_loss: 0.7700 - val_accuracy: 0.5833 - 943ms/epoch - 67ms/step
# Epoch 100/100
# 14/14 - 1s - loss: 0.2504 - accuracy: 0.9107 - val_loss: 0.7651 - val_accuracy: 0.5938 - 912ms/epoch - 65ms/step

# %%
# load optimal weights
# model.load_weights('./tmp/mi_checkpoint.h5')

###############################################################################
# can alternatively used the weights provided in the repo. If so it should get
# you 93% accuracy. Change the WEIGHTS_PATH variable to wherever it is on your
# system.
###############################################################################

# WEIGHTS_PATH = /path/to/EEGNet-8-2-weights.h5 
# model.load_weights(WEIGHTS_PATH)

###############################################################################
# make prediction on test set.
###############################################################################

probs       = model.predict(X_test)
preds       = probs.argmax(axis = -1)  
acc         = np.mean(preds == Y_test.argmax(axis=-1))
print("Classification accuracy: %f " % (acc))
# Out:
# 3/3 [==============================] - 0s 13ms/step
# Classification accuracy: 0.635294

# %%
############################# PyRiemann Portion ##############################

# code is taken from PyRiemann's ERP sample script, which is decoding in 
# the tangent space with a logistic regression

# n_components = 2  # pick some components

# # set up sklearn pipeline
# clf = make_pipeline(XdawnCovariances(n_components),
#                     TangentSpace(metric='riemann'),
#                     LogisticRegression())

# preds_rg     = np.zeros(len(Y_test))

# # reshape back to (trials, channels, samples)
# X_train      = X_train.reshape(X_train.shape[0], chans, samples)
# X_test       = X_test.reshape(X_test.shape[0], chans, samples)

# # train a classifier with xDAWN spatial filtering + Riemannian Geometry (RG)
# # labels need to be back in single-column format
# clf.fit(X_train, Y_train.argmax(axis = -1))
# preds_rg     = clf.predict(X_test)

# # Printing the results
# acc2         = np.mean(preds_rg == Y_test.argmax(axis = -1))
# print("Classification accuracy: %f " % (acc2))

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# %%
# plot the confusion matrices for both classifiers
names        = ['hands', 'feet']
# plt.figure(0)
confusion_matrix_1 = confusion_matrix(preds, Y_test)

# plt.figure(1)
# confusion_matrix_2 = confusion_matrix(preds_rg, Y_test)

disp1 = ConfusionMatrixDisplay(confusion_matrix_1, display_labels = names)
disp1.plot()

# disp2 = ConfusionMatrixDisplay(confusion_matrix_2, display_labels = names)
# disp2.plot()

# %%
print(classification_report(preds, Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.59      0.67        54
#            1       0.50      0.71      0.59        31
#
#     accuracy                           0.64        85
#    macro avg       0.64      0.65      0.63        85
# weighted avg       0.68      0.64      0.64        85
