# %%
# !pip install mne
# !pip install tensorflow==2.14.0
# !pip install tensorflow_privacy==0.9.0
# !pip install pyriemann
# Out:
# Requirement already satisfied: mne in /usr/local/lib/python3.11/dist-packages (1.9.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from mne) (4.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from mne) (3.1.6)
# Requirement already satisfied: lazy-loader>=0.3 in /usr/local/lib/python3.11/dist-packages (from mne) (0.4)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.11/dist-packages (from mne) (3.10.0)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.11/dist-packages (from mne) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from mne) (22.0)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.11/dist-packages (from mne) (1.8.2)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.11/dist-packages (from mne) (1.15.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from mne) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.5->mne) (4.3.8)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.5->mne) (2.32.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->mne) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6->mne) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2025.4.26)
# Requirement already satisfied: tensorflow==2.14.0 in /usr/local/lib/python3.11/dist-packages (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (3.13.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (18.1.1)
# Requirement already satisfied: ml-dtypes==0.2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (22.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (4.25.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (4.14.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (1.72.1)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow==2.14.0) (0.45.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.2.2)
# Requirement already satisfied: tensorflow_privacy==0.9.0 in /usr/local/lib/python3.11/dist-packages (0.9.0)
# Requirement already satisfied: absl-py==1.*,>=1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_privacy==0.9.0) (1.4.0)
# Requirement already satisfied: dm-tree==0.1.8 in /usr/local/lib/python3.11/dist-packages (from tensorflow_privacy==0.9.0) (0.1.8)
# Requirement already satisfied: dp-accounting==0.4.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow_privacy==0.9.0) (0.4.3)
# Requirement already satisfied: numpy~=1.21 in /usr/local/lib/python3.11/dist-packages (from tensorflow_privacy==0.9.0) (1.26.4)
# Requirement already satisfied: packaging~=22.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_privacy==0.9.0) (22.0)
# Requirement already satisfied: scikit-learn==1.*,>=1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_privacy==0.9.0) (1.7.0)
# Requirement already satisfied: scipy~=1.9 in /usr/local/lib/python3.11/dist-packages (from tensorflow_privacy==0.9.0) (1.15.3)
# Requirement already satisfied: tensorflow-estimator~=2.4 in /usr/local/lib/python3.11/dist-packages (from tensorflow_privacy==0.9.0) (2.14.0)
# Requirement already satisfied: tensorflow-probability~=0.22.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_privacy==0.9.0) (0.22.1)
# Requirement already satisfied: tensorflow~=2.4 in /usr/local/lib/python3.11/dist-packages (from tensorflow_privacy==0.9.0) (2.14.0)
# Requirement already satisfied: attrs>=22 in /usr/local/lib/python3.11/dist-packages (from dp-accounting==0.4.3->tensorflow_privacy==0.9.0) (25.3.0)
# Requirement already satisfied: mpmath~=1.2 in /usr/local/lib/python3.11/dist-packages (from dp-accounting==0.4.3->tensorflow_privacy==0.9.0) (1.3.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.*,>=1.0->tensorflow_privacy==0.9.0) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.*,>=1.0->tensorflow_privacy==0.9.0) (3.6.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow~=2.4->tensorflow_privacy==0.9.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.11/dist-packages (from tensorflow~=2.4->tensorflow_privacy==0.9.0) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow~=2.4->tensorflow_privacy==0.9.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow~=2.4->tensorflow_privacy==0.9.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow~=2.4->tensorflow_privacy==0.9.0) (3.13.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow~=2.4->tensorflow_privacy==0.9.0) (18.1.1)
# Requirement already satisfied: ml-dtypes==0.2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow~=2.4->tensorflow_privacy==0.9.0) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow~=2.4->tensorflow_privacy==0.9.0) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow~=2.4->tensorflow_privacy==0.9.0) (4.25.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow~=2.4->tensorflow_privacy==0.9.0) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow~=2.4->tensorflow_privacy==0.9.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow~=2.4->tensorflow_privacy==0.9.0) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow~=2.4->tensorflow_privacy==0.9.0) (4.14.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow~=2.4->tensorflow_privacy==0.9.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow~=2.4->tensorflow_privacy==0.9.0) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow~=2.4->tensorflow_privacy==0.9.0) (1.72.1)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /usr/local/lib/python3.11/dist-packages (from tensorflow~=2.4->tensorflow_privacy==0.9.0) (2.14.1)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow~=2.4->tensorflow_privacy==0.9.0) (2.14.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from tensorflow-probability~=0.22.0->tensorflow_privacy==0.9.0) (4.4.2)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow-probability~=0.22.0->tensorflow_privacy==0.9.0) (3.1.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow~=2.4->tensorflow_privacy==0.9.0) (0.45.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow~=2.4->tensorflow_privacy==0.9.0) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow~=2.4->tensorflow_privacy==0.9.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow~=2.4->tensorflow_privacy==0.9.0) (3.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow~=2.4->tensorflow_privacy==0.9.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow~=2.4->tensorflow_privacy==0.9.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow~=2.4->tensorflow_privacy==0.9.0) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow~=2.4->tensorflow_privacy==0.9.0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow~=2.4->tensorflow_privacy==0.9.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow~=2.4->tensorflow_privacy==0.9.0) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow~=2.4->tensorflow_privacy==0.9.0) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow~=2.4->tensorflow_privacy==0.9.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow~=2.4->tensorflow_privacy==0.9.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow~=2.4->tensorflow_privacy==0.9.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow~=2.4->tensorflow_privacy==0.9.0) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow~=2.4->tensorflow_privacy==0.9.0) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow~=2.4->tensorflow_privacy==0.9.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow~=2.4->tensorflow_privacy==0.9.0) (3.2.2)
# Requirement already satisfied: pyriemann in /usr/local/lib/python3.11/dist-packages (0.8)
# Collecting numpy>=2.0.0 (from pyriemann)
#   Using cached numpy-2.3.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pyriemann) (1.15.3)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.11/dist-packages (from pyriemann) (1.7.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from pyriemann) (1.5.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from pyriemann) (3.10.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.24->pyriemann) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pyriemann) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pyriemann) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pyriemann) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pyriemann) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pyriemann) (22.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pyriemann) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pyriemann) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pyriemann) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->pyriemann) (1.17.0)
# Using cached numpy-2.3.0-cp311-cp311-manylinux_2_28_x86_64.whl (16.9 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-privacy 0.9.0 requires numpy~=1.21, but you have numpy 2.3.0 which is incompatible.
# dp-accounting 0.4.3 requires numpy~=1.21, but you have numpy 2.3.0 which is incompatible.
# tensorflow-text 2.18.1 requires tensorflow<2.19,>=2.18.0, but you have tensorflow 2.14.0 which is incompatible.
# jax 0.5.2 requires ml_dtypes>=0.4.0, but you have ml-dtypes 0.2.0 which is incompatible.
# db-dtypes 1.4.3 requires packaging>=24.2.0, but you have packaging 22.0 which is incompatible.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.7.0 which is incompatible.
# ydf 0.12.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 4.25.8 which is incompatible.
# tf-keras 2.18.0 requires tensorflow<2.19,>=2.18, but you have tensorflow 2.14.0 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.0 which is incompatible.
# tensorstore 0.1.74 requires ml_dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# cupy-cuda12x 13.3.0 requires numpy<2.3,>=1.22, but you have numpy 2.3.0 which is incompatible.
# xarray 2025.3.1 requires packaging>=23.2, but you have packaging 22.0 which is incompatible.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, but you have tensorflow 2.14.0 which is incompatible.
# Successfully installed numpy-2.3.0

# %%
# !pip install --upgrade numpy==1.26.4
# !pip install --upgrade scikit-learn
# Out:
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.0
#     Uninstalling numpy-2.3.0:
#       Successfully uninstalled numpy-2.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyriemann 0.8 requires numpy>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# tensorflow-text 2.18.1 requires tensorflow<2.19,>=2.18.0, but you have tensorflow 2.14.0 which is incompatible.
# jax 0.5.2 requires ml_dtypes>=0.4.0, but you have ml-dtypes 0.2.0 which is incompatible.
# db-dtypes 1.4.3 requires packaging>=24.2.0, but you have packaging 22.0 which is incompatible.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.7.0 which is incompatible.
# ydf 0.12.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 4.25.8 which is incompatible.
# tf-keras 2.18.0 requires tensorflow<2.19,>=2.18, but you have tensorflow 2.14.0 which is incompatible.
# tensorstore 0.1.74 requires ml_dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# xarray 2025.3.1 requires packaging>=23.2, but you have packaging 22.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, but you have tensorflow 2.14.0 which is incompatible.
# Successfully installed numpy-1.26.4
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.7.0)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)

# %%
import numpy as np

# mne imports
import mne
from mne import io
from mne.datasets import sample

# EEGNet-specific imports
# from EEGModels import EEGNet
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K

# PyRiemann imports
from pyriemann.estimation import XdawnCovariances
from pyriemann.tangentspace import TangentSpace
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# tools for plotting confusion matrices
from matplotlib import pyplot as plt

# %%
"""
 ARL_EEGModels - A collection of Convolutional Neural Network models for EEG
 Signal Processing and Classification, using Keras and Tensorflow

 Requirements:
    (1) tensorflow == 2.X (as of this writing, 2.0 - 2.3 have been verified
        as working)

 To run the EEG/MEG ERP classification sample script, you will also need

    (4) mne >= 0.17.1
    (5) PyRiemann >= 0.2.5
    (6) scikit-learn >= 0.20.1
    (7) matplotlib >= 2.2.3

 To use:

    (1) Place this file in the PYTHONPATH variable in your IDE (i.e.: Spyder)
    (2) Import the model as

        from EEGModels import EEGNet

        model = EEGNet(nb_classes = ..., Chans = ..., Samples = ...)

    (3) Then compile and fit the model

        model.compile(loss = ..., optimizer = ..., metrics = ...)
        fitted    = model.fit(...)
        predicted = model.predict(...)

 Portions of this project are works of the United States Government and are not
 subject to domestic copyright protection under 17 USC Sec. 105.  Those
 portions are released world-wide under the terms of the Creative Commons Zero
 1.0 (CC0) license.

 Other portions of this project are subject to domestic copyright protection
 under 17 USC Sec. 105.  Those portions are licensed under the Apache 2.0
 license.  The complete text of the license governing this material is in
 the file labeled LICENSE.TXT that is a part of this project's official
 distribution.
"""

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Activation, Permute, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import SeparableConv2D, DepthwiseConv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import SpatialDropout2D
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.constraints import max_norm
from tensorflow.keras import backend as K


def EEGNet(nb_classes, Chans = 64, Samples = 128,
             dropoutRate = 0.5, kernLength = 64, F1 = 8,
             D = 2, F2 = 16, norm_rate = 0.25, dropoutType = 'Dropout'):
    """ Keras Implementation of EEGNet
    http://iopscience.iop.org/article/10.1088/1741-2552/aace8c/meta

    Note that this implements the newest version of EEGNet and NOT the earlier
    version (version v1 and v2 on arxiv). We strongly recommend using this
    architecture as it performs much better and has nicer properties than
    our earlier version. For example:

        1. Depthwise Convolutions to learn spatial filters within a
        temporal convolution. The use of the depth_multiplier option maps
        exactly to the number of spatial filters learned within a temporal
        filter. This matches the setup of algorithms like FBCSP which learn
        spatial filters within each filter in a filter-bank. This also limits
        the number of free parameters to fit when compared to a fully-connected
        convolution.

        2. Separable Convolutions to learn how to optimally combine spatial
        filters across temporal bands. Separable Convolutions are Depthwise
        Convolutions followed by (1x1) Pointwise Convolutions.


    While the original paper used Dropout, we found that SpatialDropout2D
    sometimes produced slightly better results for classification of ERP
    signals. However, SpatialDropout2D significantly reduced performance
    on the Oscillatory dataset (SMR, BCI-IV Dataset 2A). We recommend using
    the default Dropout in most cases.

    Assumes the input signal is sampled at 128Hz. If you want to use this model
    for any other sampling rate you will need to modify the lengths of temporal
    kernels and average pooling size in blocks 1 and 2 as needed (double the
    kernel lengths for double the sampling rate, etc). Note that we haven't
    tested the model performance with this rule so this may not work well.

    The model with default parameters gives the EEGNet-8,2 model as discussed
    in the paper. This model should do pretty well in general, although it is
	advised to do some model searching to get optimal performance on your
	particular dataset.

    We set F2 = F1 * D (number of input filters = number of output filters) for
    the SeparableConv2D layer. We haven't extensively tested other values of this
    parameter (say, F2 < F1 * D for compressed learning, and F2 > F1 * D for
    overcomplete). We believe the main parameters to focus on are F1 and D.

    Inputs:

      nb_classes      : int, number of classes to classify
      Chans, Samples  : number of channels and time points in the EEG data
      dropoutRate     : dropout fraction
      kernLength      : length of temporal convolution in first layer. We found
                        that setting this to be half the sampling rate worked
                        well in practice. For the SMR dataset in particular
                        since the data was high-passed at 4Hz we used a kernel
                        length of 32.
      F1, F2          : number of temporal filters (F1) and number of pointwise
                        filters (F2) to learn. Default: F1 = 8, F2 = F1 * D.
      D               : number of spatial filters to learn within each temporal
                        convolution. Default: D = 2
      dropoutType     : Either SpatialDropout2D or Dropout, passed as a string.

    """

    if dropoutType == 'SpatialDropout2D':
        dropoutType = SpatialDropout2D
    elif dropoutType == 'Dropout':
        dropoutType = Dropout
    else:
        raise ValueError('dropoutType must be one of SpatialDropout2D '
                         'or Dropout, passed as a string.')

    input1   = Input(shape = (Chans, Samples, 1))

    ##################################################################
    block1       = Conv2D(F1, (1, kernLength), padding = 'same',
                                   input_shape = (Chans, Samples, 1),
                                   use_bias = False)(input1)
    block1       = BatchNormalization()(block1)
    block1       = DepthwiseConv2D((Chans, 1), use_bias = False,
                                   depth_multiplier = D,
                                   depthwise_constraint = max_norm(1.))(block1)
    block1       = BatchNormalization()(block1)
    block1       = Activation('elu')(block1)
    block1       = AveragePooling2D((1, 4))(block1)
    block1       = dropoutType(dropoutRate)(block1)

    block2       = SeparableConv2D(F2, (1, 16),
                                   use_bias = False, padding = 'same')(block1)
    block2       = BatchNormalization()(block2)
    block2       = Activation('elu')(block2)
    block2       = AveragePooling2D((1, 8))(block2)
    block2       = dropoutType(dropoutRate)(block2)

    flatten      = Flatten(name = 'flatten')(block2)

    dense        = Dense(nb_classes, name = 'dense',
                         kernel_constraint = max_norm(norm_rate))(flatten)
    softmax      = Activation('softmax', name = 'softmax')(dense)

    return Model(inputs=input1, outputs=softmax)




def EEGNet_SSVEP(nb_classes = 12, Chans = 8, Samples = 256,
             dropoutRate = 0.5, kernLength = 256, F1 = 96,
             D = 1, F2 = 96, dropoutType = 'Dropout'):
    """ SSVEP Variant of EEGNet, as used in [1].

    Inputs:

      nb_classes      : int, number of classes to classify
      Chans, Samples  : number of channels and time points in the EEG data
      dropoutRate     : dropout fraction
      kernLength      : length of temporal convolution in first layer
      F1, F2          : number of temporal filters (F1) and number of pointwise
                        filters (F2) to learn.
      D               : number of spatial filters to learn within each temporal
                        convolution.
      dropoutType     : Either SpatialDropout2D or Dropout, passed as a string.


    [1]. Waytowich, N. et. al. (2018). Compact Convolutional Neural Networks
    for Classification of Asynchronous Steady-State Visual Evoked Potentials.
    Journal of Neural Engineering vol. 15(6).
    http://iopscience.iop.org/article/10.1088/1741-2552/aae5d8

    """

    if dropoutType == 'SpatialDropout2D':
        dropoutType = SpatialDropout2D
    elif dropoutType == 'Dropout':
        dropoutType = Dropout
    else:
        raise ValueError('dropoutType must be one of SpatialDropout2D '
                         'or Dropout, passed as a string.')

    input1   = Input(shape = (Chans, Samples, 1))

    ##################################################################
    block1       = Conv2D(F1, (1, kernLength), padding = 'same',
                                   input_shape = (Chans, Samples, 1),
                                   use_bias = False)(input1)
    block1       = BatchNormalization()(block1)
    block1       = DepthwiseConv2D((Chans, 1), use_bias = False,
                                   depth_multiplier = D,
                                   depthwise_constraint = max_norm(1.))(block1)
    block1       = BatchNormalization()(block1)
    block1       = Activation('elu')(block1)
    block1       = AveragePooling2D((1, 4))(block1)
    block1       = dropoutType(dropoutRate)(block1)

    block2       = SeparableConv2D(F2, (1, 16),
                                   use_bias = False, padding = 'same')(block1)
    block2       = BatchNormalization()(block2)
    block2       = Activation('elu')(block2)
    block2       = AveragePooling2D((1, 8))(block2)
    block2       = dropoutType(dropoutRate)(block2)

    flatten      = Flatten(name = 'flatten')(block2)

    dense        = Dense(nb_classes, name = 'dense')(flatten)
    softmax      = Activation('softmax', name = 'softmax')(dense)

    return Model(inputs=input1, outputs=softmax)



def EEGNet_old(nb_classes, Chans = 64, Samples = 128, regRate = 0.0001,
           dropoutRate = 0.25, kernels = [(2, 32), (8, 4)], strides = (2, 4)):
    """ Keras Implementation of EEGNet_v1 (https://arxiv.org/abs/1611.08024v2)

    This model is the original EEGNet model proposed on arxiv
            https://arxiv.org/abs/1611.08024v2

    with a few modifications: we use striding instead of max-pooling as this
    helped slightly in classification performance while also providing a
    computational speed-up.

    Note that we no longer recommend the use of this architecture, as the new
    version of EEGNet performs much better overall and has nicer properties.

    Inputs:

        nb_classes     : total number of final categories
        Chans, Samples : number of EEG channels and samples, respectively
        regRate        : regularization rate for L1 and L2 regularizations
        dropoutRate    : dropout fraction
        kernels        : the 2nd and 3rd layer kernel dimensions (default is
                         the [2, 32] x [8, 4] configuration)
        strides        : the stride size (note that this replaces the max-pool
                         used in the original paper)

    """

    # start the model
    input_main   = Input((Chans, Samples))
    layer1       = Conv2D(16, (Chans, 1), input_shape=(Chans, Samples, 1),
                                 kernel_regularizer = l1_l2(l1=regRate, l2=regRate))(input_main)
    layer1       = BatchNormalization()(layer1)
    layer1       = Activation('elu')(layer1)
    layer1       = Dropout(dropoutRate)(layer1)

    permute_dims = 2, 1, 3
    permute1     = Permute(permute_dims)(layer1)

    layer2       = Conv2D(4, kernels[0], padding = 'same',
                            kernel_regularizer=l1_l2(l1=0.0, l2=regRate),
                            strides = strides)(permute1)
    layer2       = BatchNormalization()(layer2)
    layer2       = Activation('elu')(layer2)
    layer2       = Dropout(dropoutRate)(layer2)

    layer3       = Conv2D(4, kernels[1], padding = 'same',
                            kernel_regularizer=l1_l2(l1=0.0, l2=regRate),
                            strides = strides)(layer2)
    layer3       = BatchNormalization()(layer3)
    layer3       = Activation('elu')(layer3)
    layer3       = Dropout(dropoutRate)(layer3)

    flatten      = Flatten(name = 'flatten')(layer3)

    dense        = Dense(nb_classes, name = 'dense')(flatten)
    softmax      = Activation('softmax', name = 'softmax')(dense)

    return Model(inputs=input_main, outputs=softmax)



def DeepConvNet(nb_classes, Chans = 64, Samples = 256,
                dropoutRate = 0.5):
    """ Keras implementation of the Deep Convolutional Network as described in
    Schirrmeister et. al. (2017), Human Brain Mapping.

    This implementation assumes the input is a 2-second EEG signal sampled at
    128Hz, as opposed to signals sampled at 250Hz as described in the original
    paper. We also perform temporal convolutions of length (1, 5) as opposed
    to (1, 10) due to this sampling rate difference.

    Note that we use the max_norm constraint on all convolutional layers, as
    well as the classification layer. We also change the defaults for the
    BatchNormalization layer. We used this based on a personal communication
    with the original authors.

                      ours        original paper
    pool_size        1, 2        1, 3
    strides          1, 2        1, 3
    conv filters     1, 5        1, 10

    Note that this implementation has not been verified by the original
    authors.

    """

    # start the model
    input_main   = Input((Chans, Samples, 1))
    block1       = Conv2D(25, (1, 5),
                                 input_shape=(Chans, Samples, 1),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(input_main)
    block1       = Conv2D(25, (Chans, 1),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block1)
    block1       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block1)
    block1       = Activation('elu')(block1)
    block1       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block1)
    block1       = Dropout(dropoutRate)(block1)

    block2       = Conv2D(50, (1, 5),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block1)
    block2       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block2)
    block2       = Activation('elu')(block2)
    block2       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block2)
    block2       = Dropout(dropoutRate)(block2)

    block3       = Conv2D(100, (1, 5),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block2)
    block3       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block3)
    block3       = Activation('elu')(block3)
    block3       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block3)
    block3       = Dropout(dropoutRate)(block3)

    block4       = Conv2D(200, (1, 5),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block3)
    block4       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block4)
    block4       = Activation('elu')(block4)
    block4       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block4)
    block4       = Dropout(dropoutRate)(block4)

    flatten      = Flatten()(block4)

    dense        = Dense(nb_classes, kernel_constraint = max_norm(0.5))(flatten)
    softmax      = Activation('softmax')(dense)

    return Model(inputs=input_main, outputs=softmax)


# need these for ShallowConvNet
def square(x):
    return K.square(x)

def log(x):
    return K.log(K.clip(x, min_value = 1e-7, max_value = 10000))


def ShallowConvNet(nb_classes, Chans = 64, Samples = 128, dropoutRate = 0.5):
    """ Keras implementation of the Shallow Convolutional Network as described
    in Schirrmeister et. al. (2017), Human Brain Mapping.

    Assumes the input is a 2-second EEG signal sampled at 128Hz. Note that in
    the original paper, they do temporal convolutions of length 25 for EEG
    data sampled at 250Hz. We instead use length 13 since the sampling rate is
    roughly half of the 250Hz which the paper used. The pool_size and stride
    in later layers is also approximately half of what is used in the paper.

    Note that we use the max_norm constraint on all convolutional layers, as
    well as the classification layer. We also change the defaults for the
    BatchNormalization layer. We used this based on a personal communication
    with the original authors.

                     ours        original paper
    pool_size        1, 35       1, 75
    strides          1, 7        1, 15
    conv filters     1, 13       1, 25

    Note that this implementation has not been verified by the original
    authors. We do note that this implementation reproduces the results in the
    original paper with minor deviations.
    """

    # start the model
    input_main   = Input((Chans, Samples, 1))
    block1       = Conv2D(40, (1, 13),
                                 input_shape=(Chans, Samples, 1),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(input_main)
    block1       = Conv2D(40, (Chans, 1), use_bias=False,
                          kernel_constraint = max_norm(2., axis=(0,1,2)))(block1)
    block1       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block1)
    block1       = Activation(square)(block1)
    block1       = AveragePooling2D(pool_size=(1, 35), strides=(1, 7))(block1)
    block1       = Activation(log)(block1)
    block1       = Dropout(dropoutRate)(block1)
    flatten      = Flatten()(block1)
    dense        = Dense(nb_classes, kernel_constraint = max_norm(0.5))(flatten)
    softmax      = Activation('softmax')(dense)

    return Model(inputs=input_main, outputs=softmax)

# %%
# while the default tensorflow ordering is 'channels_last' we set it here
# to be explicit in case if the user has changed the default ordering
K.set_image_data_format('channels_last')

##################### Process, filter and epoch the data ######################
data_path = str(sample.data_path())

# Set parameters and read data
raw_fname = data_path + '/MEG/sample/sample_audvis_filt-0-40_raw.fif'
event_fname = data_path + '/MEG/sample/sample_audvis_filt-0-40_raw-eve.fif'
tmin, tmax = -0., 1
event_id = dict(aud_l=1, aud_r=2, vis_l=3, vis_r=4)
# Out:
# Using default location ~/mne_data for sample...
# Creating /root/mne_data
# Downloading file 'MNE-sample-data-processed.tar.gz' from 'https://osf.io/86qa2/download?version=6' to '/root/mne_data'.
# 100%|█████████████████████████████████████| 1.65G/1.65G [00:00<00:00, 2.40TB/s]
# Untarring contents of '/root/mne_data/MNE-sample-data-processed.tar.gz' to '/root/mne_data'
# Attempting to create new mne-python configuration file:
# /root/.mne/mne-python.json
# Download complete in 04m37s (1576.2 MB)

# %%
# Setup for reading the raw data
raw = io.Raw(raw_fname, preload=True, verbose=False)
raw.filter(2, None, method='iir')  # replace baselining with high-pass
events = mne.read_events(event_fname)

raw.info['bads'] = ['MEG 2443']  # set bad channels
picks = mne.pick_types(raw.info, meg=False, eeg=True, stim=False, eog=False,
                       exclude='bads')

# Read epochs
epochs = mne.Epochs(raw, events, event_id, tmin, tmax, proj=False,
                    picks=picks, baseline=None, preload=True, verbose=False)
labels = epochs.events[:, -1]

# extract raw data. scale by 1000 due to scaling sensitivity in deep learning
X = epochs.get_data()*1000 # format is in (trials, channels, samples)
y = labels

kernels, chans, samples = 1, 60, 151
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 2 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 2.00 Hz: -6.02 dB

# %%
import time
start = time.time()

# %%
# take 50/25/25 percent of the data to train/validate/test
X_train      = X[0:144,]
Y_train      = y[0:144]
X_validate   = X[144:216,]
Y_validate   = y[144:216]
X_test       = X[216:,]
Y_test       = y[216:]

############################# EEGNet portion ##################################

# convert labels to one-hot encodings.
Y_train      = np_utils.to_categorical(Y_train-1)
Y_validate   = np_utils.to_categorical(Y_validate-1)
Y_test       = np_utils.to_categorical(Y_test-1)

# convert data to NHWC (trials, channels, samples, kernels) format. Data
# contains 60 channels and 151 time-points. Set the number of kernels to 1.
X_train      = X_train.reshape(X_train.shape[0], chans, samples, kernels)
X_validate   = X_validate.reshape(X_validate.shape[0], chans, samples, kernels)
X_test       = X_test.reshape(X_test.shape[0], chans, samples, kernels)

print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# X_train shape: (144, 60, 151, 1)
# 144 train samples
# 72 test samples

# %%
import os
os.makedirs('./tmp', exist_ok=True)

# %%
model = ShallowConvNet(nb_classes = 4, Chans = chans, Samples = samples, dropoutRate = 0.5)

# compile the model and set the optimizers
model.compile(loss='categorical_crossentropy', optimizer='adam',
              metrics = ['accuracy'])

# count number of parameters in the model
numParams    = model.count_params()

# set a valid path for your system to record model checkpoints
checkpointer = ModelCheckpoint(filepath='./tmp/checkpoint.h5', verbose=1,
                               save_best_only=True)

###############################################################################
# if the classification task was imbalanced (significantly more trials in one
# class versus the others) you can assign a weight to each class during
# optimization to balance it out. This data is approximately balanced so we
# don't need to do this, but is shown here for illustration/completeness.
###############################################################################

# the syntax is {class_1:weight_1, class_2:weight_2,...}. Here just setting
# the weights all to be 1
class_weights = {0:1, 1:1, 2:1, 3:1}

################################################################################
# fit the model. Due to very small sample sizes this can get
# pretty noisy run-to-run, but most runs should be comparable to xDAWN +
# Riemannian geometry classification (below)
################################################################################
fittedModel = model.fit(X_train, Y_train, batch_size = 16, epochs = 300,
                        verbose = 2, validation_data=(X_validate, Y_validate),
                        callbacks=[checkpointer], class_weight = class_weights)
# Out:
# Epoch 1/300
#
# Epoch 1: val_loss improved from inf to 1.64589, saving model to ./tmp/checkpoint.h5
# 9/9 - 2s - loss: 2.0020 - accuracy: 0.2917 - val_loss: 1.6459 - val_accuracy: 0.2500 - 2s/epoch - 227ms/step
# Epoch 2/300
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss did not improve from 1.64589
# 9/9 - 1s - loss: 1.3681 - accuracy: 0.3611 - val_loss: 2.7524 - val_accuracy: 0.2361 - 1s/epoch - 131ms/step
# Epoch 3/300
#
# Epoch 3: val_loss improved from 1.64589 to 1.50154, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 1.2822 - accuracy: 0.4167 - val_loss: 1.5015 - val_accuracy: 0.2639 - 1s/epoch - 159ms/step
# Epoch 4/300
#
# Epoch 4: val_loss did not improve from 1.50154
# 9/9 - 1s - loss: 1.2807 - accuracy: 0.4236 - val_loss: 1.7953 - val_accuracy: 0.3194 - 905ms/epoch - 101ms/step
# Epoch 5/300
#
# Epoch 5: val_loss did not improve from 1.50154
# 9/9 - 1s - loss: 1.1975 - accuracy: 0.4861 - val_loss: 2.1627 - val_accuracy: 0.2361 - 706ms/epoch - 78ms/step
# Epoch 6/300
#
# Epoch 6: val_loss did not improve from 1.50154
# 9/9 - 1s - loss: 1.1288 - accuracy: 0.5139 - val_loss: 2.2633 - val_accuracy: 0.2361 - 738ms/epoch - 82ms/step
# Epoch 7/300
#
# Epoch 7: val_loss did not improve from 1.50154
# 9/9 - 1s - loss: 1.0101 - accuracy: 0.5486 - val_loss: 1.7011 - val_accuracy: 0.2917 - 776ms/epoch - 86ms/step
# Epoch 8/300
#
# Epoch 8: val_loss improved from 1.50154 to 1.46615, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.9664 - accuracy: 0.6319 - val_loss: 1.4662 - val_accuracy: 0.3056 - 795ms/epoch - 88ms/step
# Epoch 9/300
#
# Epoch 9: val_loss improved from 1.46615 to 1.32926, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.8929 - accuracy: 0.6806 - val_loss: 1.3293 - val_accuracy: 0.3889 - 754ms/epoch - 84ms/step
# Epoch 10/300
#
# Epoch 10: val_loss improved from 1.32926 to 1.21751, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.8434 - accuracy: 0.6944 - val_loss: 1.2175 - val_accuracy: 0.4167 - 752ms/epoch - 84ms/step
# Epoch 11/300
#
# Epoch 11: val_loss improved from 1.21751 to 1.12175, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.7653 - accuracy: 0.7500 - val_loss: 1.1218 - val_accuracy: 0.5139 - 794ms/epoch - 88ms/step
# Epoch 12/300
#
# Epoch 12: val_loss improved from 1.12175 to 1.05568, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.7085 - accuracy: 0.7569 - val_loss: 1.0557 - val_accuracy: 0.5417 - 759ms/epoch - 84ms/step
# Epoch 13/300
#
# Epoch 13: val_loss improved from 1.05568 to 0.99813, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.6462 - accuracy: 0.8056 - val_loss: 0.9981 - val_accuracy: 0.5833 - 768ms/epoch - 85ms/step
# Epoch 14/300
#
# Epoch 14: val_loss improved from 0.99813 to 0.98800, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.6125 - accuracy: 0.8333 - val_loss: 0.9880 - val_accuracy: 0.5694 - 802ms/epoch - 89ms/step
# Epoch 15/300
#
# Epoch 15: val_loss improved from 0.98800 to 0.97737, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.5187 - accuracy: 0.8681 - val_loss: 0.9774 - val_accuracy: 0.6111 - 768ms/epoch - 85ms/step
# Epoch 16/300
#
# Epoch 16: val_loss improved from 0.97737 to 0.91583, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.5060 - accuracy: 0.9028 - val_loss: 0.9158 - val_accuracy: 0.6389 - 781ms/epoch - 87ms/step
# Epoch 17/300
#
# Epoch 17: val_loss improved from 0.91583 to 0.89047, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.4213 - accuracy: 0.9236 - val_loss: 0.8905 - val_accuracy: 0.5972 - 1s/epoch - 154ms/step
# Epoch 18/300
#
# Epoch 18: val_loss improved from 0.89047 to 0.87810, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.3890 - accuracy: 0.9375 - val_loss: 0.8781 - val_accuracy: 0.6250 - 1s/epoch - 143ms/step
# Epoch 19/300
#
# Epoch 19: val_loss improved from 0.87810 to 0.83255, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.3654 - accuracy: 0.9444 - val_loss: 0.8325 - val_accuracy: 0.6667 - 811ms/epoch - 90ms/step
# Epoch 20/300
#
# Epoch 20: val_loss improved from 0.83255 to 0.82374, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.3742 - accuracy: 0.9167 - val_loss: 0.8237 - val_accuracy: 0.6389 - 776ms/epoch - 86ms/step
# Epoch 21/300
#
# Epoch 21: val_loss improved from 0.82374 to 0.74142, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.2903 - accuracy: 0.9653 - val_loss: 0.7414 - val_accuracy: 0.6806 - 740ms/epoch - 82ms/step
# Epoch 22/300
#
# Epoch 22: val_loss did not improve from 0.74142
# 9/9 - 1s - loss: 0.2904 - accuracy: 0.9653 - val_loss: 0.7517 - val_accuracy: 0.6667 - 773ms/epoch - 86ms/step
# Epoch 23/300
#
# Epoch 23: val_loss improved from 0.74142 to 0.70653, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.2472 - accuracy: 0.9792 - val_loss: 0.7065 - val_accuracy: 0.7222 - 806ms/epoch - 90ms/step
# Epoch 24/300
#
# Epoch 24: val_loss improved from 0.70653 to 0.67449, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.2111 - accuracy: 0.9931 - val_loss: 0.6745 - val_accuracy: 0.7361 - 772ms/epoch - 86ms/step
# Epoch 25/300
#
# Epoch 25: val_loss improved from 0.67449 to 0.65478, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.1921 - accuracy: 0.9931 - val_loss: 0.6548 - val_accuracy: 0.7361 - 734ms/epoch - 82ms/step
# Epoch 26/300
#
# Epoch 26: val_loss improved from 0.65478 to 0.65312, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.1806 - accuracy: 0.9792 - val_loss: 0.6531 - val_accuracy: 0.6944 - 742ms/epoch - 82ms/step
# Epoch 27/300
#
# Epoch 27: val_loss did not improve from 0.65312
# 9/9 - 1s - loss: 0.1627 - accuracy: 0.9792 - val_loss: 0.6809 - val_accuracy: 0.6944 - 708ms/epoch - 79ms/step
# Epoch 28/300
#
# Epoch 28: val_loss improved from 0.65312 to 0.63642, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.1410 - accuracy: 1.0000 - val_loss: 0.6364 - val_accuracy: 0.7361 - 786ms/epoch - 87ms/step
# Epoch 29/300
#
# Epoch 29: val_loss improved from 0.63642 to 0.58542, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.1460 - accuracy: 1.0000 - val_loss: 0.5854 - val_accuracy: 0.7361 - 842ms/epoch - 94ms/step
# Epoch 30/300
#
# Epoch 30: val_loss did not improve from 0.58542
# 9/9 - 1s - loss: 0.1118 - accuracy: 0.9931 - val_loss: 0.6188 - val_accuracy: 0.7500 - 773ms/epoch - 86ms/step
# Epoch 31/300
#
# Epoch 31: val_loss improved from 0.58542 to 0.56716, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.1204 - accuracy: 1.0000 - val_loss: 0.5672 - val_accuracy: 0.7639 - 823ms/epoch - 91ms/step
# Epoch 32/300
#
# Epoch 32: val_loss did not improve from 0.56716
# 9/9 - 1s - loss: 0.1046 - accuracy: 1.0000 - val_loss: 0.5807 - val_accuracy: 0.7639 - 1s/epoch - 129ms/step
# Epoch 33/300
#
# Epoch 33: val_loss did not improve from 0.56716
# 9/9 - 1s - loss: 0.1015 - accuracy: 1.0000 - val_loss: 0.5710 - val_accuracy: 0.7778 - 1s/epoch - 154ms/step
# Epoch 34/300
#
# Epoch 34: val_loss did not improve from 0.56716
# 9/9 - 1s - loss: 0.1033 - accuracy: 0.9931 - val_loss: 0.5903 - val_accuracy: 0.7639 - 756ms/epoch - 84ms/step
# Epoch 35/300
#
# Epoch 35: val_loss improved from 0.56716 to 0.55247, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.0878 - accuracy: 1.0000 - val_loss: 0.5525 - val_accuracy: 0.7639 - 730ms/epoch - 81ms/step
# Epoch 36/300
#
# Epoch 36: val_loss did not improve from 0.55247
# 9/9 - 1s - loss: 0.0897 - accuracy: 1.0000 - val_loss: 0.5814 - val_accuracy: 0.7778 - 685ms/epoch - 76ms/step
# Epoch 37/300
#
# Epoch 37: val_loss did not improve from 0.55247
# 9/9 - 1s - loss: 0.0817 - accuracy: 1.0000 - val_loss: 0.6034 - val_accuracy: 0.7361 - 716ms/epoch - 80ms/step
# Epoch 38/300
#
# Epoch 38: val_loss did not improve from 0.55247
# 9/9 - 1s - loss: 0.0757 - accuracy: 0.9931 - val_loss: 0.6111 - val_accuracy: 0.7500 - 704ms/epoch - 78ms/step
# Epoch 39/300
#
# Epoch 39: val_loss did not improve from 0.55247
# 9/9 - 1s - loss: 0.0755 - accuracy: 0.9931 - val_loss: 0.6561 - val_accuracy: 0.6944 - 675ms/epoch - 75ms/step
# Epoch 40/300
#
# Epoch 40: val_loss did not improve from 0.55247
# 9/9 - 1s - loss: 0.0904 - accuracy: 1.0000 - val_loss: 0.5571 - val_accuracy: 0.7778 - 698ms/epoch - 78ms/step
# Epoch 41/300
#
# Epoch 41: val_loss did not improve from 0.55247
# 9/9 - 1s - loss: 0.0785 - accuracy: 0.9931 - val_loss: 0.5784 - val_accuracy: 0.7778 - 723ms/epoch - 80ms/step
# Epoch 42/300
#
# Epoch 42: val_loss did not improve from 0.55247
# 9/9 - 1s - loss: 0.0857 - accuracy: 0.9931 - val_loss: 0.6696 - val_accuracy: 0.7500 - 709ms/epoch - 79ms/step
# Epoch 43/300
#
# Epoch 43: val_loss did not improve from 0.55247
# 9/9 - 1s - loss: 0.1039 - accuracy: 0.9861 - val_loss: 0.5879 - val_accuracy: 0.7917 - 750ms/epoch - 83ms/step
# Epoch 44/300
#
# Epoch 44: val_loss did not improve from 0.55247
# 9/9 - 1s - loss: 0.0825 - accuracy: 1.0000 - val_loss: 0.5661 - val_accuracy: 0.7361 - 764ms/epoch - 85ms/step
# Epoch 45/300
#
# Epoch 45: val_loss did not improve from 0.55247
# 9/9 - 1s - loss: 0.0887 - accuracy: 0.9861 - val_loss: 0.5991 - val_accuracy: 0.7778 - 783ms/epoch - 87ms/step
# Epoch 46/300
#
# Epoch 46: val_loss did not improve from 0.55247
# 9/9 - 1s - loss: 0.0684 - accuracy: 1.0000 - val_loss: 0.5706 - val_accuracy: 0.7917 - 687ms/epoch - 76ms/step
# Epoch 47/300
#
# Epoch 47: val_loss did not improve from 0.55247
# 9/9 - 1s - loss: 0.0635 - accuracy: 1.0000 - val_loss: 0.5693 - val_accuracy: 0.7778 - 761ms/epoch - 85ms/step
# Epoch 48/300
#
# Epoch 48: val_loss did not improve from 0.55247
# 9/9 - 1s - loss: 0.0461 - accuracy: 1.0000 - val_loss: 0.5543 - val_accuracy: 0.7639 - 1s/epoch - 153ms/step
# Epoch 49/300
#
# Epoch 49: val_loss improved from 0.55247 to 0.54960, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.0474 - accuracy: 1.0000 - val_loss: 0.5496 - val_accuracy: 0.8056 - 1s/epoch - 133ms/step
# Epoch 50/300
#
# Epoch 50: val_loss improved from 0.54960 to 0.52332, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.0452 - accuracy: 1.0000 - val_loss: 0.5233 - val_accuracy: 0.7917 - 759ms/epoch - 84ms/step
# Epoch 51/300
#
# Epoch 51: val_loss improved from 0.52332 to 0.52208, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.0455 - accuracy: 1.0000 - val_loss: 0.5221 - val_accuracy: 0.7917 - 730ms/epoch - 81ms/step
# Epoch 52/300
#
# Epoch 52: val_loss improved from 0.52208 to 0.52065, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.0429 - accuracy: 1.0000 - val_loss: 0.5206 - val_accuracy: 0.7917 - 704ms/epoch - 78ms/step
# Epoch 53/300
#
# Epoch 53: val_loss improved from 0.52065 to 0.49013, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.0451 - accuracy: 1.0000 - val_loss: 0.4901 - val_accuracy: 0.8194 - 767ms/epoch - 85ms/step
# Epoch 54/300
#
# Epoch 54: val_loss did not improve from 0.49013
# 9/9 - 1s - loss: 0.0456 - accuracy: 1.0000 - val_loss: 0.5033 - val_accuracy: 0.8194 - 693ms/epoch - 77ms/step
# Epoch 55/300
#
# Epoch 55: val_loss did not improve from 0.49013
# 9/9 - 1s - loss: 0.0412 - accuracy: 1.0000 - val_loss: 0.5334 - val_accuracy: 0.7778 - 714ms/epoch - 79ms/step
# Epoch 56/300
#
# Epoch 56: val_loss did not improve from 0.49013
# 9/9 - 1s - loss: 0.0350 - accuracy: 1.0000 - val_loss: 0.5498 - val_accuracy: 0.7639 - 687ms/epoch - 76ms/step
# Epoch 57/300
#
# Epoch 57: val_loss did not improve from 0.49013
# 9/9 - 1s - loss: 0.0378 - accuracy: 1.0000 - val_loss: 0.5074 - val_accuracy: 0.7778 - 709ms/epoch - 79ms/step
# Epoch 58/300
#
# Epoch 58: val_loss did not improve from 0.49013
# 9/9 - 1s - loss: 0.0354 - accuracy: 1.0000 - val_loss: 0.5152 - val_accuracy: 0.7778 - 703ms/epoch - 78ms/step
# Epoch 59/300
#
# Epoch 59: val_loss did not improve from 0.49013
# 9/9 - 1s - loss: 0.0391 - accuracy: 1.0000 - val_loss: 0.5264 - val_accuracy: 0.7778 - 730ms/epoch - 81ms/step
# Epoch 60/300
#
# Epoch 60: val_loss did not improve from 0.49013
# 9/9 - 1s - loss: 0.0270 - accuracy: 1.0000 - val_loss: 0.5422 - val_accuracy: 0.7639 - 698ms/epoch - 78ms/step
# Epoch 61/300
#
# Epoch 61: val_loss did not improve from 0.49013
# 9/9 - 1s - loss: 0.0335 - accuracy: 1.0000 - val_loss: 0.5009 - val_accuracy: 0.7917 - 707ms/epoch - 79ms/step
# Epoch 62/300
#
# Epoch 62: val_loss did not improve from 0.49013
# 9/9 - 1s - loss: 0.0297 - accuracy: 1.0000 - val_loss: 0.4999 - val_accuracy: 0.7639 - 675ms/epoch - 75ms/step
# Epoch 63/300
#
# Epoch 63: val_loss did not improve from 0.49013
# 9/9 - 1s - loss: 0.0270 - accuracy: 1.0000 - val_loss: 0.5051 - val_accuracy: 0.8056 - 829ms/epoch - 92ms/step
# Epoch 64/300
#
# Epoch 64: val_loss did not improve from 0.49013
# 9/9 - 1s - loss: 0.0289 - accuracy: 1.0000 - val_loss: 0.5079 - val_accuracy: 0.7917 - 1s/epoch - 154ms/step
# Epoch 65/300
#
# Epoch 65: val_loss did not improve from 0.49013
# 9/9 - 1s - loss: 0.0276 - accuracy: 1.0000 - val_loss: 0.5134 - val_accuracy: 0.8056 - 1s/epoch - 127ms/step
# Epoch 66/300
#
# Epoch 66: val_loss did not improve from 0.49013
# 9/9 - 1s - loss: 0.0310 - accuracy: 1.0000 - val_loss: 0.4983 - val_accuracy: 0.7778 - 701ms/epoch - 78ms/step
# Epoch 67/300
#
# Epoch 67: val_loss did not improve from 0.49013
# 9/9 - 1s - loss: 0.0256 - accuracy: 1.0000 - val_loss: 0.5360 - val_accuracy: 0.7639 - 739ms/epoch - 82ms/step
# Epoch 68/300
#
# Epoch 68: val_loss did not improve from 0.49013
# 9/9 - 1s - loss: 0.0291 - accuracy: 1.0000 - val_loss: 0.4907 - val_accuracy: 0.7917 - 704ms/epoch - 78ms/step
# Epoch 69/300
#
# Epoch 69: val_loss did not improve from 0.49013
# 9/9 - 1s - loss: 0.0268 - accuracy: 1.0000 - val_loss: 0.5207 - val_accuracy: 0.7917 - 673ms/epoch - 75ms/step
# Epoch 70/300
#
# Epoch 70: val_loss improved from 0.49013 to 0.46999, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.0250 - accuracy: 1.0000 - val_loss: 0.4700 - val_accuracy: 0.7917 - 792ms/epoch - 88ms/step
# Epoch 71/300
#
# Epoch 71: val_loss improved from 0.46999 to 0.46861, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.0227 - accuracy: 1.0000 - val_loss: 0.4686 - val_accuracy: 0.7917 - 735ms/epoch - 82ms/step
# Epoch 72/300
#
# Epoch 72: val_loss did not improve from 0.46861
# 9/9 - 1s - loss: 0.0202 - accuracy: 1.0000 - val_loss: 0.5159 - val_accuracy: 0.8056 - 700ms/epoch - 78ms/step
# Epoch 73/300
#
# Epoch 73: val_loss did not improve from 0.46861
# 9/9 - 1s - loss: 0.0238 - accuracy: 1.0000 - val_loss: 0.4853 - val_accuracy: 0.8194 - 733ms/epoch - 81ms/step
# Epoch 74/300
#
# Epoch 74: val_loss did not improve from 0.46861
# 9/9 - 1s - loss: 0.0249 - accuracy: 1.0000 - val_loss: 0.4724 - val_accuracy: 0.8056 - 706ms/epoch - 78ms/step
# Epoch 75/300
#
# Epoch 75: val_loss did not improve from 0.46861
# 9/9 - 1s - loss: 0.0226 - accuracy: 1.0000 - val_loss: 0.5195 - val_accuracy: 0.7639 - 768ms/epoch - 85ms/step
# Epoch 76/300
#
# Epoch 76: val_loss did not improve from 0.46861
# 9/9 - 1s - loss: 0.0202 - accuracy: 1.0000 - val_loss: 0.4802 - val_accuracy: 0.8056 - 674ms/epoch - 75ms/step
# Epoch 77/300
#
# Epoch 77: val_loss did not improve from 0.46861
# 9/9 - 1s - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.4878 - val_accuracy: 0.8056 - 735ms/epoch - 82ms/step
# Epoch 78/300
#
# Epoch 78: val_loss did not improve from 0.46861
# 9/9 - 1s - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.4928 - val_accuracy: 0.7917 - 690ms/epoch - 77ms/step
# Epoch 79/300
#
# Epoch 79: val_loss did not improve from 0.46861
# 9/9 - 1s - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.4899 - val_accuracy: 0.8056 - 847ms/epoch - 94ms/step
# Epoch 80/300
#
# Epoch 80: val_loss did not improve from 0.46861
# 9/9 - 1s - loss: 0.0183 - accuracy: 1.0000 - val_loss: 0.5014 - val_accuracy: 0.8056 - 1s/epoch - 152ms/step
# Epoch 81/300
#
# Epoch 81: val_loss did not improve from 0.46861
# 9/9 - 1s - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.4825 - val_accuracy: 0.7778 - 1s/epoch - 117ms/step
# Epoch 82/300
#
# Epoch 82: val_loss did not improve from 0.46861
# 9/9 - 1s - loss: 0.0211 - accuracy: 1.0000 - val_loss: 0.5332 - val_accuracy: 0.7639 - 712ms/epoch - 79ms/step
# Epoch 83/300
#
# Epoch 83: val_loss did not improve from 0.46861
# 9/9 - 1s - loss: 0.0208 - accuracy: 1.0000 - val_loss: 0.5249 - val_accuracy: 0.7778 - 702ms/epoch - 78ms/step
# Epoch 84/300
#
# Epoch 84: val_loss did not improve from 0.46861
# 9/9 - 1s - loss: 0.0195 - accuracy: 1.0000 - val_loss: 0.5087 - val_accuracy: 0.7639 - 715ms/epoch - 79ms/step
# Epoch 85/300
#
# Epoch 85: val_loss did not improve from 0.46861
# 9/9 - 1s - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.5011 - val_accuracy: 0.8056 - 700ms/epoch - 78ms/step
# Epoch 86/300
#
# Epoch 86: val_loss did not improve from 0.46861
# 9/9 - 1s - loss: 0.0201 - accuracy: 1.0000 - val_loss: 0.4790 - val_accuracy: 0.8194 - 684ms/epoch - 76ms/step
# Epoch 87/300
#
# Epoch 87: val_loss did not improve from 0.46861
# 9/9 - 1s - loss: 0.0214 - accuracy: 1.0000 - val_loss: 0.5128 - val_accuracy: 0.7639 - 680ms/epoch - 76ms/step
# Epoch 88/300
#
# Epoch 88: val_loss did not improve from 0.46861
# 9/9 - 1s - loss: 0.0191 - accuracy: 1.0000 - val_loss: 0.5179 - val_accuracy: 0.7778 - 669ms/epoch - 74ms/step
# Epoch 89/300
#
# Epoch 89: val_loss improved from 0.46861 to 0.46808, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.0211 - accuracy: 1.0000 - val_loss: 0.4681 - val_accuracy: 0.8056 - 714ms/epoch - 79ms/step
# Epoch 90/300
#
# Epoch 90: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0180 - accuracy: 1.0000 - val_loss: 0.4908 - val_accuracy: 0.7778 - 736ms/epoch - 82ms/step
# Epoch 91/300
#
# Epoch 91: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.4704 - val_accuracy: 0.8194 - 662ms/epoch - 74ms/step
# Epoch 92/300
#
# Epoch 92: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.5010 - val_accuracy: 0.8056 - 724ms/epoch - 80ms/step
# Epoch 93/300
#
# Epoch 93: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.4721 - val_accuracy: 0.8056 - 682ms/epoch - 76ms/step
# Epoch 94/300
#
# Epoch 94: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.5272 - val_accuracy: 0.7778 - 681ms/epoch - 76ms/step
# Epoch 95/300
#
# Epoch 95: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0203 - accuracy: 1.0000 - val_loss: 0.5031 - val_accuracy: 0.7917 - 680ms/epoch - 76ms/step
# Epoch 96/300
#
# Epoch 96: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.4780 - val_accuracy: 0.8056 - 1s/epoch - 141ms/step
# Epoch 97/300
#
# Epoch 97: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.5276 - val_accuracy: 0.7778 - 1s/epoch - 129ms/step
# Epoch 98/300
#
# Epoch 98: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.4715 - val_accuracy: 0.8194 - 766ms/epoch - 85ms/step
# Epoch 99/300
#
# Epoch 99: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.4699 - val_accuracy: 0.8056 - 691ms/epoch - 77ms/step
# Epoch 100/300
#
# Epoch 100: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.5184 - val_accuracy: 0.7917 - 684ms/epoch - 76ms/step
# Epoch 101/300
#
# Epoch 101: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.4789 - val_accuracy: 0.7778 - 694ms/epoch - 77ms/step
# Epoch 102/300
#
# Epoch 102: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.5758 - val_accuracy: 0.7639 - 686ms/epoch - 76ms/step
# Epoch 103/300
#
# Epoch 103: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0268 - accuracy: 1.0000 - val_loss: 0.5916 - val_accuracy: 0.7361 - 655ms/epoch - 73ms/step
# Epoch 104/300
#
# Epoch 104: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0237 - accuracy: 1.0000 - val_loss: 0.5480 - val_accuracy: 0.7083 - 676ms/epoch - 75ms/step
# Epoch 105/300
#
# Epoch 105: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.5476 - val_accuracy: 0.7361 - 679ms/epoch - 75ms/step
# Epoch 106/300
#
# Epoch 106: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.5295 - val_accuracy: 0.7639 - 667ms/epoch - 74ms/step
# Epoch 107/300
#
# Epoch 107: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.5361 - val_accuracy: 0.7639 - 674ms/epoch - 75ms/step
# Epoch 108/300
#
# Epoch 108: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.5217 - val_accuracy: 0.7639 - 688ms/epoch - 76ms/step
# Epoch 109/300
#
# Epoch 109: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.5051 - val_accuracy: 0.7917 - 675ms/epoch - 75ms/step
# Epoch 110/300
#
# Epoch 110: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.4959 - val_accuracy: 0.7917 - 700ms/epoch - 78ms/step
# Epoch 111/300
#
# Epoch 111: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.4934 - val_accuracy: 0.7639 - 683ms/epoch - 76ms/step
# Epoch 112/300
#
# Epoch 112: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.5065 - val_accuracy: 0.8056 - 912ms/epoch - 101ms/step
# Epoch 113/300
#
# Epoch 113: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.5073 - val_accuracy: 0.7917 - 1s/epoch - 128ms/step
# Epoch 114/300
#
# Epoch 114: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.4744 - val_accuracy: 0.7778 - 1s/epoch - 120ms/step
# Epoch 115/300
#
# Epoch 115: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.4923 - val_accuracy: 0.7778 - 662ms/epoch - 74ms/step
# Epoch 116/300
#
# Epoch 116: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.5024 - val_accuracy: 0.8194 - 668ms/epoch - 74ms/step
# Epoch 117/300
#
# Epoch 117: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.4925 - val_accuracy: 0.8056 - 673ms/epoch - 75ms/step
# Epoch 118/300
#
# Epoch 118: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.4926 - val_accuracy: 0.7917 - 695ms/epoch - 77ms/step
# Epoch 119/300
#
# Epoch 119: val_loss did not improve from 0.46808
# 9/9 - 1s - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.4905 - val_accuracy: 0.7917 - 672ms/epoch - 75ms/step
# Epoch 120/300
#
# Epoch 120: val_loss improved from 0.46808 to 0.45580, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.4558 - val_accuracy: 0.8056 - 715ms/epoch - 79ms/step
# Epoch 121/300
#
# Epoch 121: val_loss did not improve from 0.45580
# 9/9 - 1s - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.4885 - val_accuracy: 0.7778 - 690ms/epoch - 77ms/step
# Epoch 122/300
#
# Epoch 122: val_loss did not improve from 0.45580
# 9/9 - 1s - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.4867 - val_accuracy: 0.8056 - 687ms/epoch - 76ms/step
# Epoch 123/300
#
# Epoch 123: val_loss did not improve from 0.45580
# 9/9 - 1s - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.5014 - val_accuracy: 0.7917 - 682ms/epoch - 76ms/step
# Epoch 124/300
#
# Epoch 124: val_loss did not improve from 0.45580
# 9/9 - 1s - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.5095 - val_accuracy: 0.7639 - 684ms/epoch - 76ms/step
# Epoch 125/300
#
# Epoch 125: val_loss did not improve from 0.45580
# 9/9 - 1s - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.4731 - val_accuracy: 0.7778 - 684ms/epoch - 76ms/step
# Epoch 126/300
#
# Epoch 126: val_loss did not improve from 0.45580
# 9/9 - 1s - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.5135 - val_accuracy: 0.7917 - 646ms/epoch - 72ms/step
# Epoch 127/300
#
# Epoch 127: val_loss did not improve from 0.45580
# 9/9 - 1s - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.4604 - val_accuracy: 0.8056 - 681ms/epoch - 76ms/step
# Epoch 128/300
#
# Epoch 128: val_loss did not improve from 0.45580
# 9/9 - 1s - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.4944 - val_accuracy: 0.8056 - 674ms/epoch - 75ms/step
# Epoch 129/300
#
# Epoch 129: val_loss did not improve from 0.45580
# 9/9 - 1s - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.5106 - val_accuracy: 0.8056 - 1s/epoch - 112ms/step
# Epoch 130/300
#
# Epoch 130: val_loss did not improve from 0.45580
# 9/9 - 1s - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.4859 - val_accuracy: 0.7917 - 1s/epoch - 130ms/step
# Epoch 131/300
#
# Epoch 131: val_loss did not improve from 0.45580
# 9/9 - 1s - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.4988 - val_accuracy: 0.7917 - 1s/epoch - 118ms/step
# Epoch 132/300
#
# Epoch 132: val_loss did not improve from 0.45580
# 9/9 - 1s - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.4972 - val_accuracy: 0.8194 - 660ms/epoch - 73ms/step
# Epoch 133/300
#
# Epoch 133: val_loss did not improve from 0.45580
# 9/9 - 1s - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.5254 - val_accuracy: 0.7917 - 700ms/epoch - 78ms/step
# Epoch 134/300
#
# Epoch 134: val_loss did not improve from 0.45580
# 9/9 - 1s - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.5357 - val_accuracy: 0.7917 - 679ms/epoch - 75ms/step
# Epoch 135/300
#
# Epoch 135: val_loss did not improve from 0.45580
# 9/9 - 1s - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.5196 - val_accuracy: 0.7917 - 658ms/epoch - 73ms/step
# Epoch 136/300
#
# Epoch 136: val_loss did not improve from 0.45580
# 9/9 - 1s - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.4946 - val_accuracy: 0.7639 - 695ms/epoch - 77ms/step
# Epoch 137/300
#
# Epoch 137: val_loss did not improve from 0.45580
# 9/9 - 1s - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.4873 - val_accuracy: 0.8056 - 708ms/epoch - 79ms/step
# Epoch 138/300
#
# Epoch 138: val_loss did not improve from 0.45580
# 9/9 - 1s - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.4840 - val_accuracy: 0.8056 - 665ms/epoch - 74ms/step
# Epoch 139/300
#
# Epoch 139: val_loss did not improve from 0.45580
# 9/9 - 1s - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.4889 - val_accuracy: 0.7917 - 691ms/epoch - 77ms/step
# Epoch 140/300
#
# Epoch 140: val_loss did not improve from 0.45580
# 9/9 - 1s - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.4891 - val_accuracy: 0.8194 - 687ms/epoch - 76ms/step
# Epoch 141/300
#
# Epoch 141: val_loss did not improve from 0.45580
# 9/9 - 1s - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.4953 - val_accuracy: 0.7917 - 676ms/epoch - 75ms/step
# Epoch 142/300
#
# Epoch 142: val_loss did not improve from 0.45580
# 9/9 - 1s - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.4677 - val_accuracy: 0.8056 - 678ms/epoch - 75ms/step
# Epoch 143/300
#
# Epoch 143: val_loss did not improve from 0.45580
# 9/9 - 1s - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.4772 - val_accuracy: 0.7917 - 681ms/epoch - 76ms/step
# Epoch 144/300
#
# Epoch 144: val_loss did not improve from 0.45580
# 9/9 - 1s - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.4644 - val_accuracy: 0.8056 - 667ms/epoch - 74ms/step
# Epoch 145/300
#
# Epoch 145: val_loss did not improve from 0.45580
# 9/9 - 1s - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.4918 - val_accuracy: 0.8056 - 675ms/epoch - 75ms/step
# Epoch 146/300
#
# Epoch 146: val_loss improved from 0.45580 to 0.44387, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.4439 - val_accuracy: 0.7917 - 1s/epoch - 134ms/step
# Epoch 147/300
#
# Epoch 147: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.4675 - val_accuracy: 0.8056 - 1s/epoch - 127ms/step
# Epoch 148/300
#
# Epoch 148: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.4600 - val_accuracy: 0.7917 - 835ms/epoch - 93ms/step
# Epoch 149/300
#
# Epoch 149: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.4573 - val_accuracy: 0.8056 - 695ms/epoch - 77ms/step
# Epoch 150/300
#
# Epoch 150: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.4932 - val_accuracy: 0.7778 - 674ms/epoch - 75ms/step
# Epoch 151/300
#
# Epoch 151: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.4601 - val_accuracy: 0.7917 - 678ms/epoch - 75ms/step
# Epoch 152/300
#
# Epoch 152: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.5058 - val_accuracy: 0.7917 - 721ms/epoch - 80ms/step
# Epoch 153/300
#
# Epoch 153: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.5013 - val_accuracy: 0.7639 - 678ms/epoch - 75ms/step
# Epoch 154/300
#
# Epoch 154: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.4837 - val_accuracy: 0.7917 - 672ms/epoch - 75ms/step
# Epoch 155/300
#
# Epoch 155: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.5006 - val_accuracy: 0.7917 - 722ms/epoch - 80ms/step
# Epoch 156/300
#
# Epoch 156: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.4922 - val_accuracy: 0.7778 - 655ms/epoch - 73ms/step
# Epoch 157/300
#
# Epoch 157: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.4891 - val_accuracy: 0.7917 - 678ms/epoch - 75ms/step
# Epoch 158/300
#
# Epoch 158: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.5223 - val_accuracy: 0.7917 - 721ms/epoch - 80ms/step
# Epoch 159/300
#
# Epoch 159: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.4812 - val_accuracy: 0.7917 - 661ms/epoch - 73ms/step
# Epoch 160/300
#
# Epoch 160: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.4968 - val_accuracy: 0.7917 - 676ms/epoch - 75ms/step
# Epoch 161/300
#
# Epoch 161: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.4703 - val_accuracy: 0.8056 - 668ms/epoch - 74ms/step
# Epoch 162/300
#
# Epoch 162: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.4729 - val_accuracy: 0.8056 - 728ms/epoch - 81ms/step
# Epoch 163/300
#
# Epoch 163: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.4859 - val_accuracy: 0.7917 - 1s/epoch - 145ms/step
# Epoch 164/300
#
# Epoch 164: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.4874 - val_accuracy: 0.7917 - 1s/epoch - 123ms/step
# Epoch 165/300
#
# Epoch 165: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.5032 - val_accuracy: 0.7917 - 667ms/epoch - 74ms/step
# Epoch 166/300
#
# Epoch 166: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.5218 - val_accuracy: 0.7778 - 669ms/epoch - 74ms/step
# Epoch 167/300
#
# Epoch 167: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.4602 - val_accuracy: 0.7778 - 692ms/epoch - 77ms/step
# Epoch 168/300
#
# Epoch 168: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.4556 - val_accuracy: 0.8056 - 682ms/epoch - 76ms/step
# Epoch 169/300
#
# Epoch 169: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.4964 - val_accuracy: 0.7917 - 674ms/epoch - 75ms/step
# Epoch 170/300
#
# Epoch 170: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.4893 - val_accuracy: 0.7917 - 666ms/epoch - 74ms/step
# Epoch 171/300
#
# Epoch 171: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.5015 - val_accuracy: 0.7917 - 668ms/epoch - 74ms/step
# Epoch 172/300
#
# Epoch 172: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.4751 - val_accuracy: 0.8056 - 707ms/epoch - 79ms/step
# Epoch 173/300
#
# Epoch 173: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.4812 - val_accuracy: 0.7778 - 668ms/epoch - 74ms/step
# Epoch 174/300
#
# Epoch 174: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.4906 - val_accuracy: 0.7778 - 697ms/epoch - 77ms/step
# Epoch 175/300
#
# Epoch 175: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.4791 - val_accuracy: 0.7778 - 679ms/epoch - 75ms/step
# Epoch 176/300
#
# Epoch 176: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.5136 - val_accuracy: 0.7778 - 661ms/epoch - 73ms/step
# Epoch 177/300
#
# Epoch 177: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.4801 - val_accuracy: 0.7778 - 706ms/epoch - 78ms/step
# Epoch 178/300
#
# Epoch 178: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.5389 - val_accuracy: 0.7639 - 685ms/epoch - 76ms/step
# Epoch 179/300
#
# Epoch 179: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.5543 - val_accuracy: 0.7917 - 861ms/epoch - 96ms/step
# Epoch 180/300
#
# Epoch 180: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.4853 - val_accuracy: 0.7917 - 1s/epoch - 125ms/step
# Epoch 181/300
#
# Epoch 181: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.5437 - val_accuracy: 0.7778 - 1s/epoch - 127ms/step
# Epoch 182/300
#
# Epoch 182: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.4853 - val_accuracy: 0.7917 - 658ms/epoch - 73ms/step
# Epoch 183/300
#
# Epoch 183: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.4785 - val_accuracy: 0.7917 - 673ms/epoch - 75ms/step
# Epoch 184/300
#
# Epoch 184: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.5199 - val_accuracy: 0.7917 - 665ms/epoch - 74ms/step
# Epoch 185/300
#
# Epoch 185: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.4576 - val_accuracy: 0.8194 - 704ms/epoch - 78ms/step
# Epoch 186/300
#
# Epoch 186: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.4598 - val_accuracy: 0.8056 - 673ms/epoch - 75ms/step
# Epoch 187/300
#
# Epoch 187: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.4661 - val_accuracy: 0.8056 - 666ms/epoch - 74ms/step
# Epoch 188/300
#
# Epoch 188: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.5011 - val_accuracy: 0.7639 - 683ms/epoch - 76ms/step
# Epoch 189/300
#
# Epoch 189: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.4678 - val_accuracy: 0.7917 - 678ms/epoch - 75ms/step
# Epoch 190/300
#
# Epoch 190: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.4583 - val_accuracy: 0.8056 - 670ms/epoch - 74ms/step
# Epoch 191/300
#
# Epoch 191: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.4618 - val_accuracy: 0.8056 - 684ms/epoch - 76ms/step
# Epoch 192/300
#
# Epoch 192: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.4508 - val_accuracy: 0.7917 - 687ms/epoch - 76ms/step
# Epoch 193/300
#
# Epoch 193: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.4626 - val_accuracy: 0.8194 - 671ms/epoch - 75ms/step
# Epoch 194/300
#
# Epoch 194: val_loss did not improve from 0.44387
# 9/9 - 1s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.4933 - val_accuracy: 0.8056 - 676ms/epoch - 75ms/step
# Epoch 195/300
#
# Epoch 195: val_loss improved from 0.44387 to 0.43956, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.4396 - val_accuracy: 0.8194 - 761ms/epoch - 85ms/step
# Epoch 196/300
#
# Epoch 196: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4865 - val_accuracy: 0.7917 - 990ms/epoch - 110ms/step
# Epoch 197/300
#
# Epoch 197: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.5284 - val_accuracy: 0.7778 - 1s/epoch - 128ms/step
# Epoch 198/300
#
# Epoch 198: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.4657 - val_accuracy: 0.8056 - 994ms/epoch - 110ms/step
# Epoch 199/300
#
# Epoch 199: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.4870 - val_accuracy: 0.7917 - 667ms/epoch - 74ms/step
# Epoch 200/300
#
# Epoch 200: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.4820 - val_accuracy: 0.8056 - 685ms/epoch - 76ms/step
# Epoch 201/300
#
# Epoch 201: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.4814 - val_accuracy: 0.7917 - 686ms/epoch - 76ms/step
# Epoch 202/300
#
# Epoch 202: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.4453 - val_accuracy: 0.8056 - 661ms/epoch - 73ms/step
# Epoch 203/300
#
# Epoch 203: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.4814 - val_accuracy: 0.7917 - 689ms/epoch - 77ms/step
# Epoch 204/300
#
# Epoch 204: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.4784 - val_accuracy: 0.7778 - 688ms/epoch - 76ms/step
# Epoch 205/300
#
# Epoch 205: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.4542 - val_accuracy: 0.7778 - 668ms/epoch - 74ms/step
# Epoch 206/300
#
# Epoch 206: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.4959 - val_accuracy: 0.7917 - 670ms/epoch - 74ms/step
# Epoch 207/300
#
# Epoch 207: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.4631 - val_accuracy: 0.7917 - 676ms/epoch - 75ms/step
# Epoch 208/300
#
# Epoch 208: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.4638 - val_accuracy: 0.8194 - 647ms/epoch - 72ms/step
# Epoch 209/300
#
# Epoch 209: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.4769 - val_accuracy: 0.7778 - 681ms/epoch - 76ms/step
# Epoch 210/300
#
# Epoch 210: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.4604 - val_accuracy: 0.8056 - 653ms/epoch - 73ms/step
# Epoch 211/300
#
# Epoch 211: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4692 - val_accuracy: 0.8194 - 667ms/epoch - 74ms/step
# Epoch 212/300
#
# Epoch 212: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.4500 - val_accuracy: 0.7917 - 673ms/epoch - 75ms/step
# Epoch 213/300
#
# Epoch 213: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.4957 - val_accuracy: 0.7917 - 1s/epoch - 116ms/step
# Epoch 214/300
#
# Epoch 214: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.4734 - val_accuracy: 0.7917 - 1s/epoch - 128ms/step
# Epoch 215/300
#
# Epoch 215: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.4569 - val_accuracy: 0.7917 - 985ms/epoch - 109ms/step
# Epoch 216/300
#
# Epoch 216: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.4643 - val_accuracy: 0.7917 - 665ms/epoch - 74ms/step
# Epoch 217/300
#
# Epoch 217: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.4688 - val_accuracy: 0.7917 - 706ms/epoch - 78ms/step
# Epoch 218/300
#
# Epoch 218: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.5166 - val_accuracy: 0.7917 - 669ms/epoch - 74ms/step
# Epoch 219/300
#
# Epoch 219: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4790 - val_accuracy: 0.7917 - 666ms/epoch - 74ms/step
# Epoch 220/300
#
# Epoch 220: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.4462 - val_accuracy: 0.8056 - 694ms/epoch - 77ms/step
# Epoch 221/300
#
# Epoch 221: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.5062 - val_accuracy: 0.7917 - 704ms/epoch - 78ms/step
# Epoch 222/300
#
# Epoch 222: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.4880 - val_accuracy: 0.8056 - 660ms/epoch - 73ms/step
# Epoch 223/300
#
# Epoch 223: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.5018 - val_accuracy: 0.7778 - 682ms/epoch - 76ms/step
# Epoch 224/300
#
# Epoch 224: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.4607 - val_accuracy: 0.8194 - 690ms/epoch - 77ms/step
# Epoch 225/300
#
# Epoch 225: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.4500 - val_accuracy: 0.8056 - 663ms/epoch - 74ms/step
# Epoch 226/300
#
# Epoch 226: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.4784 - val_accuracy: 0.8056 - 686ms/epoch - 76ms/step
# Epoch 227/300
#
# Epoch 227: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.4940 - val_accuracy: 0.8056 - 690ms/epoch - 77ms/step
# Epoch 228/300
#
# Epoch 228: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.5209 - val_accuracy: 0.7917 - 670ms/epoch - 74ms/step
# Epoch 229/300
#
# Epoch 229: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.4563 - val_accuracy: 0.8056 - 686ms/epoch - 76ms/step
# Epoch 230/300
#
# Epoch 230: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.4555 - val_accuracy: 0.8056 - 1s/epoch - 128ms/step
# Epoch 231/300
#
# Epoch 231: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.4583 - val_accuracy: 0.7917 - 1s/epoch - 123ms/step
# Epoch 232/300
#
# Epoch 232: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4731 - val_accuracy: 0.8194 - 957ms/epoch - 106ms/step
# Epoch 233/300
#
# Epoch 233: val_loss did not improve from 0.43956
# 9/9 - 1s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4719 - val_accuracy: 0.8194 - 723ms/epoch - 80ms/step
# Epoch 234/300
#
# Epoch 234: val_loss improved from 0.43956 to 0.43875, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.4388 - val_accuracy: 0.8472 - 677ms/epoch - 75ms/step
# Epoch 235/300
#
# Epoch 235: val_loss did not improve from 0.43875
# 9/9 - 1s - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.4872 - val_accuracy: 0.7778 - 671ms/epoch - 75ms/step
# Epoch 236/300
#
# Epoch 236: val_loss did not improve from 0.43875
# 9/9 - 1s - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.7124 - val_accuracy: 0.7500 - 684ms/epoch - 76ms/step
# Epoch 237/300
#
# Epoch 237: val_loss did not improve from 0.43875
# 9/9 - 1s - loss: 0.1321 - accuracy: 0.9792 - val_loss: 0.9798 - val_accuracy: 0.6111 - 673ms/epoch - 75ms/step
# Epoch 238/300
#
# Epoch 238: val_loss did not improve from 0.43875
# 9/9 - 1s - loss: 0.2503 - accuracy: 0.9792 - val_loss: 0.8997 - val_accuracy: 0.6111 - 679ms/epoch - 75ms/step
# Epoch 239/300
#
# Epoch 239: val_loss did not improve from 0.43875
# 9/9 - 1s - loss: 0.2018 - accuracy: 0.9931 - val_loss: 0.7155 - val_accuracy: 0.7222 - 682ms/epoch - 76ms/step
# Epoch 240/300
#
# Epoch 240: val_loss did not improve from 0.43875
# 9/9 - 1s - loss: 0.1283 - accuracy: 0.9792 - val_loss: 0.7127 - val_accuracy: 0.7222 - 671ms/epoch - 75ms/step
# Epoch 241/300
#
# Epoch 241: val_loss did not improve from 0.43875
# 9/9 - 1s - loss: 0.1815 - accuracy: 0.9514 - val_loss: 0.7480 - val_accuracy: 0.6944 - 680ms/epoch - 76ms/step
# Epoch 242/300
#
# Epoch 242: val_loss did not improve from 0.43875
# 9/9 - 1s - loss: 0.1682 - accuracy: 0.9653 - val_loss: 0.7850 - val_accuracy: 0.6806 - 665ms/epoch - 74ms/step
# Epoch 243/300
#
# Epoch 243: val_loss did not improve from 0.43875
# 9/9 - 1s - loss: 0.1569 - accuracy: 0.9792 - val_loss: 0.9038 - val_accuracy: 0.6111 - 682ms/epoch - 76ms/step
# Epoch 244/300
#
# Epoch 244: val_loss did not improve from 0.43875
# 9/9 - 1s - loss: 0.1164 - accuracy: 0.9931 - val_loss: 0.6983 - val_accuracy: 0.6944 - 682ms/epoch - 76ms/step
# Epoch 245/300
#
# Epoch 245: val_loss did not improve from 0.43875
# 9/9 - 1s - loss: 0.0997 - accuracy: 0.9931 - val_loss: 0.7990 - val_accuracy: 0.6111 - 743ms/epoch - 83ms/step
# Epoch 246/300
#
# Epoch 246: val_loss did not improve from 0.43875
# 9/9 - 1s - loss: 0.0703 - accuracy: 1.0000 - val_loss: 0.8333 - val_accuracy: 0.6528 - 672ms/epoch - 75ms/step
# Epoch 247/300
#
# Epoch 247: val_loss did not improve from 0.43875
# 9/9 - 1s - loss: 0.0488 - accuracy: 1.0000 - val_loss: 0.6259 - val_accuracy: 0.7222 - 1s/epoch - 116ms/step
# Epoch 248/300
#
# Epoch 248: val_loss did not improve from 0.43875
# 9/9 - 1s - loss: 0.0500 - accuracy: 1.0000 - val_loss: 0.5943 - val_accuracy: 0.7778 - 1s/epoch - 122ms/step
# Epoch 249/300
#
# Epoch 249: val_loss did not improve from 0.43875
# 9/9 - 1s - loss: 0.0378 - accuracy: 1.0000 - val_loss: 0.5099 - val_accuracy: 0.7917 - 946ms/epoch - 105ms/step
# Epoch 250/300
#
# Epoch 250: val_loss did not improve from 0.43875
# 9/9 - 1s - loss: 0.0291 - accuracy: 1.0000 - val_loss: 0.5010 - val_accuracy: 0.8056 - 681ms/epoch - 76ms/step
# Epoch 251/300
#
# Epoch 251: val_loss did not improve from 0.43875
# 9/9 - 1s - loss: 0.0234 - accuracy: 1.0000 - val_loss: 0.4449 - val_accuracy: 0.8056 - 728ms/epoch - 81ms/step
# Epoch 252/300
#
# Epoch 252: val_loss improved from 0.43875 to 0.43470, saving model to ./tmp/checkpoint.h5
# 9/9 - 1s - loss: 0.0243 - accuracy: 1.0000 - val_loss: 0.4347 - val_accuracy: 0.8333 - 751ms/epoch - 83ms/step
# Epoch 253/300
#
# Epoch 253: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0207 - accuracy: 1.0000 - val_loss: 0.4376 - val_accuracy: 0.8333 - 685ms/epoch - 76ms/step
# Epoch 254/300
#
# Epoch 254: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.5183 - val_accuracy: 0.7917 - 656ms/epoch - 73ms/step
# Epoch 255/300
#
# Epoch 255: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.4828 - val_accuracy: 0.7917 - 671ms/epoch - 75ms/step
# Epoch 256/300
#
# Epoch 256: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.4918 - val_accuracy: 0.7778 - 683ms/epoch - 76ms/step
# Epoch 257/300
#
# Epoch 257: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.4992 - val_accuracy: 0.7778 - 669ms/epoch - 74ms/step
# Epoch 258/300
#
# Epoch 258: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.4643 - val_accuracy: 0.7778 - 689ms/epoch - 77ms/step
# Epoch 259/300
#
# Epoch 259: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.4378 - val_accuracy: 0.7917 - 704ms/epoch - 78ms/step
# Epoch 260/300
#
# Epoch 260: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.4606 - val_accuracy: 0.7917 - 662ms/epoch - 74ms/step
# Epoch 261/300
#
# Epoch 261: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.4709 - val_accuracy: 0.7917 - 698ms/epoch - 78ms/step
# Epoch 262/300
#
# Epoch 262: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.4652 - val_accuracy: 0.7917 - 695ms/epoch - 77ms/step
# Epoch 263/300
#
# Epoch 263: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.4780 - val_accuracy: 0.7917 - 657ms/epoch - 73ms/step
# Epoch 264/300
#
# Epoch 264: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.4568 - val_accuracy: 0.7917 - 1s/epoch - 141ms/step
# Epoch 265/300
#
# Epoch 265: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.4724 - val_accuracy: 0.7917 - 1s/epoch - 125ms/step
# Epoch 266/300
#
# Epoch 266: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.4789 - val_accuracy: 0.7917 - 808ms/epoch - 90ms/step
# Epoch 267/300
#
# Epoch 267: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.4486 - val_accuracy: 0.7917 - 671ms/epoch - 75ms/step
# Epoch 268/300
#
# Epoch 268: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.4744 - val_accuracy: 0.7917 - 676ms/epoch - 75ms/step
# Epoch 269/300
#
# Epoch 269: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.4741 - val_accuracy: 0.7917 - 665ms/epoch - 74ms/step
# Epoch 270/300
#
# Epoch 270: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.4617 - val_accuracy: 0.7917 - 677ms/epoch - 75ms/step
# Epoch 271/300
#
# Epoch 271: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.4737 - val_accuracy: 0.7917 - 703ms/epoch - 78ms/step
# Epoch 272/300
#
# Epoch 272: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.4678 - val_accuracy: 0.7917 - 672ms/epoch - 75ms/step
# Epoch 273/300
#
# Epoch 273: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.4522 - val_accuracy: 0.7917 - 683ms/epoch - 76ms/step
# Epoch 274/300
#
# Epoch 274: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.4824 - val_accuracy: 0.7917 - 683ms/epoch - 76ms/step
# Epoch 275/300
#
# Epoch 275: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.4690 - val_accuracy: 0.7917 - 662ms/epoch - 74ms/step
# Epoch 276/300
#
# Epoch 276: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.4695 - val_accuracy: 0.7917 - 677ms/epoch - 75ms/step
# Epoch 277/300
#
# Epoch 277: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.4599 - val_accuracy: 0.7917 - 677ms/epoch - 75ms/step
# Epoch 278/300
#
# Epoch 278: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.4683 - val_accuracy: 0.7917 - 670ms/epoch - 74ms/step
# Epoch 279/300
#
# Epoch 279: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.4951 - val_accuracy: 0.7917 - 673ms/epoch - 75ms/step
# Epoch 280/300
#
# Epoch 280: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.4883 - val_accuracy: 0.7917 - 736ms/epoch - 82ms/step
# Epoch 281/300
#
# Epoch 281: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.4755 - val_accuracy: 0.7917 - 1s/epoch - 144ms/step
# Epoch 282/300
#
# Epoch 282: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.4959 - val_accuracy: 0.7778 - 1s/epoch - 143ms/step
# Epoch 283/300
#
# Epoch 283: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.4743 - val_accuracy: 0.7917 - 681ms/epoch - 76ms/step
# Epoch 284/300
#
# Epoch 284: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.4661 - val_accuracy: 0.7917 - 687ms/epoch - 76ms/step
# Epoch 285/300
#
# Epoch 285: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.4790 - val_accuracy: 0.7917 - 686ms/epoch - 76ms/step
# Epoch 286/300
#
# Epoch 286: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.4809 - val_accuracy: 0.7917 - 689ms/epoch - 77ms/step
# Epoch 287/300
#
# Epoch 287: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.4624 - val_accuracy: 0.7917 - 675ms/epoch - 75ms/step
# Epoch 288/300
#
# Epoch 288: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.4626 - val_accuracy: 0.7917 - 711ms/epoch - 79ms/step
# Epoch 289/300
#
# Epoch 289: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.4867 - val_accuracy: 0.8056 - 692ms/epoch - 77ms/step
# Epoch 290/300
#
# Epoch 290: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.4926 - val_accuracy: 0.7917 - 671ms/epoch - 75ms/step
# Epoch 291/300
#
# Epoch 291: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.4907 - val_accuracy: 0.7917 - 684ms/epoch - 76ms/step
# Epoch 292/300
#
# Epoch 292: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.4869 - val_accuracy: 0.7917 - 700ms/epoch - 78ms/step
# Epoch 293/300
#
# Epoch 293: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.4744 - val_accuracy: 0.7778 - 724ms/epoch - 80ms/step
# Epoch 294/300
#
# Epoch 294: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.4752 - val_accuracy: 0.7917 - 691ms/epoch - 77ms/step
# Epoch 295/300
#
# Epoch 295: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.4803 - val_accuracy: 0.7917 - 694ms/epoch - 77ms/step
# Epoch 296/300
#
# Epoch 296: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.4959 - val_accuracy: 0.7917 - 674ms/epoch - 75ms/step
# Epoch 297/300
#
# Epoch 297: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.4853 - val_accuracy: 0.7917 - 1s/epoch - 130ms/step
# Epoch 298/300
#
# Epoch 298: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.4880 - val_accuracy: 0.7917 - 1s/epoch - 128ms/step
# Epoch 299/300
#
# Epoch 299: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.4917 - val_accuracy: 0.8056 - 898ms/epoch - 100ms/step
# Epoch 300/300
#
# Epoch 300: val_loss did not improve from 0.43470
# 9/9 - 1s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.4994 - val_accuracy: 0.7778 - 691ms/epoch - 77ms/step

# %%
# load optimal weights
model.load_weights('./tmp/checkpoint.h5')

###############################################################################
# can alternatively used the weights provided in the repo. If so it should get
# you 93% accuracy. Change the WEIGHTS_PATH variable to wherever it is on your
# system.
###############################################################################

# WEIGHTS_PATH = /path/to/EEGNet-8-2-weights.h5
# model.load_weights(WEIGHTS_PATH)

###############################################################################
# make prediction on test set.
###############################################################################

probs       = model.predict(X_test)
preds       = probs.argmax(axis = -1)
acc         = np.mean(preds == Y_test.argmax(axis=-1))
print("Classification accuracy: %f " % (acc))


############################# PyRiemann Portion ##############################

# code is taken from PyRiemann's ERP sample script, which is decoding in
# the tangent space with a logistic regression

n_components = 2  # pick some components

# set up sklearn pipeline
clf = make_pipeline(XdawnCovariances(n_components),
                    TangentSpace(metric='riemann'),
                    LogisticRegression())

preds_rg     = np.zeros(len(Y_test))

# reshape back to (trials, channels, samples)
X_train      = X_train.reshape(X_train.shape[0], chans, samples)
X_test       = X_test.reshape(X_test.shape[0], chans, samples)

# train a classifier with xDAWN spatial filtering + Riemannian Geometry (RG)
# labels need to be back in single-column format
clf.fit(X_train, Y_train.argmax(axis = -1))
preds_rg     = clf.predict(X_test)

# Printing the results
acc2         = np.mean(preds_rg == Y_test.argmax(axis = -1))
print("Classification accuracy: %f " % (acc2))
# Out:
# 3/3 [==============================] - 0s 31ms/step
# Classification accuracy: 0.944444
# Classification accuracy: 0.944444

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# %%
# plot the confusion matrices for both classifiers
names        = ['audio left', 'audio right', 'vis left', 'vis right']
# plt.figure(0)
confusion_matrix_1 = confusion_matrix(preds, Y_test.argmax(axis = -1))

# plt.figure(1)
confusion_matrix_2 = confusion_matrix(preds_rg, Y_test.argmax(axis = -1))

# %%
confusion_matrix_1
# Out:
# array([[16,  3,  0,  0],
#        [ 1, 16,  0,  0],
#        [ 0,  0, 18,  0],
#        [ 0,  0,  0, 18]])

# %%
disp1 = ConfusionMatrixDisplay(confusion_matrix_1, display_labels = names)
disp1.plot()

# ConfusionMatrixDisplay(confusion_matrix_2, display_labels = names)

# %%
print(classification_report(preds, Y_test.argmax(axis = -1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.84      0.89        19
#            1       0.84      0.94      0.89        17
#            2       1.00      1.00      1.00        18
#            3       1.00      1.00      1.00        18
#
#     accuracy                           0.94        72
#    macro avg       0.95      0.95      0.94        72
# weighted avg       0.95      0.94      0.94        72

# %%
disp2 = ConfusionMatrixDisplay(confusion_matrix_2, display_labels = names)
disp2.plot()

# %%
end = time.time()
print(f"Took {end - start:.2f} seconds")
# Out:
# Took 235.49 seconds
