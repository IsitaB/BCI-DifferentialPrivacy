# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import ShuffleSplit, cross_val_score
from sklearn.pipeline import Pipeline

from EEGModels import EEGNet
from mne import Epochs, pick_types
from mne.channels import make_standard_montage
from mne.datasets import eegbci
from mne.decoding import CSP
from mne.io import concatenate_raws, read_raw_edf

print(__doc__)
# Out:
# Automatically created module for IPython interactive environment

# %%
import h5py

# %%
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K

# %%
# #############################################################################
# # Set parameters and read data

# avoid classification of evoked responses by using epochs that start 1s after
# cue onset.
tmin, tmax = -1.0, 4.0
subjects = range(1,10)
runs = [6, 10, 14]  # motor imagery: hands vs feet

raw_fnames = eegbci.load_data(subjects, runs)
raw = concatenate_raws([read_raw_edf(f, preload=True) for f in raw_fnames])
eegbci.standardize(raw)  # set channel names
montage = make_standard_montage("standard_1005")
raw.set_montage(montage)
raw.annotations.rename(dict(T1="hands", T2="feet"))  # as documented on PhysioNet
raw.set_eeg_reference(projection=True)

# Apply band-pass filter
raw.filter(7.0, 30.0, fir_design="firwin", skip_by_annotation="edge")

picks = pick_types(raw.info, meg=False, eeg=True, stim=False, eog=False, exclude="bads")

# Read epochs (train will be done only between 1 and 2s)
# Testing will be done with a running classifier
epochs = Epochs(
    raw,
    event_id=["hands", "feet"],
    tmin=tmin,
    tmax=tmax,
    proj=True,
    picks=picks,
    baseline=None,
    preload=True,
)
epochs_train = epochs.copy().crop(tmin=1.0, tmax=2.0)
labels = epochs.events[:, -1] - 2
# Out:
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S001/S001R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S001/S001R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S001/S001R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S002/S002R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S002/S002R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S002/S002R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S003/S003R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S003/S003R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S003/S003R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S004/S004R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S004/S004R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S004/S004R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S005/S005R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S005/S005R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S005/S005R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S006/S006R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S006/S006R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S006/S006R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S007/S007R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S007/S007R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S007/S007R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S008/S008R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S008/S008R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S008/S008R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S009/S009R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S009/S009R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /Users/isita/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S009/S009R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 7 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 7.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 6.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 265 samples (1.656 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Used Annotations descriptions: ['T0', 'feet', 'hands']
# Ignoring annotation durations and creating fixed-duration epochs around annotation onsets.
# Not setting metadata
# 405 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 405 events and 801 original time points ...
# 0 bad epochs dropped

# %%
# extract raw data. scale by 1000 due to scaling sensitivity in deep learning
X = epochs.get_data()*1000 # format is in (trials, channels, samples)
y = labels

kernels, chans, samples = 1, 64, 801

# %%
print(X.shape, y.shape)
# Out:
# (405, 64, 801) (405,)

# %%
X_train      = X[0:224,]
Y_train      = y[0:224]
X_validate   = X[224:320,]
Y_validate   = y[224:320]
X_test       = X[320:416]
Y_test       = y[320:416]

# %%
X_train      = X_train.reshape(X_train.shape[0], chans, samples, kernels)
X_validate   = X_validate.reshape(X_validate.shape[0], chans, samples, kernels)
X_test       = X_test.reshape(X_test.shape[0], chans, samples, kernels)
   
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# X_train shape: (224, 64, 801, 1)
# 224 train samples
# 85 test samples

# %%
# configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
# model configurations may do better, but this is a good starting point)
model = EEGNet(nb_classes = 2, Chans = chans, Samples = samples, 
               dropoutRate = 0.5, kernLength = 32, F1 = 8, D = 2, F2 = 16, 
               dropoutType = 'Dropout')

# compile the model and set the optimizers
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', 
              metrics = ['accuracy'])

# count number of parameters in the model
numParams    = model.count_params()    

# set a valid path for your system to record model checkpoints
with h5py.File('./tmp/mi_checkpoint.h5', 'w') as f:
    # This creates 2 attributes of arrays of different np.float types:
    arr_in = np.array([1.0,2.0,3.0])
    f.attrs['as_float64'] = arr_in
    # arr_in.dtype = np.float128
    # f.attrs['as_float128'] = arr_in
checkpointer = ModelCheckpoint(filepath='./tmp/mi_checkpoint.h5', verbose=1,
                               save_best_only=True)

###############################################################################
# if the classification task was imbalanced (significantly more trials in one
# class versus the others) you can assign a weight to each class during 
# optimization to balance it out. This data is approximately balanced so we 
# don't need to do this, but is shown here for illustration/completeness. 
###############################################################################

# the syntax is {class_1:weight_1, class_2:weight_2,...}. Here just setting
# the weights all to be 1
class_weights = {0:1, 1:1}

################################################################################
# fit the model. Due to very small sample sizes this can get
# pretty noisy run-to-run, but most runs should be comparable to xDAWN + 
# Riemannian geometry classification (below)
################################################################################
fittedModel = model.fit(X_train, Y_train, batch_size = 32, epochs = 100, 
                        verbose = 2, validation_data=(X_validate, Y_validate),
                        # callbacks=[checkpointer], 
                        class_weight = class_weights)
# Out:
# Epoch 1/100
# 7/7 - 1s - loss: 0.7002 - accuracy: 0.4732 - val_loss: 0.6931 - val_accuracy: 0.5104 - 1s/epoch - 147ms/step
# Epoch 2/100
# 7/7 - 1s - loss: 0.6959 - accuracy: 0.4821 - val_loss: 0.6930 - val_accuracy: 0.5104 - 863ms/epoch - 123ms/step
# Epoch 3/100
# 7/7 - 1s - loss: 0.6896 - accuracy: 0.5268 - val_loss: 0.6931 - val_accuracy: 0.5104 - 865ms/epoch - 124ms/step
# Epoch 4/100
# 7/7 - 1s - loss: 0.6887 - accuracy: 0.5625 - val_loss: 0.6931 - val_accuracy: 0.5104 - 932ms/epoch - 133ms/step
# Epoch 5/100
# 7/7 - 1s - loss: 0.6809 - accuracy: 0.5938 - val_loss: 0.6931 - val_accuracy: 0.5104 - 858ms/epoch - 123ms/step
# Epoch 6/100
# 7/7 - 1s - loss: 0.6802 - accuracy: 0.6295 - val_loss: 0.6931 - val_accuracy: 0.5104 - 861ms/epoch - 123ms/step
# Epoch 7/100
# 7/7 - 1s - loss: 0.6815 - accuracy: 0.5670 - val_loss: 0.6931 - val_accuracy: 0.5104 - 880ms/epoch - 126ms/step
# Epoch 8/100
# 7/7 - 1s - loss: 0.6698 - accuracy: 0.5982 - val_loss: 0.6931 - val_accuracy: 0.5104 - 871ms/epoch - 124ms/step
# Epoch 9/100
# 7/7 - 1s - loss: 0.6618 - accuracy: 0.6250 - val_loss: 0.6931 - val_accuracy: 0.5104 - 988ms/epoch - 141ms/step
# Epoch 10/100
# 7/7 - 1s - loss: 0.6618 - accuracy: 0.6250 - val_loss: 0.6931 - val_accuracy: 0.5104 - 846ms/epoch - 121ms/step
# Epoch 11/100
# 7/7 - 1s - loss: 0.6577 - accuracy: 0.6071 - val_loss: 0.6931 - val_accuracy: 0.5104 - 872ms/epoch - 125ms/step
# Epoch 12/100
# 7/7 - 1s - loss: 0.6648 - accuracy: 0.6339 - val_loss: 0.6931 - val_accuracy: 0.4375 - 887ms/epoch - 127ms/step
# Epoch 13/100
# 7/7 - 1s - loss: 0.6404 - accuracy: 0.7098 - val_loss: 0.6931 - val_accuracy: 0.5104 - 854ms/epoch - 122ms/step
# Epoch 14/100
# 7/7 - 1s - loss: 0.6432 - accuracy: 0.6696 - val_loss: 0.6932 - val_accuracy: 0.4896 - 853ms/epoch - 122ms/step
# Epoch 15/100
# 7/7 - 1s - loss: 0.6465 - accuracy: 0.6696 - val_loss: 0.6933 - val_accuracy: 0.4896 - 844ms/epoch - 121ms/step
# Epoch 16/100
# 7/7 - 1s - loss: 0.6301 - accuracy: 0.6652 - val_loss: 0.6933 - val_accuracy: 0.4896 - 847ms/epoch - 121ms/step
# Epoch 17/100
# 7/7 - 1s - loss: 0.6312 - accuracy: 0.6786 - val_loss: 0.6934 - val_accuracy: 0.4896 - 857ms/epoch - 122ms/step
# Epoch 18/100
# 7/7 - 1s - loss: 0.6155 - accuracy: 0.6518 - val_loss: 0.6937 - val_accuracy: 0.4896 - 854ms/epoch - 122ms/step
# Epoch 19/100
# 7/7 - 1s - loss: 0.6256 - accuracy: 0.6205 - val_loss: 0.6939 - val_accuracy: 0.4896 - 861ms/epoch - 123ms/step
# Epoch 20/100
# 7/7 - 1s - loss: 0.6032 - accuracy: 0.6920 - val_loss: 0.6936 - val_accuracy: 0.4896 - 879ms/epoch - 126ms/step
# Epoch 21/100
# 7/7 - 1s - loss: 0.5814 - accuracy: 0.7277 - val_loss: 0.6937 - val_accuracy: 0.4896 - 860ms/epoch - 123ms/step
# Epoch 22/100
# 7/7 - 1s - loss: 0.5747 - accuracy: 0.7188 - val_loss: 0.6937 - val_accuracy: 0.4896 - 851ms/epoch - 122ms/step
# Epoch 23/100
# 7/7 - 1s - loss: 0.5879 - accuracy: 0.6741 - val_loss: 0.6928 - val_accuracy: 0.5104 - 854ms/epoch - 122ms/step
# Epoch 24/100
# 7/7 - 1s - loss: 0.6029 - accuracy: 0.6339 - val_loss: 0.6928 - val_accuracy: 0.5104 - 845ms/epoch - 121ms/step
# Epoch 25/100
# 7/7 - 1s - loss: 0.5510 - accuracy: 0.7366 - val_loss: 0.6931 - val_accuracy: 0.4896 - 906ms/epoch - 129ms/step
# Epoch 26/100
# 7/7 - 1s - loss: 0.5858 - accuracy: 0.6830 - val_loss: 0.6939 - val_accuracy: 0.5104 - 844ms/epoch - 121ms/step
# Epoch 27/100
# 7/7 - 1s - loss: 0.5481 - accuracy: 0.7366 - val_loss: 0.6929 - val_accuracy: 0.5104 - 852ms/epoch - 122ms/step
# Epoch 28/100
# 7/7 - 1s - loss: 0.5411 - accuracy: 0.7321 - val_loss: 0.6929 - val_accuracy: 0.5104 - 852ms/epoch - 122ms/step
# Epoch 29/100
# 7/7 - 1s - loss: 0.5516 - accuracy: 0.7098 - val_loss: 0.6937 - val_accuracy: 0.4896 - 849ms/epoch - 121ms/step
# Epoch 30/100
# 7/7 - 1s - loss: 0.5348 - accuracy: 0.7188 - val_loss: 0.6964 - val_accuracy: 0.4896 - 865ms/epoch - 124ms/step
# Epoch 31/100
# 7/7 - 1s - loss: 0.5358 - accuracy: 0.6920 - val_loss: 0.6935 - val_accuracy: 0.4896 - 864ms/epoch - 123ms/step
# Epoch 32/100
# 7/7 - 1s - loss: 0.5516 - accuracy: 0.7143 - val_loss: 0.6940 - val_accuracy: 0.5104 - 861ms/epoch - 123ms/step
# Epoch 33/100
# 7/7 - 1s - loss: 0.5500 - accuracy: 0.6786 - val_loss: 0.6938 - val_accuracy: 0.5104 - 852ms/epoch - 122ms/step
# Epoch 34/100
# 7/7 - 1s - loss: 0.5097 - accuracy: 0.7098 - val_loss: 0.6927 - val_accuracy: 0.5104 - 865ms/epoch - 124ms/step
# Epoch 35/100
# 7/7 - 1s - loss: 0.5116 - accuracy: 0.7500 - val_loss: 0.6923 - val_accuracy: 0.5104 - 880ms/epoch - 126ms/step
# Epoch 36/100
# 7/7 - 1s - loss: 0.5353 - accuracy: 0.6964 - val_loss: 0.6934 - val_accuracy: 0.5104 - 853ms/epoch - 122ms/step
# Epoch 37/100
# 7/7 - 1s - loss: 0.5301 - accuracy: 0.7054 - val_loss: 0.6922 - val_accuracy: 0.5104 - 853ms/epoch - 122ms/step
# Epoch 38/100
# 7/7 - 1s - loss: 0.5118 - accuracy: 0.7500 - val_loss: 0.6925 - val_accuracy: 0.5104 - 871ms/epoch - 124ms/step
# Epoch 39/100
# 7/7 - 1s - loss: 0.4999 - accuracy: 0.7634 - val_loss: 0.6930 - val_accuracy: 0.5104 - 864ms/epoch - 123ms/step
# Epoch 40/100
# 7/7 - 1s - loss: 0.5043 - accuracy: 0.7366 - val_loss: 0.6988 - val_accuracy: 0.5104 - 926ms/epoch - 132ms/step
# Epoch 41/100
# 7/7 - 1s - loss: 0.4682 - accuracy: 0.7634 - val_loss: 0.6956 - val_accuracy: 0.5104 - 874ms/epoch - 125ms/step
# Epoch 42/100
# 7/7 - 1s - loss: 0.4933 - accuracy: 0.7500 - val_loss: 0.6918 - val_accuracy: 0.5104 - 851ms/epoch - 122ms/step
# Epoch 43/100
# 7/7 - 1s - loss: 0.5042 - accuracy: 0.7098 - val_loss: 0.6941 - val_accuracy: 0.5104 - 852ms/epoch - 122ms/step
# Epoch 44/100
# 7/7 - 1s - loss: 0.4830 - accuracy: 0.7768 - val_loss: 0.6938 - val_accuracy: 0.5104 - 847ms/epoch - 121ms/step
# Epoch 45/100
# 7/7 - 1s - loss: 0.4778 - accuracy: 0.7768 - val_loss: 0.6931 - val_accuracy: 0.5104 - 896ms/epoch - 128ms/step
# Epoch 46/100
# 7/7 - 1s - loss: 0.4921 - accuracy: 0.7411 - val_loss: 0.7010 - val_accuracy: 0.5104 - 852ms/epoch - 122ms/step
# Epoch 47/100
# 7/7 - 1s - loss: 0.4682 - accuracy: 0.7723 - val_loss: 0.7062 - val_accuracy: 0.5104 - 840ms/epoch - 120ms/step
# Epoch 48/100
# 7/7 - 1s - loss: 0.4790 - accuracy: 0.7500 - val_loss: 0.6963 - val_accuracy: 0.5104 - 843ms/epoch - 120ms/step
# Epoch 49/100
# 7/7 - 1s - loss: 0.4476 - accuracy: 0.7545 - val_loss: 0.6854 - val_accuracy: 0.5104 - 847ms/epoch - 121ms/step
# Epoch 50/100
# 7/7 - 1s - loss: 0.4257 - accuracy: 0.8304 - val_loss: 0.6866 - val_accuracy: 0.5104 - 858ms/epoch - 123ms/step
# Epoch 51/100
# 7/7 - 1s - loss: 0.4751 - accuracy: 0.7634 - val_loss: 0.6886 - val_accuracy: 0.5104 - 851ms/epoch - 122ms/step
# Epoch 52/100
# 7/7 - 1s - loss: 0.4705 - accuracy: 0.7768 - val_loss: 0.6984 - val_accuracy: 0.5104 - 847ms/epoch - 121ms/step
# Epoch 53/100
# 7/7 - 1s - loss: 0.4556 - accuracy: 0.7679 - val_loss: 0.6999 - val_accuracy: 0.5104 - 848ms/epoch - 121ms/step
# Epoch 54/100
# 7/7 - 1s - loss: 0.4673 - accuracy: 0.7723 - val_loss: 0.6847 - val_accuracy: 0.5104 - 861ms/epoch - 123ms/step
# Epoch 55/100
# 7/7 - 1s - loss: 0.4683 - accuracy: 0.7589 - val_loss: 0.6775 - val_accuracy: 0.5938 - 872ms/epoch - 125ms/step
# Epoch 56/100
# 7/7 - 1s - loss: 0.4288 - accuracy: 0.8036 - val_loss: 0.6792 - val_accuracy: 0.5104 - 858ms/epoch - 123ms/step
# Epoch 57/100
# 7/7 - 1s - loss: 0.4096 - accuracy: 0.8348 - val_loss: 0.6757 - val_accuracy: 0.5208 - 849ms/epoch - 121ms/step
# Epoch 58/100
# 7/7 - 1s - loss: 0.4421 - accuracy: 0.7946 - val_loss: 0.6722 - val_accuracy: 0.6979 - 862ms/epoch - 123ms/step
# Epoch 59/100
# 7/7 - 1s - loss: 0.3936 - accuracy: 0.8304 - val_loss: 0.6810 - val_accuracy: 0.4896 - 847ms/epoch - 121ms/step
# Epoch 60/100
# 7/7 - 1s - loss: 0.4625 - accuracy: 0.7500 - val_loss: 0.6962 - val_accuracy: 0.4896 - 850ms/epoch - 121ms/step
# Epoch 61/100
# 7/7 - 1s - loss: 0.3961 - accuracy: 0.8170 - val_loss: 0.6934 - val_accuracy: 0.5000 - 842ms/epoch - 120ms/step
# Epoch 62/100
# 7/7 - 1s - loss: 0.4358 - accuracy: 0.7857 - val_loss: 0.6663 - val_accuracy: 0.5833 - 911ms/epoch - 130ms/step
# Epoch 63/100
# 7/7 - 1s - loss: 0.4101 - accuracy: 0.8348 - val_loss: 0.6687 - val_accuracy: 0.5208 - 877ms/epoch - 125ms/step
# Epoch 64/100
# 7/7 - 1s - loss: 0.3974 - accuracy: 0.8214 - val_loss: 0.6944 - val_accuracy: 0.5104 - 869ms/epoch - 124ms/step
# Epoch 65/100
# 7/7 - 1s - loss: 0.4031 - accuracy: 0.8080 - val_loss: 0.6929 - val_accuracy: 0.5104 - 855ms/epoch - 122ms/step
# Epoch 66/100
# 7/7 - 1s - loss: 0.3795 - accuracy: 0.8438 - val_loss: 0.6637 - val_accuracy: 0.6875 - 852ms/epoch - 122ms/step
# Epoch 67/100
# 7/7 - 1s - loss: 0.4035 - accuracy: 0.8214 - val_loss: 0.6466 - val_accuracy: 0.6771 - 881ms/epoch - 126ms/step
# Epoch 68/100
# 7/7 - 1s - loss: 0.3725 - accuracy: 0.8304 - val_loss: 0.6557 - val_accuracy: 0.6979 - 858ms/epoch - 123ms/step
# Epoch 69/100
# 7/7 - 1s - loss: 0.3933 - accuracy: 0.8080 - val_loss: 0.6538 - val_accuracy: 0.5625 - 850ms/epoch - 121ms/step
# Epoch 70/100
# 7/7 - 1s - loss: 0.3791 - accuracy: 0.8482 - val_loss: 0.6977 - val_accuracy: 0.5208 - 859ms/epoch - 123ms/step
# Epoch 71/100
# 7/7 - 1s - loss: 0.3771 - accuracy: 0.8348 - val_loss: 0.6805 - val_accuracy: 0.5104 - 847ms/epoch - 121ms/step
# Epoch 72/100
# 7/7 - 1s - loss: 0.3323 - accuracy: 0.8571 - val_loss: 0.6985 - val_accuracy: 0.5312 - 841ms/epoch - 120ms/step
# Epoch 73/100
# 7/7 - 1s - loss: 0.3609 - accuracy: 0.8348 - val_loss: 0.7454 - val_accuracy: 0.5208 - 835ms/epoch - 119ms/step
# Epoch 74/100
# 7/7 - 1s - loss: 0.3253 - accuracy: 0.8571 - val_loss: 0.6955 - val_accuracy: 0.5417 - 846ms/epoch - 121ms/step
# Epoch 75/100
# 7/7 - 1s - loss: 0.3276 - accuracy: 0.8750 - val_loss: 0.6678 - val_accuracy: 0.5312 - 845ms/epoch - 121ms/step
# Epoch 76/100
# 7/7 - 1s - loss: 0.3560 - accuracy: 0.8661 - val_loss: 0.7042 - val_accuracy: 0.5104 - 848ms/epoch - 121ms/step
# Epoch 77/100
# 7/7 - 1s - loss: 0.3395 - accuracy: 0.8839 - val_loss: 0.7320 - val_accuracy: 0.5208 - 850ms/epoch - 121ms/step
# Epoch 78/100
# 7/7 - 1s - loss: 0.2953 - accuracy: 0.8973 - val_loss: 0.8443 - val_accuracy: 0.5312 - 915ms/epoch - 131ms/step
# Epoch 79/100
# 7/7 - 1s - loss: 0.3126 - accuracy: 0.8929 - val_loss: 1.1488 - val_accuracy: 0.5208 - 857ms/epoch - 122ms/step
# Epoch 80/100
# 7/7 - 1s - loss: 0.3723 - accuracy: 0.8214 - val_loss: 1.5151 - val_accuracy: 0.5000 - 850ms/epoch - 121ms/step
# Epoch 81/100
# 7/7 - 1s - loss: 0.3096 - accuracy: 0.8705 - val_loss: 1.5259 - val_accuracy: 0.5000 - 847ms/epoch - 121ms/step
# Epoch 82/100
# 7/7 - 1s - loss: 0.3066 - accuracy: 0.8705 - val_loss: 1.6237 - val_accuracy: 0.4896 - 845ms/epoch - 121ms/step
# Epoch 83/100
# 7/7 - 1s - loss: 0.3109 - accuracy: 0.8795 - val_loss: 2.0343 - val_accuracy: 0.5000 - 852ms/epoch - 122ms/step
# Epoch 84/100
# 7/7 - 1s - loss: 0.3024 - accuracy: 0.8750 - val_loss: 2.2869 - val_accuracy: 0.5104 - 853ms/epoch - 122ms/step
# Epoch 85/100
# 7/7 - 1s - loss: 0.2899 - accuracy: 0.8839 - val_loss: 2.5116 - val_accuracy: 0.5104 - 837ms/epoch - 120ms/step
# Epoch 86/100
# 7/7 - 1s - loss: 0.2840 - accuracy: 0.9018 - val_loss: 3.0289 - val_accuracy: 0.5104 - 846ms/epoch - 121ms/step
# Epoch 87/100
# 7/7 - 1s - loss: 0.2796 - accuracy: 0.9107 - val_loss: 3.3463 - val_accuracy: 0.5000 - 870ms/epoch - 124ms/step
# Epoch 88/100
# 7/7 - 1s - loss: 0.2770 - accuracy: 0.8705 - val_loss: 3.2485 - val_accuracy: 0.5000 - 876ms/epoch - 125ms/step
# Epoch 89/100
# 7/7 - 1s - loss: 0.3212 - accuracy: 0.8616 - val_loss: 2.9138 - val_accuracy: 0.5000 - 864ms/epoch - 123ms/step
# Epoch 90/100
# 7/7 - 1s - loss: 0.2267 - accuracy: 0.9420 - val_loss: 2.7948 - val_accuracy: 0.4792 - 850ms/epoch - 121ms/step
# Epoch 91/100
# 7/7 - 1s - loss: 0.2837 - accuracy: 0.8705 - val_loss: 2.2948 - val_accuracy: 0.4896 - 849ms/epoch - 121ms/step
# Epoch 92/100
# 7/7 - 1s - loss: 0.2766 - accuracy: 0.9062 - val_loss: 2.1296 - val_accuracy: 0.5000 - 850ms/epoch - 121ms/step
# Epoch 93/100
# 7/7 - 1s - loss: 0.2979 - accuracy: 0.8884 - val_loss: 1.6383 - val_accuracy: 0.5208 - 847ms/epoch - 121ms/step
# Epoch 94/100
# 7/7 - 1s - loss: 0.2358 - accuracy: 0.9286 - val_loss: 1.6170 - val_accuracy: 0.5208 - 842ms/epoch - 120ms/step
# Epoch 95/100
# 7/7 - 1s - loss: 0.2867 - accuracy: 0.9107 - val_loss: 1.5939 - val_accuracy: 0.5208 - 846ms/epoch - 121ms/step
# Epoch 96/100
# 7/7 - 1s - loss: 0.2722 - accuracy: 0.8973 - val_loss: 1.4860 - val_accuracy: 0.5208 - 901ms/epoch - 129ms/step
# Epoch 97/100
# 7/7 - 1s - loss: 0.2539 - accuracy: 0.8973 - val_loss: 1.5941 - val_accuracy: 0.5104 - 874ms/epoch - 125ms/step
# Epoch 98/100
# 7/7 - 1s - loss: 0.2466 - accuracy: 0.9062 - val_loss: 1.2449 - val_accuracy: 0.5000 - 863ms/epoch - 123ms/step
# Epoch 99/100
# 7/7 - 1s - loss: 0.2284 - accuracy: 0.9241 - val_loss: 1.2941 - val_accuracy: 0.4896 - 852ms/epoch - 122ms/step
# Epoch 100/100
# 7/7 - 1s - loss: 0.2676 - accuracy: 0.8884 - val_loss: 1.1802 - val_accuracy: 0.5312 - 853ms/epoch - 122ms/step

# %%
# load optimal weights
# model.load_weights('./tmp/mi_checkpoint.h5')

###############################################################################
# can alternatively used the weights provided in the repo. If so it should get
# you 93% accuracy. Change the WEIGHTS_PATH variable to wherever it is on your
# system.
###############################################################################

# WEIGHTS_PATH = /path/to/EEGNet-8-2-weights.h5 
# model.load_weights(WEIGHTS_PATH)

###############################################################################
# make prediction on test set.
###############################################################################

probs       = model.predict(X_test)
preds       = probs.argmax(axis = -1)  
acc         = np.mean(preds == Y_test.argmax(axis=-1))
print("Classification accuracy: %f " % (acc))
# Out:
# 3/3 [==============================] - 0s 12ms/step
# Classification accuracy: 0.658824

# %%
############################# PyRiemann Portion ##############################

# code is taken from PyRiemann's ERP sample script, which is decoding in 
# the tangent space with a logistic regression

# n_components = 2  # pick some components

# # set up sklearn pipeline
# clf = make_pipeline(XdawnCovariances(n_components),
#                     TangentSpace(metric='riemann'),
#                     LogisticRegression())

# preds_rg     = np.zeros(len(Y_test))

# # reshape back to (trials, channels, samples)
# X_train      = X_train.reshape(X_train.shape[0], chans, samples)
# X_test       = X_test.reshape(X_test.shape[0], chans, samples)

# # train a classifier with xDAWN spatial filtering + Riemannian Geometry (RG)
# # labels need to be back in single-column format
# clf.fit(X_train, Y_train.argmax(axis = -1))
# preds_rg     = clf.predict(X_test)

# # Printing the results
# acc2         = np.mean(preds_rg == Y_test.argmax(axis = -1))
# print("Classification accuracy: %f " % (acc2))

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# %%
# plot the confusion matrices for both classifiers
names        = ['hands', 'feet']
# plt.figure(0)
confusion_matrix_1 = confusion_matrix(preds, Y_test)

# plt.figure(1)
# confusion_matrix_2 = confusion_matrix(preds_rg, Y_test)

disp1 = ConfusionMatrixDisplay(confusion_matrix_1, display_labels = names)
disp1.plot()

# disp2 = ConfusionMatrixDisplay(confusion_matrix_2, display_labels = names)
# disp2.plot()

# %%
print(classification_report(preds, Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.48      0.56        56
#            1       0.34      0.52      0.41        29
#
#     accuracy                           0.49        85
#    macro avg       0.50      0.50      0.48        85
# weighted avg       0.55      0.49      0.51        85
