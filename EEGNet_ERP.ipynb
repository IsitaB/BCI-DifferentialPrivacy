# %%
import numpy as np

# mne imports
import mne
from mne import io
from mne.datasets import sample

# EEGNet-specific imports
# from EEGModels import EEGNet
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K

# PyRiemann imports
from pyriemann.estimation import XdawnCovariances
from pyriemann.tangentspace import TangentSpace
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# tools for plotting confusion matrices
from matplotlib import pyplot as plt

# %%
"""
 ARL_EEGModels - A collection of Convolutional Neural Network models for EEG
 Signal Processing and Classification, using Keras and Tensorflow

 Requirements:
    (1) tensorflow == 2.X (as of this writing, 2.0 - 2.3 have been verified
        as working)
 
 To run the EEG/MEG ERP classification sample script, you will also need

    (4) mne >= 0.17.1
    (5) PyRiemann >= 0.2.5
    (6) scikit-learn >= 0.20.1
    (7) matplotlib >= 2.2.3
    
 To use:
    
    (1) Place this file in the PYTHONPATH variable in your IDE (i.e.: Spyder)
    (2) Import the model as
        
        from EEGModels import EEGNet    
        
        model = EEGNet(nb_classes = ..., Chans = ..., Samples = ...)
        
    (3) Then compile and fit the model
    
        model.compile(loss = ..., optimizer = ..., metrics = ...)
        fitted    = model.fit(...)
        predicted = model.predict(...)

 Portions of this project are works of the United States Government and are not
 subject to domestic copyright protection under 17 USC Sec. 105.  Those 
 portions are released world-wide under the terms of the Creative Commons Zero 
 1.0 (CC0) license.  
 
 Other portions of this project are subject to domestic copyright protection 
 under 17 USC Sec. 105.  Those portions are licensed under the Apache 2.0 
 license.  The complete text of the license governing this material is in 
 the file labeled LICENSE.TXT that is a part of this project's official 
 distribution. 
"""

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Activation, Permute, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import SeparableConv2D, DepthwiseConv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import SpatialDropout2D
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.constraints import max_norm
from tensorflow.keras import backend as K


def EEGNet(nb_classes, Chans = 64, Samples = 128, 
             dropoutRate = 0.5, kernLength = 64, F1 = 8, 
             D = 2, F2 = 16, norm_rate = 0.25, dropoutType = 'Dropout'):
    """ Keras Implementation of EEGNet
    http://iopscience.iop.org/article/10.1088/1741-2552/aace8c/meta

    Note that this implements the newest version of EEGNet and NOT the earlier
    version (version v1 and v2 on arxiv). We strongly recommend using this
    architecture as it performs much better and has nicer properties than
    our earlier version. For example:
        
        1. Depthwise Convolutions to learn spatial filters within a 
        temporal convolution. The use of the depth_multiplier option maps 
        exactly to the number of spatial filters learned within a temporal
        filter. This matches the setup of algorithms like FBCSP which learn 
        spatial filters within each filter in a filter-bank. This also limits 
        the number of free parameters to fit when compared to a fully-connected
        convolution. 
        
        2. Separable Convolutions to learn how to optimally combine spatial
        filters across temporal bands. Separable Convolutions are Depthwise
        Convolutions followed by (1x1) Pointwise Convolutions. 
        
    
    While the original paper used Dropout, we found that SpatialDropout2D 
    sometimes produced slightly better results for classification of ERP 
    signals. However, SpatialDropout2D significantly reduced performance 
    on the Oscillatory dataset (SMR, BCI-IV Dataset 2A). We recommend using
    the default Dropout in most cases.
        
    Assumes the input signal is sampled at 128Hz. If you want to use this model
    for any other sampling rate you will need to modify the lengths of temporal
    kernels and average pooling size in blocks 1 and 2 as needed (double the 
    kernel lengths for double the sampling rate, etc). Note that we haven't 
    tested the model performance with this rule so this may not work well. 
    
    The model with default parameters gives the EEGNet-8,2 model as discussed
    in the paper. This model should do pretty well in general, although it is
	advised to do some model searching to get optimal performance on your
	particular dataset.

    We set F2 = F1 * D (number of input filters = number of output filters) for
    the SeparableConv2D layer. We haven't extensively tested other values of this
    parameter (say, F2 < F1 * D for compressed learning, and F2 > F1 * D for
    overcomplete). We believe the main parameters to focus on are F1 and D. 

    Inputs:
        
      nb_classes      : int, number of classes to classify
      Chans, Samples  : number of channels and time points in the EEG data
      dropoutRate     : dropout fraction
      kernLength      : length of temporal convolution in first layer. We found
                        that setting this to be half the sampling rate worked
                        well in practice. For the SMR dataset in particular
                        since the data was high-passed at 4Hz we used a kernel
                        length of 32.     
      F1, F2          : number of temporal filters (F1) and number of pointwise
                        filters (F2) to learn. Default: F1 = 8, F2 = F1 * D. 
      D               : number of spatial filters to learn within each temporal
                        convolution. Default: D = 2
      dropoutType     : Either SpatialDropout2D or Dropout, passed as a string.

    """
    
    if dropoutType == 'SpatialDropout2D':
        dropoutType = SpatialDropout2D
    elif dropoutType == 'Dropout':
        dropoutType = Dropout
    else:
        raise ValueError('dropoutType must be one of SpatialDropout2D '
                         'or Dropout, passed as a string.')
    
    input1   = Input(shape = (Chans, Samples, 1))

    ##################################################################
    block1       = Conv2D(F1, (1, kernLength), padding = 'same',
                                   input_shape = (Chans, Samples, 1),
                                   use_bias = False)(input1)
    block1       = BatchNormalization()(block1)
    block1       = DepthwiseConv2D((Chans, 1), use_bias = False, 
                                   depth_multiplier = D,
                                   depthwise_constraint = max_norm(1.))(block1)
    block1       = BatchNormalization()(block1)
    block1       = Activation('elu')(block1)
    block1       = AveragePooling2D((1, 4))(block1)
    block1       = dropoutType(dropoutRate)(block1)
    
    block2       = SeparableConv2D(F2, (1, 16),
                                   use_bias = False, padding = 'same')(block1)
    block2       = BatchNormalization()(block2)
    block2       = Activation('elu')(block2)
    block2       = AveragePooling2D((1, 8))(block2)
    block2       = dropoutType(dropoutRate)(block2)
        
    flatten      = Flatten(name = 'flatten')(block2)
    
    dense        = Dense(nb_classes, name = 'dense', 
                         kernel_constraint = max_norm(norm_rate))(flatten)
    softmax      = Activation('softmax', name = 'softmax')(dense)
    
    return Model(inputs=input1, outputs=softmax)




def EEGNet_SSVEP(nb_classes = 12, Chans = 8, Samples = 256, 
             dropoutRate = 0.5, kernLength = 256, F1 = 96, 
             D = 1, F2 = 96, dropoutType = 'Dropout'):
    """ SSVEP Variant of EEGNet, as used in [1]. 

    Inputs:
        
      nb_classes      : int, number of classes to classify
      Chans, Samples  : number of channels and time points in the EEG data
      dropoutRate     : dropout fraction
      kernLength      : length of temporal convolution in first layer
      F1, F2          : number of temporal filters (F1) and number of pointwise
                        filters (F2) to learn. 
      D               : number of spatial filters to learn within each temporal
                        convolution.
      dropoutType     : Either SpatialDropout2D or Dropout, passed as a string.
      
      
    [1]. Waytowich, N. et. al. (2018). Compact Convolutional Neural Networks
    for Classification of Asynchronous Steady-State Visual Evoked Potentials.
    Journal of Neural Engineering vol. 15(6). 
    http://iopscience.iop.org/article/10.1088/1741-2552/aae5d8

    """
    
    if dropoutType == 'SpatialDropout2D':
        dropoutType = SpatialDropout2D
    elif dropoutType == 'Dropout':
        dropoutType = Dropout
    else:
        raise ValueError('dropoutType must be one of SpatialDropout2D '
                         'or Dropout, passed as a string.')
    
    input1   = Input(shape = (Chans, Samples, 1))

    ##################################################################
    block1       = Conv2D(F1, (1, kernLength), padding = 'same',
                                   input_shape = (Chans, Samples, 1),
                                   use_bias = False)(input1)
    block1       = BatchNormalization()(block1)
    block1       = DepthwiseConv2D((Chans, 1), use_bias = False, 
                                   depth_multiplier = D,
                                   depthwise_constraint = max_norm(1.))(block1)
    block1       = BatchNormalization()(block1)
    block1       = Activation('elu')(block1)
    block1       = AveragePooling2D((1, 4))(block1)
    block1       = dropoutType(dropoutRate)(block1)
    
    block2       = SeparableConv2D(F2, (1, 16),
                                   use_bias = False, padding = 'same')(block1)
    block2       = BatchNormalization()(block2)
    block2       = Activation('elu')(block2)
    block2       = AveragePooling2D((1, 8))(block2)
    block2       = dropoutType(dropoutRate)(block2)
        
    flatten      = Flatten(name = 'flatten')(block2)
    
    dense        = Dense(nb_classes, name = 'dense')(flatten)
    softmax      = Activation('softmax', name = 'softmax')(dense)
    
    return Model(inputs=input1, outputs=softmax)



def EEGNet_old(nb_classes, Chans = 64, Samples = 128, regRate = 0.0001,
           dropoutRate = 0.25, kernels = [(2, 32), (8, 4)], strides = (2, 4)):
    """ Keras Implementation of EEGNet_v1 (https://arxiv.org/abs/1611.08024v2)

    This model is the original EEGNet model proposed on arxiv
            https://arxiv.org/abs/1611.08024v2
    
    with a few modifications: we use striding instead of max-pooling as this 
    helped slightly in classification performance while also providing a 
    computational speed-up. 
    
    Note that we no longer recommend the use of this architecture, as the new
    version of EEGNet performs much better overall and has nicer properties.
    
    Inputs:
        
        nb_classes     : total number of final categories
        Chans, Samples : number of EEG channels and samples, respectively
        regRate        : regularization rate for L1 and L2 regularizations
        dropoutRate    : dropout fraction
        kernels        : the 2nd and 3rd layer kernel dimensions (default is 
                         the [2, 32] x [8, 4] configuration)
        strides        : the stride size (note that this replaces the max-pool
                         used in the original paper)
    
    """

    # start the model
    input_main   = Input((Chans, Samples))
    layer1       = Conv2D(16, (Chans, 1), input_shape=(Chans, Samples, 1),
                                 kernel_regularizer = l1_l2(l1=regRate, l2=regRate))(input_main)
    layer1       = BatchNormalization()(layer1)
    layer1       = Activation('elu')(layer1)
    layer1       = Dropout(dropoutRate)(layer1)
    
    permute_dims = 2, 1, 3
    permute1     = Permute(permute_dims)(layer1)
    
    layer2       = Conv2D(4, kernels[0], padding = 'same', 
                            kernel_regularizer=l1_l2(l1=0.0, l2=regRate),
                            strides = strides)(permute1)
    layer2       = BatchNormalization()(layer2)
    layer2       = Activation('elu')(layer2)
    layer2       = Dropout(dropoutRate)(layer2)
    
    layer3       = Conv2D(4, kernels[1], padding = 'same',
                            kernel_regularizer=l1_l2(l1=0.0, l2=regRate),
                            strides = strides)(layer2)
    layer3       = BatchNormalization()(layer3)
    layer3       = Activation('elu')(layer3)
    layer3       = Dropout(dropoutRate)(layer3)
    
    flatten      = Flatten(name = 'flatten')(layer3)
    
    dense        = Dense(nb_classes, name = 'dense')(flatten)
    softmax      = Activation('softmax', name = 'softmax')(dense)
    
    return Model(inputs=input_main, outputs=softmax)



def DeepConvNet(nb_classes, Chans = 64, Samples = 256,
                dropoutRate = 0.5):
    """ Keras implementation of the Deep Convolutional Network as described in
    Schirrmeister et. al. (2017), Human Brain Mapping.
    
    This implementation assumes the input is a 2-second EEG signal sampled at 
    128Hz, as opposed to signals sampled at 250Hz as described in the original
    paper. We also perform temporal convolutions of length (1, 5) as opposed
    to (1, 10) due to this sampling rate difference. 
    
    Note that we use the max_norm constraint on all convolutional layers, as 
    well as the classification layer. We also change the defaults for the
    BatchNormalization layer. We used this based on a personal communication 
    with the original authors.
    
                      ours        original paper
    pool_size        1, 2        1, 3
    strides          1, 2        1, 3
    conv filters     1, 5        1, 10
    
    Note that this implementation has not been verified by the original 
    authors. 
    
    """

    # start the model
    input_main   = Input((Chans, Samples, 1))
    block1       = Conv2D(25, (1, 5), 
                                 input_shape=(Chans, Samples, 1),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(input_main)
    block1       = Conv2D(25, (Chans, 1),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block1)
    block1       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block1)
    block1       = Activation('elu')(block1)
    block1       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block1)
    block1       = Dropout(dropoutRate)(block1)
  
    block2       = Conv2D(50, (1, 5),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block1)
    block2       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block2)
    block2       = Activation('elu')(block2)
    block2       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block2)
    block2       = Dropout(dropoutRate)(block2)
    
    block3       = Conv2D(100, (1, 5),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block2)
    block3       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block3)
    block3       = Activation('elu')(block3)
    block3       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block3)
    block3       = Dropout(dropoutRate)(block3)
    
    block4       = Conv2D(200, (1, 5),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block3)
    block4       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block4)
    block4       = Activation('elu')(block4)
    block4       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block4)
    block4       = Dropout(dropoutRate)(block4)
    
    flatten      = Flatten()(block4)
    
    dense        = Dense(nb_classes, kernel_constraint = max_norm(0.5))(flatten)
    softmax      = Activation('softmax')(dense)
    
    return Model(inputs=input_main, outputs=softmax)


# need these for ShallowConvNet
def square(x):
    return K.square(x)

def log(x):
    return K.log(K.clip(x, min_value = 1e-7, max_value = 10000))   


def ShallowConvNet(nb_classes, Chans = 64, Samples = 128, dropoutRate = 0.5):
    """ Keras implementation of the Shallow Convolutional Network as described
    in Schirrmeister et. al. (2017), Human Brain Mapping.
    
    Assumes the input is a 2-second EEG signal sampled at 128Hz. Note that in 
    the original paper, they do temporal convolutions of length 25 for EEG
    data sampled at 250Hz. We instead use length 13 since the sampling rate is 
    roughly half of the 250Hz which the paper used. The pool_size and stride
    in later layers is also approximately half of what is used in the paper.
    
    Note that we use the max_norm constraint on all convolutional layers, as 
    well as the classification layer. We also change the defaults for the
    BatchNormalization layer. We used this based on a personal communication 
    with the original authors.
    
                     ours        original paper
    pool_size        1, 35       1, 75
    strides          1, 7        1, 15
    conv filters     1, 13       1, 25    
    
    Note that this implementation has not been verified by the original 
    authors. We do note that this implementation reproduces the results in the
    original paper with minor deviations. 
    """

    # start the model
    input_main   = Input((Chans, Samples, 1))
    block1       = Conv2D(40, (1, 13), 
                                 input_shape=(Chans, Samples, 1),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(input_main)
    block1       = Conv2D(40, (Chans, 1), use_bias=False, 
                          kernel_constraint = max_norm(2., axis=(0,1,2)))(block1)
    block1       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block1)
    block1       = Activation(square)(block1)
    block1       = AveragePooling2D(pool_size=(1, 35), strides=(1, 7))(block1)
    block1       = Activation(log)(block1)
    block1       = Dropout(dropoutRate)(block1)
    flatten      = Flatten()(block1)
    dense        = Dense(nb_classes, kernel_constraint = max_norm(0.5))(flatten)
    softmax      = Activation('softmax')(dense)
    
    return Model(inputs=input_main, outputs=softmax)

# %%
# while the default tensorflow ordering is 'channels_last' we set it here
# to be explicit in case if the user has changed the default ordering
K.set_image_data_format('channels_last')

##################### Process, filter and epoch the data ######################
data_path = str(sample.data_path())

# Set parameters and read data
raw_fname = data_path + '/MEG/sample/sample_audvis_filt-0-40_raw.fif'
event_fname = data_path + '/MEG/sample/sample_audvis_filt-0-40_raw-eve.fif'
tmin, tmax = -0., 1
event_id = dict(aud_l=1, aud_r=2, vis_l=3, vis_r=4)

# %%
# Setup for reading the raw data
raw = io.Raw(raw_fname, preload=True, verbose=False)
raw.filter(2, None, method='iir')  # replace baselining with high-pass
events = mne.read_events(event_fname)

raw.info['bads'] = ['MEG 2443']  # set bad channels
picks = mne.pick_types(raw.info, meg=False, eeg=True, stim=False, eog=False,
                       exclude='bads')

# Read epochs
epochs = mne.Epochs(raw, events, event_id, tmin, tmax, proj=False,
                    picks=picks, baseline=None, preload=True, verbose=False)
labels = epochs.events[:, -1]

# extract raw data. scale by 1000 due to scaling sensitivity in deep learning
X = epochs.get_data()*1000 # format is in (trials, channels, samples)
y = labels

kernels, chans, samples = 1, 60, 151
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 2 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 2.00 Hz: -6.02 dB

# %%
# take 50/25/25 percent of the data to train/validate/test
X_train      = X[0:144,]
Y_train      = y[0:144]
X_validate   = X[144:216,]
Y_validate   = y[144:216]
X_test       = X[216:,]
Y_test       = y[216:]

############################# EEGNet portion ##################################

# convert labels to one-hot encodings.
Y_train      = np_utils.to_categorical(Y_train-1)
Y_validate   = np_utils.to_categorical(Y_validate-1)
Y_test       = np_utils.to_categorical(Y_test-1)

# convert data to NHWC (trials, channels, samples, kernels) format. Data 
# contains 60 channels and 151 time-points. Set the number of kernels to 1.
X_train      = X_train.reshape(X_train.shape[0], chans, samples, kernels)
X_validate   = X_validate.reshape(X_validate.shape[0], chans, samples, kernels)
X_test       = X_test.reshape(X_test.shape[0], chans, samples, kernels)
   
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# X_train shape: (144, 60, 151, 1)
# 144 train samples
# 72 test samples

# %%
# configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
# model configurations may do better, but this is a good starting point)
model = EEGNet(nb_classes = 4, Chans = chans, Samples = samples, 
               dropoutRate = 0.5, kernLength = 32, F1 = 8, D = 2, F2 = 16, 
               dropoutType = 'Dropout')

# compile the model and set the optimizers
model.compile(loss='categorical_crossentropy', optimizer='adam', 
              metrics = ['accuracy'])

# count number of parameters in the model
numParams    = model.count_params()    

# set a valid path for your system to record model checkpoints
checkpointer = ModelCheckpoint(filepath='./tmp/checkpoint.h5', verbose=1,
                               save_best_only=True)

###############################################################################
# if the classification task was imbalanced (significantly more trials in one
# class versus the others) you can assign a weight to each class during 
# optimization to balance it out. This data is approximately balanced so we 
# don't need to do this, but is shown here for illustration/completeness. 
###############################################################################

# the syntax is {class_1:weight_1, class_2:weight_2,...}. Here just setting
# the weights all to be 1
class_weights = {0:1, 1:1, 2:1, 3:1}

################################################################################
# fit the model. Due to very small sample sizes this can get
# pretty noisy run-to-run, but most runs should be comparable to xDAWN + 
# Riemannian geometry classification (below)
################################################################################
fittedModel = model.fit(X_train, Y_train, batch_size = 16, epochs = 300, 
                        verbose = 2, validation_data=(X_validate, Y_validate),
                        callbacks=[checkpointer], class_weight = class_weights)
# Out:
# Epoch 1/300
#
# Epoch 1: val_loss improved from inf to 1.38637, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.3765 - accuracy: 0.2778 - val_loss: 1.3864 - val_accuracy: 0.2500 - 348ms/epoch - 39ms/step
# Epoch 2/300
#
# Epoch 2: val_loss did not improve from 1.38637
# 9/9 - 0s - loss: 1.3749 - accuracy: 0.3333 - val_loss: 1.3864 - val_accuracy: 0.2500 - 129ms/epoch - 14ms/step
# Epoch 3/300
# /opt/anaconda3/envs/zazu2/lib/python3.11/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 3: val_loss improved from 1.38637 to 1.38636, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.3666 - accuracy: 0.3681 - val_loss: 1.3864 - val_accuracy: 0.2500 - 135ms/epoch - 15ms/step
# Epoch 4/300
#
# Epoch 4: val_loss improved from 1.38636 to 1.38635, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.3664 - accuracy: 0.3264 - val_loss: 1.3863 - val_accuracy: 0.2500 - 137ms/epoch - 15ms/step
# Epoch 5/300
#
# Epoch 5: val_loss did not improve from 1.38635
# 9/9 - 0s - loss: 1.3720 - accuracy: 0.3125 - val_loss: 1.3864 - val_accuracy: 0.2500 - 126ms/epoch - 14ms/step
# Epoch 6/300
#
# Epoch 6: val_loss did not improve from 1.38635
# 9/9 - 0s - loss: 1.3565 - accuracy: 0.3681 - val_loss: 1.3864 - val_accuracy: 0.2500 - 127ms/epoch - 14ms/step
# Epoch 7/300
#
# Epoch 7: val_loss improved from 1.38635 to 1.38632, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.3421 - accuracy: 0.3681 - val_loss: 1.3863 - val_accuracy: 0.2500 - 130ms/epoch - 14ms/step
# Epoch 8/300
#
# Epoch 8: val_loss improved from 1.38632 to 1.38627, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.3252 - accuracy: 0.4444 - val_loss: 1.3863 - val_accuracy: 0.2500 - 134ms/epoch - 15ms/step
# Epoch 9/300
#
# Epoch 9: val_loss improved from 1.38627 to 1.38620, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.3167 - accuracy: 0.4722 - val_loss: 1.3862 - val_accuracy: 0.2500 - 139ms/epoch - 15ms/step
# Epoch 10/300
#
# Epoch 10: val_loss improved from 1.38620 to 1.38607, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.3037 - accuracy: 0.4514 - val_loss: 1.3861 - val_accuracy: 0.2500 - 160ms/epoch - 18ms/step
# Epoch 11/300
#
# Epoch 11: val_loss improved from 1.38607 to 1.38587, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.2557 - accuracy: 0.5347 - val_loss: 1.3859 - val_accuracy: 0.2500 - 138ms/epoch - 15ms/step
# Epoch 12/300
#
# Epoch 12: val_loss improved from 1.38587 to 1.38565, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.2218 - accuracy: 0.5417 - val_loss: 1.3856 - val_accuracy: 0.2500 - 134ms/epoch - 15ms/step
# Epoch 13/300
#
# Epoch 13: val_loss improved from 1.38565 to 1.38535, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.2048 - accuracy: 0.5764 - val_loss: 1.3854 - val_accuracy: 0.2500 - 135ms/epoch - 15ms/step
# Epoch 14/300
#
# Epoch 14: val_loss improved from 1.38535 to 1.38493, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.1809 - accuracy: 0.5694 - val_loss: 1.3849 - val_accuracy: 0.2500 - 134ms/epoch - 15ms/step
# Epoch 15/300
#
# Epoch 15: val_loss improved from 1.38493 to 1.38449, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.1530 - accuracy: 0.5417 - val_loss: 1.3845 - val_accuracy: 0.2500 - 136ms/epoch - 15ms/step
# Epoch 16/300
#
# Epoch 16: val_loss improved from 1.38449 to 1.38398, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.1370 - accuracy: 0.5694 - val_loss: 1.3840 - val_accuracy: 0.2500 - 134ms/epoch - 15ms/step
# Epoch 17/300
#
# Epoch 17: val_loss improved from 1.38398 to 1.38348, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.1141 - accuracy: 0.5764 - val_loss: 1.3835 - val_accuracy: 0.2500 - 132ms/epoch - 15ms/step
# Epoch 18/300
#
# Epoch 18: val_loss improved from 1.38348 to 1.38270, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.1022 - accuracy: 0.5903 - val_loss: 1.3827 - val_accuracy: 0.2500 - 132ms/epoch - 15ms/step
# Epoch 19/300
#
# Epoch 19: val_loss improved from 1.38270 to 1.38192, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.0891 - accuracy: 0.5347 - val_loss: 1.3819 - val_accuracy: 0.2500 - 135ms/epoch - 15ms/step
# Epoch 20/300
#
# Epoch 20: val_loss improved from 1.38192 to 1.38122, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.0554 - accuracy: 0.5972 - val_loss: 1.3812 - val_accuracy: 0.2500 - 133ms/epoch - 15ms/step
# Epoch 21/300
#
# Epoch 21: val_loss improved from 1.38122 to 1.38061, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.0532 - accuracy: 0.5278 - val_loss: 1.3806 - val_accuracy: 0.2500 - 137ms/epoch - 15ms/step
# Epoch 22/300
#
# Epoch 22: val_loss improved from 1.38061 to 1.37975, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.0432 - accuracy: 0.5556 - val_loss: 1.3798 - val_accuracy: 0.2500 - 139ms/epoch - 15ms/step
# Epoch 23/300
#
# Epoch 23: val_loss improved from 1.37975 to 1.37867, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.0248 - accuracy: 0.6111 - val_loss: 1.3787 - val_accuracy: 0.2500 - 156ms/epoch - 17ms/step
# Epoch 24/300
#
# Epoch 24: val_loss improved from 1.37867 to 1.37744, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.0369 - accuracy: 0.5625 - val_loss: 1.3774 - val_accuracy: 0.2500 - 137ms/epoch - 15ms/step
# Epoch 25/300
#
# Epoch 25: val_loss improved from 1.37744 to 1.37619, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.0136 - accuracy: 0.6042 - val_loss: 1.3762 - val_accuracy: 0.2500 - 137ms/epoch - 15ms/step
# Epoch 26/300
#
# Epoch 26: val_loss improved from 1.37619 to 1.37515, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.0051 - accuracy: 0.6389 - val_loss: 1.3752 - val_accuracy: 0.2500 - 137ms/epoch - 15ms/step
# Epoch 27/300
#
# Epoch 27: val_loss improved from 1.37515 to 1.37364, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9901 - accuracy: 0.6250 - val_loss: 1.3736 - val_accuracy: 0.2500 - 137ms/epoch - 15ms/step
# Epoch 28/300
#
# Epoch 28: val_loss improved from 1.37364 to 1.37203, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9977 - accuracy: 0.6181 - val_loss: 1.3720 - val_accuracy: 0.2500 - 136ms/epoch - 15ms/step
# Epoch 29/300
#
# Epoch 29: val_loss improved from 1.37203 to 1.37020, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9848 - accuracy: 0.5833 - val_loss: 1.3702 - val_accuracy: 0.2500 - 132ms/epoch - 15ms/step
# Epoch 30/300
#
# Epoch 30: val_loss improved from 1.37020 to 1.36874, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9820 - accuracy: 0.5833 - val_loss: 1.3687 - val_accuracy: 0.2500 - 135ms/epoch - 15ms/step
# Epoch 31/300
#
# Epoch 31: val_loss improved from 1.36874 to 1.36693, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9658 - accuracy: 0.5972 - val_loss: 1.3669 - val_accuracy: 0.2500 - 137ms/epoch - 15ms/step
# Epoch 32/300
#
# Epoch 32: val_loss improved from 1.36693 to 1.36507, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9689 - accuracy: 0.6250 - val_loss: 1.3651 - val_accuracy: 0.2500 - 137ms/epoch - 15ms/step
# Epoch 33/300
#
# Epoch 33: val_loss improved from 1.36507 to 1.36220, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9517 - accuracy: 0.6458 - val_loss: 1.3622 - val_accuracy: 0.2500 - 140ms/epoch - 16ms/step
# Epoch 34/300
#
# Epoch 34: val_loss improved from 1.36220 to 1.35946, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9677 - accuracy: 0.5903 - val_loss: 1.3595 - val_accuracy: 0.2500 - 138ms/epoch - 15ms/step
# Epoch 35/300
#
# Epoch 35: val_loss improved from 1.35946 to 1.35701, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9688 - accuracy: 0.5833 - val_loss: 1.3570 - val_accuracy: 0.2639 - 135ms/epoch - 15ms/step
# Epoch 36/300
#
# Epoch 36: val_loss improved from 1.35701 to 1.35462, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9760 - accuracy: 0.5972 - val_loss: 1.3546 - val_accuracy: 0.2778 - 137ms/epoch - 15ms/step
# Epoch 37/300
#
# Epoch 37: val_loss improved from 1.35462 to 1.35013, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9466 - accuracy: 0.6111 - val_loss: 1.3501 - val_accuracy: 0.2778 - 137ms/epoch - 15ms/step
# Epoch 38/300
#
# Epoch 38: val_loss improved from 1.35013 to 1.34730, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9384 - accuracy: 0.6597 - val_loss: 1.3473 - val_accuracy: 0.3056 - 140ms/epoch - 16ms/step
# Epoch 39/300
#
# Epoch 39: val_loss improved from 1.34730 to 1.34433, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9209 - accuracy: 0.6389 - val_loss: 1.3443 - val_accuracy: 0.3056 - 138ms/epoch - 15ms/step
# Epoch 40/300
#
# Epoch 40: val_loss improved from 1.34433 to 1.34036, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9346 - accuracy: 0.6389 - val_loss: 1.3404 - val_accuracy: 0.3056 - 134ms/epoch - 15ms/step
# Epoch 41/300
#
# Epoch 41: val_loss improved from 1.34036 to 1.33472, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9169 - accuracy: 0.6528 - val_loss: 1.3347 - val_accuracy: 0.3194 - 140ms/epoch - 16ms/step
# Epoch 42/300
#
# Epoch 42: val_loss improved from 1.33472 to 1.33034, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9163 - accuracy: 0.6528 - val_loss: 1.3303 - val_accuracy: 0.3333 - 135ms/epoch - 15ms/step
# Epoch 43/300
#
# Epoch 43: val_loss improved from 1.33034 to 1.32629, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8928 - accuracy: 0.6944 - val_loss: 1.3263 - val_accuracy: 0.3333 - 138ms/epoch - 15ms/step
# Epoch 44/300
#
# Epoch 44: val_loss improved from 1.32629 to 1.32265, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8918 - accuracy: 0.6806 - val_loss: 1.3227 - val_accuracy: 0.3333 - 136ms/epoch - 15ms/step
# Epoch 45/300
#
# Epoch 45: val_loss improved from 1.32265 to 1.31979, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8794 - accuracy: 0.6667 - val_loss: 1.3198 - val_accuracy: 0.3333 - 137ms/epoch - 15ms/step
# Epoch 46/300
#
# Epoch 46: val_loss improved from 1.31979 to 1.31075, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9048 - accuracy: 0.6667 - val_loss: 1.3107 - val_accuracy: 0.3472 - 133ms/epoch - 15ms/step
# Epoch 47/300
#
# Epoch 47: val_loss improved from 1.31075 to 1.30458, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8705 - accuracy: 0.6528 - val_loss: 1.3046 - val_accuracy: 0.3889 - 161ms/epoch - 18ms/step
# Epoch 48/300
#
# Epoch 48: val_loss improved from 1.30458 to 1.29435, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8855 - accuracy: 0.6667 - val_loss: 1.2944 - val_accuracy: 0.4028 - 138ms/epoch - 15ms/step
# Epoch 49/300
#
# Epoch 49: val_loss improved from 1.29435 to 1.28341, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8905 - accuracy: 0.6458 - val_loss: 1.2834 - val_accuracy: 0.4028 - 143ms/epoch - 16ms/step
# Epoch 50/300
#
# Epoch 50: val_loss improved from 1.28341 to 1.27545, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9016 - accuracy: 0.6806 - val_loss: 1.2754 - val_accuracy: 0.4028 - 139ms/epoch - 15ms/step
# Epoch 51/300
#
# Epoch 51: val_loss improved from 1.27545 to 1.26993, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8760 - accuracy: 0.6667 - val_loss: 1.2699 - val_accuracy: 0.4167 - 136ms/epoch - 15ms/step
# Epoch 52/300
#
# Epoch 52: val_loss improved from 1.26993 to 1.26131, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8531 - accuracy: 0.6667 - val_loss: 1.2613 - val_accuracy: 0.4722 - 134ms/epoch - 15ms/step
# Epoch 53/300
#
# Epoch 53: val_loss improved from 1.26131 to 1.25025, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8511 - accuracy: 0.6875 - val_loss: 1.2502 - val_accuracy: 0.4444 - 139ms/epoch - 15ms/step
# Epoch 54/300
#
# Epoch 54: val_loss improved from 1.25025 to 1.23825, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8646 - accuracy: 0.6319 - val_loss: 1.2383 - val_accuracy: 0.4861 - 136ms/epoch - 15ms/step
# Epoch 55/300
#
# Epoch 55: val_loss improved from 1.23825 to 1.22890, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8247 - accuracy: 0.7014 - val_loss: 1.2289 - val_accuracy: 0.5139 - 137ms/epoch - 15ms/step
# Epoch 56/300
#
# Epoch 56: val_loss improved from 1.22890 to 1.21426, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8292 - accuracy: 0.7083 - val_loss: 1.2143 - val_accuracy: 0.5000 - 138ms/epoch - 15ms/step
# Epoch 57/300
#
# Epoch 57: val_loss did not improve from 1.21426
# 9/9 - 0s - loss: 0.8094 - accuracy: 0.7431 - val_loss: 1.2156 - val_accuracy: 0.5000 - 132ms/epoch - 15ms/step
# Epoch 58/300
#
# Epoch 58: val_loss improved from 1.21426 to 1.20158, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8077 - accuracy: 0.7361 - val_loss: 1.2016 - val_accuracy: 0.5139 - 136ms/epoch - 15ms/step
# Epoch 59/300
#
# Epoch 59: val_loss improved from 1.20158 to 1.18944, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8318 - accuracy: 0.7292 - val_loss: 1.1894 - val_accuracy: 0.4861 - 135ms/epoch - 15ms/step
# Epoch 60/300
#
# Epoch 60: val_loss improved from 1.18944 to 1.17864, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8185 - accuracy: 0.7500 - val_loss: 1.1786 - val_accuracy: 0.5139 - 141ms/epoch - 16ms/step
# Epoch 61/300
#
# Epoch 61: val_loss improved from 1.17864 to 1.17356, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8188 - accuracy: 0.7153 - val_loss: 1.1736 - val_accuracy: 0.5000 - 141ms/epoch - 16ms/step
# Epoch 62/300
#
# Epoch 62: val_loss improved from 1.17356 to 1.15847, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7949 - accuracy: 0.7431 - val_loss: 1.1585 - val_accuracy: 0.5556 - 139ms/epoch - 15ms/step
# Epoch 63/300
#
# Epoch 63: val_loss improved from 1.15847 to 1.15087, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8077 - accuracy: 0.7014 - val_loss: 1.1509 - val_accuracy: 0.5694 - 139ms/epoch - 15ms/step
# Epoch 64/300
#
# Epoch 64: val_loss improved from 1.15087 to 1.13867, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7827 - accuracy: 0.7014 - val_loss: 1.1387 - val_accuracy: 0.5556 - 135ms/epoch - 15ms/step
# Epoch 65/300
#
# Epoch 65: val_loss improved from 1.13867 to 1.13031, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7644 - accuracy: 0.7569 - val_loss: 1.1303 - val_accuracy: 0.5694 - 137ms/epoch - 15ms/step
# Epoch 66/300
#
# Epoch 66: val_loss improved from 1.13031 to 1.11933, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7762 - accuracy: 0.7500 - val_loss: 1.1193 - val_accuracy: 0.5833 - 142ms/epoch - 16ms/step
# Epoch 67/300
#
# Epoch 67: val_loss improved from 1.11933 to 1.08874, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8176 - accuracy: 0.6944 - val_loss: 1.0887 - val_accuracy: 0.6111 - 164ms/epoch - 18ms/step
# Epoch 68/300
#
# Epoch 68: val_loss improved from 1.08874 to 1.08656, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8158 - accuracy: 0.6806 - val_loss: 1.0866 - val_accuracy: 0.5694 - 138ms/epoch - 15ms/step
# Epoch 69/300
#
# Epoch 69: val_loss improved from 1.08656 to 1.05906, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7687 - accuracy: 0.6944 - val_loss: 1.0591 - val_accuracy: 0.6111 - 136ms/epoch - 15ms/step
# Epoch 70/300
#
# Epoch 70: val_loss improved from 1.05906 to 1.04306, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7831 - accuracy: 0.7222 - val_loss: 1.0431 - val_accuracy: 0.6389 - 137ms/epoch - 15ms/step
# Epoch 71/300
#
# Epoch 71: val_loss improved from 1.04306 to 1.03663, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7570 - accuracy: 0.7361 - val_loss: 1.0366 - val_accuracy: 0.5694 - 139ms/epoch - 15ms/step
# Epoch 72/300
#
# Epoch 72: val_loss improved from 1.03663 to 1.02777, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7413 - accuracy: 0.7847 - val_loss: 1.0278 - val_accuracy: 0.5972 - 135ms/epoch - 15ms/step
# Epoch 73/300
#
# Epoch 73: val_loss improved from 1.02777 to 1.01925, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7441 - accuracy: 0.7708 - val_loss: 1.0192 - val_accuracy: 0.6250 - 137ms/epoch - 15ms/step
# Epoch 74/300
#
# Epoch 74: val_loss improved from 1.01925 to 1.00633, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7243 - accuracy: 0.8333 - val_loss: 1.0063 - val_accuracy: 0.6111 - 141ms/epoch - 16ms/step
# Epoch 75/300
#
# Epoch 75: val_loss improved from 1.00633 to 1.00181, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7691 - accuracy: 0.6944 - val_loss: 1.0018 - val_accuracy: 0.6250 - 137ms/epoch - 15ms/step
# Epoch 76/300
#
# Epoch 76: val_loss improved from 1.00181 to 0.98387, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7315 - accuracy: 0.8056 - val_loss: 0.9839 - val_accuracy: 0.6111 - 144ms/epoch - 16ms/step
# Epoch 77/300
#
# Epoch 77: val_loss improved from 0.98387 to 0.98161, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7393 - accuracy: 0.7708 - val_loss: 0.9816 - val_accuracy: 0.6528 - 142ms/epoch - 16ms/step
# Epoch 78/300
#
# Epoch 78: val_loss improved from 0.98161 to 0.97696, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7380 - accuracy: 0.7917 - val_loss: 0.9770 - val_accuracy: 0.6250 - 139ms/epoch - 15ms/step
# Epoch 79/300
#
# Epoch 79: val_loss improved from 0.97696 to 0.96399, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7641 - accuracy: 0.7431 - val_loss: 0.9640 - val_accuracy: 0.6389 - 138ms/epoch - 15ms/step
# Epoch 80/300
#
# Epoch 80: val_loss improved from 0.96399 to 0.95775, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7397 - accuracy: 0.8056 - val_loss: 0.9577 - val_accuracy: 0.6111 - 139ms/epoch - 15ms/step
# Epoch 81/300
#
# Epoch 81: val_loss improved from 0.95775 to 0.94977, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7012 - accuracy: 0.7917 - val_loss: 0.9498 - val_accuracy: 0.6111 - 138ms/epoch - 15ms/step
# Epoch 82/300
#
# Epoch 82: val_loss improved from 0.94977 to 0.93735, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7524 - accuracy: 0.7014 - val_loss: 0.9373 - val_accuracy: 0.6528 - 140ms/epoch - 16ms/step
# Epoch 83/300
#
# Epoch 83: val_loss did not improve from 0.93735
# 9/9 - 0s - loss: 0.6944 - accuracy: 0.7917 - val_loss: 0.9542 - val_accuracy: 0.6389 - 131ms/epoch - 15ms/step
# Epoch 84/300
#
# Epoch 84: val_loss improved from 0.93735 to 0.92050, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.6919 - accuracy: 0.8125 - val_loss: 0.9205 - val_accuracy: 0.6250 - 136ms/epoch - 15ms/step
# Epoch 85/300
#
# Epoch 85: val_loss did not improve from 0.92050
# 9/9 - 0s - loss: 0.7241 - accuracy: 0.7778 - val_loss: 0.9258 - val_accuracy: 0.6528 - 129ms/epoch - 14ms/step
# Epoch 86/300
#
# Epoch 86: val_loss improved from 0.92050 to 0.90300, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7137 - accuracy: 0.7917 - val_loss: 0.9030 - val_accuracy: 0.6944 - 153ms/epoch - 17ms/step
# Epoch 87/300
#
# Epoch 87: val_loss improved from 0.90300 to 0.88425, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7019 - accuracy: 0.7778 - val_loss: 0.8842 - val_accuracy: 0.7222 - 136ms/epoch - 15ms/step
# Epoch 88/300
#
# Epoch 88: val_loss did not improve from 0.88425
# 9/9 - 0s - loss: 0.7037 - accuracy: 0.7708 - val_loss: 0.8956 - val_accuracy: 0.6806 - 131ms/epoch - 15ms/step
# Epoch 89/300
#
# Epoch 89: val_loss improved from 0.88425 to 0.88105, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.6799 - accuracy: 0.7917 - val_loss: 0.8811 - val_accuracy: 0.6528 - 136ms/epoch - 15ms/step
# Epoch 90/300
#
# Epoch 90: val_loss did not improve from 0.88105
# 9/9 - 0s - loss: 0.6764 - accuracy: 0.8264 - val_loss: 0.8836 - val_accuracy: 0.7083 - 131ms/epoch - 15ms/step
# Epoch 91/300
#
# Epoch 91: val_loss improved from 0.88105 to 0.87647, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.6770 - accuracy: 0.7917 - val_loss: 0.8765 - val_accuracy: 0.6806 - 136ms/epoch - 15ms/step
# Epoch 92/300
#
# Epoch 92: val_loss improved from 0.87647 to 0.86976, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.6794 - accuracy: 0.7708 - val_loss: 0.8698 - val_accuracy: 0.6944 - 139ms/epoch - 15ms/step
# Epoch 93/300
#
# Epoch 93: val_loss did not improve from 0.86976
# 9/9 - 0s - loss: 0.6789 - accuracy: 0.8125 - val_loss: 0.8776 - val_accuracy: 0.6944 - 129ms/epoch - 14ms/step
# Epoch 94/300
#
# Epoch 94: val_loss improved from 0.86976 to 0.86687, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.6653 - accuracy: 0.8125 - val_loss: 0.8669 - val_accuracy: 0.6806 - 138ms/epoch - 15ms/step
# Epoch 95/300
#
# Epoch 95: val_loss did not improve from 0.86687
# 9/9 - 0s - loss: 0.6726 - accuracy: 0.8125 - val_loss: 0.8816 - val_accuracy: 0.6806 - 133ms/epoch - 15ms/step
# Epoch 96/300
#
# Epoch 96: val_loss did not improve from 0.86687
# 9/9 - 0s - loss: 0.6857 - accuracy: 0.7917 - val_loss: 0.8769 - val_accuracy: 0.6806 - 137ms/epoch - 15ms/step
# Epoch 97/300
#
# Epoch 97: val_loss improved from 0.86687 to 0.86281, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.6572 - accuracy: 0.7847 - val_loss: 0.8628 - val_accuracy: 0.6667 - 141ms/epoch - 16ms/step
# Epoch 98/300
#
# Epoch 98: val_loss did not improve from 0.86281
# 9/9 - 0s - loss: 0.6627 - accuracy: 0.8194 - val_loss: 0.8961 - val_accuracy: 0.6806 - 135ms/epoch - 15ms/step
# Epoch 99/300
#
# Epoch 99: val_loss improved from 0.86281 to 0.81177, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7484 - accuracy: 0.7361 - val_loss: 0.8118 - val_accuracy: 0.7639 - 140ms/epoch - 16ms/step
# Epoch 100/300
#
# Epoch 100: val_loss did not improve from 0.81177
# 9/9 - 0s - loss: 0.6374 - accuracy: 0.8611 - val_loss: 0.8401 - val_accuracy: 0.6944 - 134ms/epoch - 15ms/step
# Epoch 101/300
#
# Epoch 101: val_loss did not improve from 0.81177
# 9/9 - 0s - loss: 0.6831 - accuracy: 0.7500 - val_loss: 0.8208 - val_accuracy: 0.6528 - 131ms/epoch - 15ms/step
# Epoch 102/300
#
# Epoch 102: val_loss did not improve from 0.81177
# 9/9 - 0s - loss: 0.6576 - accuracy: 0.7986 - val_loss: 0.8222 - val_accuracy: 0.7083 - 133ms/epoch - 15ms/step
# Epoch 103/300
#
# Epoch 103: val_loss did not improve from 0.81177
# 9/9 - 0s - loss: 0.5835 - accuracy: 0.8611 - val_loss: 0.8215 - val_accuracy: 0.7083 - 152ms/epoch - 17ms/step
# Epoch 104/300
#
# Epoch 104: val_loss did not improve from 0.81177
# 9/9 - 0s - loss: 0.6201 - accuracy: 0.8542 - val_loss: 0.8169 - val_accuracy: 0.7500 - 137ms/epoch - 15ms/step
# Epoch 105/300
#
# Epoch 105: val_loss did not improve from 0.81177
# 9/9 - 0s - loss: 0.6108 - accuracy: 0.7917 - val_loss: 0.8151 - val_accuracy: 0.7083 - 131ms/epoch - 15ms/step
# Epoch 106/300
#
# Epoch 106: val_loss did not improve from 0.81177
# 9/9 - 0s - loss: 0.6411 - accuracy: 0.7708 - val_loss: 0.8240 - val_accuracy: 0.6806 - 133ms/epoch - 15ms/step
# Epoch 107/300
#
# Epoch 107: val_loss did not improve from 0.81177
# 9/9 - 0s - loss: 0.6343 - accuracy: 0.8056 - val_loss: 0.8376 - val_accuracy: 0.6667 - 134ms/epoch - 15ms/step
# Epoch 108/300
#
# Epoch 108: val_loss did not improve from 0.81177
# 9/9 - 0s - loss: 0.6522 - accuracy: 0.8264 - val_loss: 0.8289 - val_accuracy: 0.6528 - 130ms/epoch - 14ms/step
# Epoch 109/300
#
# Epoch 109: val_loss did not improve from 0.81177
# 9/9 - 0s - loss: 0.6174 - accuracy: 0.8125 - val_loss: 0.8166 - val_accuracy: 0.7083 - 129ms/epoch - 14ms/step
# Epoch 110/300
#
# Epoch 110: val_loss did not improve from 0.81177
# 9/9 - 0s - loss: 0.6747 - accuracy: 0.7986 - val_loss: 0.8268 - val_accuracy: 0.6944 - 134ms/epoch - 15ms/step
# Epoch 111/300
#
# Epoch 111: val_loss improved from 0.81177 to 0.80876, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.5955 - accuracy: 0.8472 - val_loss: 0.8088 - val_accuracy: 0.6944 - 140ms/epoch - 16ms/step
# Epoch 112/300
#
# Epoch 112: val_loss did not improve from 0.80876
# 9/9 - 0s - loss: 0.6247 - accuracy: 0.8472 - val_loss: 0.8200 - val_accuracy: 0.6250 - 133ms/epoch - 15ms/step
# Epoch 113/300
#
# Epoch 113: val_loss improved from 0.80876 to 0.80258, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.6368 - accuracy: 0.8125 - val_loss: 0.8026 - val_accuracy: 0.7500 - 138ms/epoch - 15ms/step
# Epoch 114/300
#
# Epoch 114: val_loss improved from 0.80258 to 0.79368, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.6512 - accuracy: 0.8194 - val_loss: 0.7937 - val_accuracy: 0.7222 - 138ms/epoch - 15ms/step
# Epoch 115/300
#
# Epoch 115: val_loss improved from 0.79368 to 0.78236, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.6377 - accuracy: 0.7986 - val_loss: 0.7824 - val_accuracy: 0.7222 - 138ms/epoch - 15ms/step
# Epoch 116/300
#
# Epoch 116: val_loss did not improve from 0.78236
# 9/9 - 0s - loss: 0.6365 - accuracy: 0.8194 - val_loss: 0.8270 - val_accuracy: 0.6944 - 136ms/epoch - 15ms/step
# Epoch 117/300
#
# Epoch 117: val_loss did not improve from 0.78236
# 9/9 - 0s - loss: 0.6225 - accuracy: 0.8472 - val_loss: 0.8043 - val_accuracy: 0.6528 - 130ms/epoch - 14ms/step
# Epoch 118/300
#
# Epoch 118: val_loss did not improve from 0.78236
# 9/9 - 0s - loss: 0.6156 - accuracy: 0.8472 - val_loss: 0.8111 - val_accuracy: 0.7361 - 134ms/epoch - 15ms/step
# Epoch 119/300
#
# Epoch 119: val_loss did not improve from 0.78236
# 9/9 - 0s - loss: 0.6160 - accuracy: 0.8333 - val_loss: 0.7872 - val_accuracy: 0.7361 - 151ms/epoch - 17ms/step
# Epoch 120/300
#
# Epoch 120: val_loss did not improve from 0.78236
# 9/9 - 0s - loss: 0.5946 - accuracy: 0.8333 - val_loss: 0.8038 - val_accuracy: 0.6806 - 133ms/epoch - 15ms/step
# Epoch 121/300
#
# Epoch 121: val_loss did not improve from 0.78236
# 9/9 - 0s - loss: 0.5956 - accuracy: 0.8403 - val_loss: 0.8462 - val_accuracy: 0.6528 - 133ms/epoch - 15ms/step
# Epoch 122/300
#
# Epoch 122: val_loss did not improve from 0.78236
# 9/9 - 0s - loss: 0.5898 - accuracy: 0.8542 - val_loss: 0.8085 - val_accuracy: 0.6528 - 135ms/epoch - 15ms/step
# Epoch 123/300
#
# Epoch 123: val_loss did not improve from 0.78236
# 9/9 - 0s - loss: 0.6284 - accuracy: 0.7778 - val_loss: 0.7880 - val_accuracy: 0.6944 - 133ms/epoch - 15ms/step
# Epoch 124/300
#
# Epoch 124: val_loss did not improve from 0.78236
# 9/9 - 0s - loss: 0.5869 - accuracy: 0.8125 - val_loss: 0.7925 - val_accuracy: 0.7083 - 133ms/epoch - 15ms/step
# Epoch 125/300
#
# Epoch 125: val_loss improved from 0.78236 to 0.76095, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.5353 - accuracy: 0.8819 - val_loss: 0.7610 - val_accuracy: 0.7500 - 139ms/epoch - 15ms/step
# Epoch 126/300
#
# Epoch 126: val_loss did not improve from 0.76095
# 9/9 - 0s - loss: 0.5391 - accuracy: 0.8819 - val_loss: 0.7875 - val_accuracy: 0.6806 - 134ms/epoch - 15ms/step
# Epoch 127/300
#
# Epoch 127: val_loss did not improve from 0.76095
# 9/9 - 0s - loss: 0.5600 - accuracy: 0.8403 - val_loss: 0.7909 - val_accuracy: 0.6806 - 133ms/epoch - 15ms/step
# Epoch 128/300
#
# Epoch 128: val_loss improved from 0.76095 to 0.74915, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.5728 - accuracy: 0.8889 - val_loss: 0.7491 - val_accuracy: 0.7222 - 136ms/epoch - 15ms/step
# Epoch 129/300
#
# Epoch 129: val_loss did not improve from 0.74915
# 9/9 - 0s - loss: 0.5494 - accuracy: 0.8750 - val_loss: 0.7733 - val_accuracy: 0.7500 - 135ms/epoch - 15ms/step
# Epoch 130/300
#
# Epoch 130: val_loss did not improve from 0.74915
# 9/9 - 0s - loss: 0.5402 - accuracy: 0.8750 - val_loss: 0.7629 - val_accuracy: 0.7500 - 138ms/epoch - 15ms/step
# Epoch 131/300
#
# Epoch 131: val_loss did not improve from 0.74915
# 9/9 - 0s - loss: 0.5230 - accuracy: 0.8611 - val_loss: 0.7652 - val_accuracy: 0.7917 - 136ms/epoch - 15ms/step
# Epoch 132/300
#
# Epoch 132: val_loss improved from 0.74915 to 0.73892, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.5317 - accuracy: 0.8958 - val_loss: 0.7389 - val_accuracy: 0.7083 - 140ms/epoch - 16ms/step
# Epoch 133/300
#
# Epoch 133: val_loss did not improve from 0.73892
# 9/9 - 0s - loss: 0.5050 - accuracy: 0.8472 - val_loss: 0.7682 - val_accuracy: 0.7500 - 160ms/epoch - 18ms/step
# Epoch 134/300
#
# Epoch 134: val_loss did not improve from 0.73892
# 9/9 - 0s - loss: 0.5052 - accuracy: 0.8889 - val_loss: 0.7769 - val_accuracy: 0.7083 - 132ms/epoch - 15ms/step
# Epoch 135/300
#
# Epoch 135: val_loss did not improve from 0.73892
# 9/9 - 0s - loss: 0.5088 - accuracy: 0.8819 - val_loss: 0.7561 - val_accuracy: 0.7778 - 133ms/epoch - 15ms/step
# Epoch 136/300
#
# Epoch 136: val_loss improved from 0.73892 to 0.71764, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.4925 - accuracy: 0.8819 - val_loss: 0.7176 - val_accuracy: 0.7917 - 136ms/epoch - 15ms/step
# Epoch 137/300
#
# Epoch 137: val_loss did not improve from 0.71764
# 9/9 - 0s - loss: 0.5168 - accuracy: 0.8472 - val_loss: 0.7338 - val_accuracy: 0.7083 - 132ms/epoch - 15ms/step
# Epoch 138/300
#
# Epoch 138: val_loss did not improve from 0.71764
# 9/9 - 0s - loss: 0.5494 - accuracy: 0.8611 - val_loss: 0.7957 - val_accuracy: 0.7083 - 135ms/epoch - 15ms/step
# Epoch 139/300
#
# Epoch 139: val_loss did not improve from 0.71764
# 9/9 - 0s - loss: 0.5446 - accuracy: 0.8472 - val_loss: 0.7609 - val_accuracy: 0.7222 - 131ms/epoch - 15ms/step
# Epoch 140/300
#
# Epoch 140: val_loss did not improve from 0.71764
# 9/9 - 0s - loss: 0.5381 - accuracy: 0.8194 - val_loss: 0.7436 - val_accuracy: 0.7361 - 131ms/epoch - 15ms/step
# Epoch 141/300
#
# Epoch 141: val_loss did not improve from 0.71764
# 9/9 - 0s - loss: 0.4930 - accuracy: 0.8750 - val_loss: 0.7551 - val_accuracy: 0.6944 - 130ms/epoch - 14ms/step
# Epoch 142/300
#
# Epoch 142: val_loss did not improve from 0.71764
# 9/9 - 0s - loss: 0.5031 - accuracy: 0.8889 - val_loss: 0.7593 - val_accuracy: 0.7083 - 130ms/epoch - 14ms/step
# Epoch 143/300
#
# Epoch 143: val_loss did not improve from 0.71764
# 9/9 - 0s - loss: 0.5131 - accuracy: 0.8819 - val_loss: 0.7845 - val_accuracy: 0.7083 - 131ms/epoch - 15ms/step
# Epoch 144/300
#
# Epoch 144: val_loss did not improve from 0.71764
# 9/9 - 0s - loss: 0.5098 - accuracy: 0.9097 - val_loss: 0.7565 - val_accuracy: 0.7778 - 132ms/epoch - 15ms/step
# Epoch 145/300
#
# Epoch 145: val_loss did not improve from 0.71764
# 9/9 - 0s - loss: 0.4755 - accuracy: 0.9028 - val_loss: 0.7494 - val_accuracy: 0.7361 - 138ms/epoch - 15ms/step
# Epoch 146/300
#
# Epoch 146: val_loss did not improve from 0.71764
# 9/9 - 0s - loss: 0.5103 - accuracy: 0.8819 - val_loss: 0.7298 - val_accuracy: 0.7917 - 135ms/epoch - 15ms/step
# Epoch 147/300
#
# Epoch 147: val_loss did not improve from 0.71764
# 9/9 - 0s - loss: 0.5393 - accuracy: 0.8403 - val_loss: 0.7550 - val_accuracy: 0.7361 - 134ms/epoch - 15ms/step
# Epoch 148/300
#
# Epoch 148: val_loss did not improve from 0.71764
# 9/9 - 0s - loss: 0.4643 - accuracy: 0.9375 - val_loss: 0.7434 - val_accuracy: 0.7361 - 156ms/epoch - 17ms/step
# Epoch 149/300
#
# Epoch 149: val_loss did not improve from 0.71764
# 9/9 - 0s - loss: 0.4950 - accuracy: 0.8542 - val_loss: 0.7729 - val_accuracy: 0.7361 - 138ms/epoch - 15ms/step
# Epoch 150/300
#
# Epoch 150: val_loss improved from 0.71764 to 0.71295, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.4878 - accuracy: 0.8889 - val_loss: 0.7129 - val_accuracy: 0.7500 - 143ms/epoch - 16ms/step
# Epoch 151/300
#
# Epoch 151: val_loss did not improve from 0.71295
# 9/9 - 0s - loss: 0.5234 - accuracy: 0.8750 - val_loss: 0.7271 - val_accuracy: 0.7222 - 134ms/epoch - 15ms/step
# Epoch 152/300
#
# Epoch 152: val_loss did not improve from 0.71295
# 9/9 - 0s - loss: 0.5250 - accuracy: 0.8542 - val_loss: 0.7555 - val_accuracy: 0.7361 - 131ms/epoch - 15ms/step
# Epoch 153/300
#
# Epoch 153: val_loss did not improve from 0.71295
# 9/9 - 0s - loss: 0.4752 - accuracy: 0.8750 - val_loss: 0.7494 - val_accuracy: 0.7083 - 132ms/epoch - 15ms/step
# Epoch 154/300
#
# Epoch 154: val_loss did not improve from 0.71295
# 9/9 - 0s - loss: 0.5050 - accuracy: 0.8194 - val_loss: 0.7301 - val_accuracy: 0.7361 - 131ms/epoch - 15ms/step
# Epoch 155/300
#
# Epoch 155: val_loss did not improve from 0.71295
# 9/9 - 0s - loss: 0.4680 - accuracy: 0.9028 - val_loss: 0.7235 - val_accuracy: 0.7639 - 130ms/epoch - 14ms/step
# Epoch 156/300
#
# Epoch 156: val_loss did not improve from 0.71295
# 9/9 - 0s - loss: 0.4923 - accuracy: 0.8681 - val_loss: 0.7150 - val_accuracy: 0.7500 - 133ms/epoch - 15ms/step
# Epoch 157/300
#
# Epoch 157: val_loss improved from 0.71295 to 0.67997, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.5439 - accuracy: 0.8264 - val_loss: 0.6800 - val_accuracy: 0.7222 - 138ms/epoch - 15ms/step
# Epoch 158/300
#
# Epoch 158: val_loss did not improve from 0.67997
# 9/9 - 0s - loss: 0.4728 - accuracy: 0.8750 - val_loss: 0.7154 - val_accuracy: 0.7500 - 132ms/epoch - 15ms/step
# Epoch 159/300
#
# Epoch 159: val_loss did not improve from 0.67997
# 9/9 - 0s - loss: 0.4542 - accuracy: 0.8681 - val_loss: 0.7154 - val_accuracy: 0.6944 - 134ms/epoch - 15ms/step
# Epoch 160/300
#
# Epoch 160: val_loss did not improve from 0.67997
# 9/9 - 0s - loss: 0.4720 - accuracy: 0.8889 - val_loss: 0.7335 - val_accuracy: 0.6944 - 134ms/epoch - 15ms/step
# Epoch 161/300
#
# Epoch 161: val_loss did not improve from 0.67997
# 9/9 - 0s - loss: 0.5028 - accuracy: 0.8403 - val_loss: 0.6923 - val_accuracy: 0.7778 - 133ms/epoch - 15ms/step
# Epoch 162/300
#
# Epoch 162: val_loss did not improve from 0.67997
# 9/9 - 0s - loss: 0.4817 - accuracy: 0.8889 - val_loss: 0.7013 - val_accuracy: 0.7361 - 134ms/epoch - 15ms/step
# Epoch 163/300
#
# Epoch 163: val_loss did not improve from 0.67997
# 9/9 - 0s - loss: 0.4856 - accuracy: 0.8611 - val_loss: 0.6851 - val_accuracy: 0.7639 - 132ms/epoch - 15ms/step
# Epoch 164/300
#
# Epoch 164: val_loss did not improve from 0.67997
# 9/9 - 0s - loss: 0.4441 - accuracy: 0.8889 - val_loss: 0.6846 - val_accuracy: 0.7222 - 135ms/epoch - 15ms/step
# Epoch 165/300
#
# Epoch 165: val_loss did not improve from 0.67997
# 9/9 - 0s - loss: 0.4351 - accuracy: 0.8958 - val_loss: 0.7202 - val_accuracy: 0.7639 - 136ms/epoch - 15ms/step
# Epoch 166/300
#
# Epoch 166: val_loss improved from 0.67997 to 0.67662, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.4267 - accuracy: 0.9097 - val_loss: 0.6766 - val_accuracy: 0.7917 - 142ms/epoch - 16ms/step
# Epoch 167/300
#
# Epoch 167: val_loss did not improve from 0.67662
# 9/9 - 0s - loss: 0.4367 - accuracy: 0.9097 - val_loss: 0.6894 - val_accuracy: 0.7639 - 136ms/epoch - 15ms/step
# Epoch 168/300
#
# Epoch 168: val_loss improved from 0.67662 to 0.66424, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.4413 - accuracy: 0.8889 - val_loss: 0.6642 - val_accuracy: 0.7500 - 139ms/epoch - 15ms/step
# Epoch 169/300
#
# Epoch 169: val_loss did not improve from 0.66424
# 9/9 - 0s - loss: 0.4678 - accuracy: 0.8681 - val_loss: 0.7562 - val_accuracy: 0.6667 - 137ms/epoch - 15ms/step
# Epoch 170/300
#
# Epoch 170: val_loss did not improve from 0.66424
# 9/9 - 0s - loss: 0.4819 - accuracy: 0.8472 - val_loss: 0.6847 - val_accuracy: 0.7500 - 135ms/epoch - 15ms/step
# Epoch 171/300
#
# Epoch 171: val_loss did not improve from 0.66424
# 9/9 - 0s - loss: 0.4770 - accuracy: 0.8750 - val_loss: 0.6932 - val_accuracy: 0.7917 - 138ms/epoch - 15ms/step
# Epoch 172/300
#
# Epoch 172: val_loss did not improve from 0.66424
# 9/9 - 0s - loss: 0.4327 - accuracy: 0.9236 - val_loss: 0.6769 - val_accuracy: 0.7917 - 135ms/epoch - 15ms/step
# Epoch 173/300
#
# Epoch 173: val_loss did not improve from 0.66424
# 9/9 - 0s - loss: 0.4571 - accuracy: 0.8958 - val_loss: 0.6866 - val_accuracy: 0.7639 - 140ms/epoch - 16ms/step
# Epoch 174/300
#
# Epoch 174: val_loss did not improve from 0.66424
# 9/9 - 0s - loss: 0.3888 - accuracy: 0.9306 - val_loss: 0.7122 - val_accuracy: 0.7361 - 133ms/epoch - 15ms/step
# Epoch 175/300
#
# Epoch 175: val_loss did not improve from 0.66424
# 9/9 - 0s - loss: 0.4257 - accuracy: 0.9097 - val_loss: 0.7111 - val_accuracy: 0.7361 - 135ms/epoch - 15ms/step
# Epoch 176/300
#
# Epoch 176: val_loss did not improve from 0.66424
# 9/9 - 0s - loss: 0.4292 - accuracy: 0.9444 - val_loss: 0.6859 - val_accuracy: 0.7361 - 137ms/epoch - 15ms/step
# Epoch 177/300
#
# Epoch 177: val_loss did not improve from 0.66424
# 9/9 - 0s - loss: 0.4017 - accuracy: 0.9097 - val_loss: 0.7143 - val_accuracy: 0.7500 - 134ms/epoch - 15ms/step
# Epoch 178/300
#
# Epoch 178: val_loss did not improve from 0.66424
# 9/9 - 0s - loss: 0.4576 - accuracy: 0.8889 - val_loss: 0.6774 - val_accuracy: 0.7917 - 135ms/epoch - 15ms/step
# Epoch 179/300
#
# Epoch 179: val_loss did not improve from 0.66424
# 9/9 - 0s - loss: 0.4496 - accuracy: 0.8889 - val_loss: 0.6944 - val_accuracy: 0.7639 - 136ms/epoch - 15ms/step
# Epoch 180/300
#
# Epoch 180: val_loss improved from 0.66424 to 0.64426, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.4416 - accuracy: 0.8611 - val_loss: 0.6443 - val_accuracy: 0.8194 - 138ms/epoch - 15ms/step
# Epoch 181/300
#
# Epoch 181: val_loss did not improve from 0.64426
# 9/9 - 0s - loss: 0.4010 - accuracy: 0.9028 - val_loss: 0.6443 - val_accuracy: 0.7917 - 132ms/epoch - 15ms/step
# Epoch 182/300
#
# Epoch 182: val_loss did not improve from 0.64426
# 9/9 - 0s - loss: 0.4292 - accuracy: 0.8958 - val_loss: 0.6653 - val_accuracy: 0.7639 - 131ms/epoch - 15ms/step
# Epoch 183/300
#
# Epoch 183: val_loss did not improve from 0.64426
# 9/9 - 0s - loss: 0.4051 - accuracy: 0.9097 - val_loss: 0.6685 - val_accuracy: 0.8056 - 135ms/epoch - 15ms/step
# Epoch 184/300
#
# Epoch 184: val_loss improved from 0.64426 to 0.63774, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.3909 - accuracy: 0.9236 - val_loss: 0.6377 - val_accuracy: 0.7917 - 141ms/epoch - 16ms/step
# Epoch 185/300
#
# Epoch 185: val_loss did not improve from 0.63774
# 9/9 - 0s - loss: 0.4142 - accuracy: 0.9097 - val_loss: 0.6510 - val_accuracy: 0.7500 - 138ms/epoch - 15ms/step
# Epoch 186/300
#
# Epoch 186: val_loss did not improve from 0.63774
# 9/9 - 0s - loss: 0.4208 - accuracy: 0.9236 - val_loss: 0.6780 - val_accuracy: 0.8333 - 132ms/epoch - 15ms/step
# Epoch 187/300
#
# Epoch 187: val_loss improved from 0.63774 to 0.61263, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.4336 - accuracy: 0.9097 - val_loss: 0.6126 - val_accuracy: 0.8194 - 137ms/epoch - 15ms/step
# Epoch 188/300
#
# Epoch 188: val_loss did not improve from 0.61263
# 9/9 - 0s - loss: 0.4289 - accuracy: 0.9097 - val_loss: 0.6481 - val_accuracy: 0.7917 - 132ms/epoch - 15ms/step
# Epoch 189/300
#
# Epoch 189: val_loss did not improve from 0.61263
# 9/9 - 0s - loss: 0.4236 - accuracy: 0.8819 - val_loss: 0.6396 - val_accuracy: 0.8194 - 135ms/epoch - 15ms/step
# Epoch 190/300
#
# Epoch 190: val_loss did not improve from 0.61263
# 9/9 - 0s - loss: 0.4429 - accuracy: 0.8819 - val_loss: 0.6489 - val_accuracy: 0.8056 - 137ms/epoch - 15ms/step
# Epoch 191/300
#
# Epoch 191: val_loss did not improve from 0.61263
# 9/9 - 0s - loss: 0.4097 - accuracy: 0.8889 - val_loss: 0.6402 - val_accuracy: 0.8056 - 134ms/epoch - 15ms/step
# Epoch 192/300
#
# Epoch 192: val_loss did not improve from 0.61263
# 9/9 - 0s - loss: 0.4151 - accuracy: 0.9167 - val_loss: 0.6477 - val_accuracy: 0.8056 - 133ms/epoch - 15ms/step
# Epoch 193/300
#
# Epoch 193: val_loss improved from 0.61263 to 0.59083, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.3922 - accuracy: 0.8819 - val_loss: 0.5908 - val_accuracy: 0.8194 - 139ms/epoch - 15ms/step
# Epoch 194/300
#
# Epoch 194: val_loss improved from 0.59083 to 0.57912, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.3632 - accuracy: 0.9167 - val_loss: 0.5791 - val_accuracy: 0.8611 - 139ms/epoch - 15ms/step
# Epoch 195/300
#
# Epoch 195: val_loss did not improve from 0.57912
# 9/9 - 0s - loss: 0.3843 - accuracy: 0.9306 - val_loss: 0.5918 - val_accuracy: 0.8194 - 133ms/epoch - 15ms/step
# Epoch 196/300
#
# Epoch 196: val_loss improved from 0.57912 to 0.55378, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.3552 - accuracy: 0.9583 - val_loss: 0.5538 - val_accuracy: 0.8750 - 196ms/epoch - 22ms/step
# Epoch 197/300
#
# Epoch 197: val_loss did not improve from 0.55378
# 9/9 - 0s - loss: 0.3462 - accuracy: 0.9306 - val_loss: 0.5730 - val_accuracy: 0.8333 - 143ms/epoch - 16ms/step
# Epoch 198/300
#
# Epoch 198: val_loss did not improve from 0.55378
# 9/9 - 0s - loss: 0.3274 - accuracy: 0.9444 - val_loss: 0.5838 - val_accuracy: 0.8611 - 142ms/epoch - 16ms/step
# Epoch 199/300
#
# Epoch 199: val_loss did not improve from 0.55378
# 9/9 - 0s - loss: 0.3884 - accuracy: 0.9375 - val_loss: 0.6416 - val_accuracy: 0.7917 - 135ms/epoch - 15ms/step
# Epoch 200/300
#
# Epoch 200: val_loss did not improve from 0.55378
# 9/9 - 0s - loss: 0.3490 - accuracy: 0.9306 - val_loss: 0.6188 - val_accuracy: 0.7917 - 161ms/epoch - 18ms/step
# Epoch 201/300
#
# Epoch 201: val_loss did not improve from 0.55378
# 9/9 - 0s - loss: 0.3594 - accuracy: 0.9167 - val_loss: 0.6063 - val_accuracy: 0.8333 - 140ms/epoch - 16ms/step
# Epoch 202/300
#
# Epoch 202: val_loss did not improve from 0.55378
# 9/9 - 0s - loss: 0.3778 - accuracy: 0.8958 - val_loss: 0.6877 - val_accuracy: 0.7361 - 133ms/epoch - 15ms/step
# Epoch 203/300
#
# Epoch 203: val_loss did not improve from 0.55378
# 9/9 - 0s - loss: 0.4201 - accuracy: 0.8542 - val_loss: 0.6151 - val_accuracy: 0.8333 - 135ms/epoch - 15ms/step
# Epoch 204/300
#
# Epoch 204: val_loss did not improve from 0.55378
# 9/9 - 0s - loss: 0.3824 - accuracy: 0.8819 - val_loss: 0.5836 - val_accuracy: 0.8056 - 132ms/epoch - 15ms/step
# Epoch 205/300
#
# Epoch 205: val_loss did not improve from 0.55378
# 9/9 - 0s - loss: 0.3218 - accuracy: 0.9028 - val_loss: 0.5748 - val_accuracy: 0.8472 - 177ms/epoch - 20ms/step
# Epoch 206/300
#
# Epoch 206: val_loss did not improve from 0.55378
# 9/9 - 0s - loss: 0.3254 - accuracy: 0.9653 - val_loss: 0.5959 - val_accuracy: 0.8333 - 182ms/epoch - 20ms/step
# Epoch 207/300
#
# Epoch 207: val_loss did not improve from 0.55378
# 9/9 - 0s - loss: 0.3541 - accuracy: 0.9375 - val_loss: 0.5606 - val_accuracy: 0.7917 - 135ms/epoch - 15ms/step
# Epoch 208/300
#
# Epoch 208: val_loss did not improve from 0.55378
# 9/9 - 0s - loss: 0.3805 - accuracy: 0.9167 - val_loss: 0.6097 - val_accuracy: 0.8194 - 130ms/epoch - 14ms/step
# Epoch 209/300
#
# Epoch 209: val_loss did not improve from 0.55378
# 9/9 - 0s - loss: 0.3733 - accuracy: 0.9097 - val_loss: 0.5705 - val_accuracy: 0.7500 - 130ms/epoch - 14ms/step
# Epoch 210/300
#
# Epoch 210: val_loss did not improve from 0.55378
# 9/9 - 0s - loss: 0.3893 - accuracy: 0.9028 - val_loss: 0.6235 - val_accuracy: 0.8056 - 132ms/epoch - 15ms/step
# Epoch 211/300
#
# Epoch 211: val_loss did not improve from 0.55378
# 9/9 - 0s - loss: 0.3957 - accuracy: 0.8889 - val_loss: 0.5858 - val_accuracy: 0.7917 - 130ms/epoch - 14ms/step
# Epoch 212/300
#
# Epoch 212: val_loss did not improve from 0.55378
# 9/9 - 0s - loss: 0.3718 - accuracy: 0.9028 - val_loss: 0.5880 - val_accuracy: 0.7778 - 132ms/epoch - 15ms/step
# Epoch 213/300
#
# Epoch 213: val_loss did not improve from 0.55378
# 9/9 - 0s - loss: 0.3437 - accuracy: 0.9097 - val_loss: 0.6044 - val_accuracy: 0.7917 - 132ms/epoch - 15ms/step
# Epoch 214/300
#
# Epoch 214: val_loss did not improve from 0.55378
# 9/9 - 0s - loss: 0.3326 - accuracy: 0.9306 - val_loss: 0.6093 - val_accuracy: 0.8194 - 132ms/epoch - 15ms/step
# Epoch 215/300
#
# Epoch 215: val_loss did not improve from 0.55378
# 9/9 - 0s - loss: 0.3624 - accuracy: 0.9306 - val_loss: 0.5918 - val_accuracy: 0.8194 - 139ms/epoch - 15ms/step
# Epoch 216/300
#
# Epoch 216: val_loss did not improve from 0.55378
# 9/9 - 0s - loss: 0.3495 - accuracy: 0.9236 - val_loss: 0.6070 - val_accuracy: 0.7917 - 149ms/epoch - 17ms/step
# Epoch 217/300
#
# Epoch 217: val_loss improved from 0.55378 to 0.52456, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.3508 - accuracy: 0.9097 - val_loss: 0.5246 - val_accuracy: 0.8611 - 138ms/epoch - 15ms/step
# Epoch 218/300
#
# Epoch 218: val_loss did not improve from 0.52456
# 9/9 - 0s - loss: 0.3479 - accuracy: 0.9236 - val_loss: 0.5978 - val_accuracy: 0.8056 - 139ms/epoch - 15ms/step
# Epoch 219/300
#
# Epoch 219: val_loss did not improve from 0.52456
# 9/9 - 0s - loss: 0.3289 - accuracy: 0.9375 - val_loss: 0.6365 - val_accuracy: 0.7639 - 135ms/epoch - 15ms/step
# Epoch 220/300
#
# Epoch 220: val_loss did not improve from 0.52456
# 9/9 - 0s - loss: 0.2876 - accuracy: 0.9583 - val_loss: 0.5766 - val_accuracy: 0.8333 - 134ms/epoch - 15ms/step
# Epoch 221/300
#
# Epoch 221: val_loss did not improve from 0.52456
# 9/9 - 0s - loss: 0.3034 - accuracy: 0.9306 - val_loss: 0.5461 - val_accuracy: 0.8750 - 135ms/epoch - 15ms/step
# Epoch 222/300
#
# Epoch 222: val_loss did not improve from 0.52456
# 9/9 - 0s - loss: 0.3491 - accuracy: 0.9028 - val_loss: 0.5999 - val_accuracy: 0.7917 - 134ms/epoch - 15ms/step
# Epoch 223/300
#
# Epoch 223: val_loss did not improve from 0.52456
# 9/9 - 0s - loss: 0.3142 - accuracy: 0.9514 - val_loss: 0.5506 - val_accuracy: 0.8472 - 164ms/epoch - 18ms/step
# Epoch 224/300
#
# Epoch 224: val_loss did not improve from 0.52456
# 9/9 - 0s - loss: 0.3021 - accuracy: 0.9375 - val_loss: 0.5931 - val_accuracy: 0.7917 - 146ms/epoch - 16ms/step
# Epoch 225/300
#
# Epoch 225: val_loss did not improve from 0.52456
# 9/9 - 0s - loss: 0.3367 - accuracy: 0.9306 - val_loss: 0.5546 - val_accuracy: 0.8194 - 133ms/epoch - 15ms/step
# Epoch 226/300
#
# Epoch 226: val_loss did not improve from 0.52456
# 9/9 - 0s - loss: 0.3409 - accuracy: 0.8889 - val_loss: 0.5395 - val_accuracy: 0.7917 - 128ms/epoch - 14ms/step
# Epoch 227/300
#
# Epoch 227: val_loss did not improve from 0.52456
# 9/9 - 0s - loss: 0.3977 - accuracy: 0.8958 - val_loss: 0.5631 - val_accuracy: 0.8194 - 132ms/epoch - 15ms/step
# Epoch 228/300
#
# Epoch 228: val_loss did not improve from 0.52456
# 9/9 - 0s - loss: 0.3258 - accuracy: 0.9028 - val_loss: 0.5658 - val_accuracy: 0.7639 - 133ms/epoch - 15ms/step
# Epoch 229/300
#
# Epoch 229: val_loss did not improve from 0.52456
# 9/9 - 0s - loss: 0.3371 - accuracy: 0.9236 - val_loss: 0.5363 - val_accuracy: 0.8194 - 131ms/epoch - 15ms/step
# Epoch 230/300
#
# Epoch 230: val_loss improved from 0.52456 to 0.51356, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.3061 - accuracy: 0.9375 - val_loss: 0.5136 - val_accuracy: 0.8333 - 188ms/epoch - 21ms/step
# Epoch 231/300
#
# Epoch 231: val_loss did not improve from 0.51356
# 9/9 - 0s - loss: 0.3560 - accuracy: 0.9236 - val_loss: 0.5555 - val_accuracy: 0.7917 - 141ms/epoch - 16ms/step
# Epoch 232/300
#
# Epoch 232: val_loss did not improve from 0.51356
# 9/9 - 0s - loss: 0.2995 - accuracy: 0.9306 - val_loss: 0.5696 - val_accuracy: 0.8333 - 135ms/epoch - 15ms/step
# Epoch 233/300
#
# Epoch 233: val_loss did not improve from 0.51356
# 9/9 - 0s - loss: 0.3174 - accuracy: 0.9444 - val_loss: 0.5515 - val_accuracy: 0.8056 - 138ms/epoch - 15ms/step
# Epoch 234/300
#
# Epoch 234: val_loss did not improve from 0.51356
# 9/9 - 0s - loss: 0.2914 - accuracy: 0.9167 - val_loss: 0.5845 - val_accuracy: 0.7917 - 135ms/epoch - 15ms/step
# Epoch 235/300
#
# Epoch 235: val_loss did not improve from 0.51356
# 9/9 - 0s - loss: 0.3552 - accuracy: 0.9167 - val_loss: 0.5935 - val_accuracy: 0.7778 - 132ms/epoch - 15ms/step
# Epoch 236/300
#
# Epoch 236: val_loss did not improve from 0.51356
# 9/9 - 0s - loss: 0.3700 - accuracy: 0.8750 - val_loss: 0.5543 - val_accuracy: 0.8333 - 133ms/epoch - 15ms/step
# Epoch 237/300
#
# Epoch 237: val_loss did not improve from 0.51356
# 9/9 - 0s - loss: 0.2852 - accuracy: 0.9375 - val_loss: 0.5593 - val_accuracy: 0.7917 - 132ms/epoch - 15ms/step
# Epoch 238/300
#
# Epoch 238: val_loss did not improve from 0.51356
# 9/9 - 0s - loss: 0.3157 - accuracy: 0.9167 - val_loss: 0.5302 - val_accuracy: 0.8472 - 134ms/epoch - 15ms/step
# Epoch 239/300
#
# Epoch 239: val_loss did not improve from 0.51356
# 9/9 - 0s - loss: 0.2799 - accuracy: 0.9375 - val_loss: 0.6325 - val_accuracy: 0.7639 - 133ms/epoch - 15ms/step
# Epoch 240/300
#
# Epoch 240: val_loss did not improve from 0.51356
# 9/9 - 0s - loss: 0.2890 - accuracy: 0.9167 - val_loss: 0.5179 - val_accuracy: 0.8611 - 134ms/epoch - 15ms/step
# Epoch 241/300
#
# Epoch 241: val_loss did not improve from 0.51356
# 9/9 - 0s - loss: 0.3457 - accuracy: 0.9236 - val_loss: 0.5744 - val_accuracy: 0.7639 - 138ms/epoch - 15ms/step
# Epoch 242/300
#
# Epoch 242: val_loss did not improve from 0.51356
# 9/9 - 0s - loss: 0.2915 - accuracy: 0.9236 - val_loss: 0.5542 - val_accuracy: 0.8056 - 136ms/epoch - 15ms/step
# Epoch 243/300
#
# Epoch 243: val_loss improved from 0.51356 to 0.48975, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.2787 - accuracy: 0.9583 - val_loss: 0.4898 - val_accuracy: 0.8472 - 137ms/epoch - 15ms/step
# Epoch 244/300
#
# Epoch 244: val_loss did not improve from 0.48975
# 9/9 - 0s - loss: 0.3657 - accuracy: 0.9097 - val_loss: 0.5541 - val_accuracy: 0.8194 - 133ms/epoch - 15ms/step
# Epoch 245/300
#
# Epoch 245: val_loss did not improve from 0.48975
# 9/9 - 0s - loss: 0.3082 - accuracy: 0.9375 - val_loss: 0.5325 - val_accuracy: 0.8056 - 131ms/epoch - 15ms/step
# Epoch 246/300
#
# Epoch 246: val_loss did not improve from 0.48975
# 9/9 - 0s - loss: 0.2746 - accuracy: 0.9653 - val_loss: 0.5372 - val_accuracy: 0.8194 - 130ms/epoch - 14ms/step
# Epoch 247/300
#
# Epoch 247: val_loss did not improve from 0.48975
# 9/9 - 0s - loss: 0.2467 - accuracy: 0.9653 - val_loss: 0.6530 - val_accuracy: 0.7361 - 130ms/epoch - 14ms/step
# Epoch 248/300
#
# Epoch 248: val_loss did not improve from 0.48975
# 9/9 - 0s - loss: 0.2912 - accuracy: 0.9514 - val_loss: 0.5187 - val_accuracy: 0.8333 - 132ms/epoch - 15ms/step
# Epoch 249/300
#
# Epoch 249: val_loss did not improve from 0.48975
# 9/9 - 0s - loss: 0.3044 - accuracy: 0.9375 - val_loss: 0.5019 - val_accuracy: 0.8472 - 130ms/epoch - 14ms/step
# Epoch 250/300
#
# Epoch 250: val_loss did not improve from 0.48975
# 9/9 - 0s - loss: 0.2556 - accuracy: 0.9514 - val_loss: 0.5631 - val_accuracy: 0.8056 - 135ms/epoch - 15ms/step
# Epoch 251/300
#
# Epoch 251: val_loss did not improve from 0.48975
# 9/9 - 0s - loss: 0.2946 - accuracy: 0.9097 - val_loss: 0.5503 - val_accuracy: 0.8194 - 133ms/epoch - 15ms/step
# Epoch 252/300
#
# Epoch 252: val_loss did not improve from 0.48975
# 9/9 - 0s - loss: 0.2629 - accuracy: 0.9514 - val_loss: 0.4970 - val_accuracy: 0.8611 - 134ms/epoch - 15ms/step
# Epoch 253/300
#
# Epoch 253: val_loss did not improve from 0.48975
# 9/9 - 0s - loss: 0.2344 - accuracy: 0.9722 - val_loss: 0.4935 - val_accuracy: 0.8611 - 131ms/epoch - 15ms/step
# Epoch 254/300
#
# Epoch 254: val_loss did not improve from 0.48975
# 9/9 - 0s - loss: 0.2678 - accuracy: 0.9514 - val_loss: 0.5319 - val_accuracy: 0.8333 - 131ms/epoch - 15ms/step
# Epoch 255/300
#
# Epoch 255: val_loss did not improve from 0.48975
# 9/9 - 0s - loss: 0.3134 - accuracy: 0.9097 - val_loss: 0.5643 - val_accuracy: 0.8194 - 129ms/epoch - 14ms/step
# Epoch 256/300
#
# Epoch 256: val_loss did not improve from 0.48975
# 9/9 - 0s - loss: 0.3011 - accuracy: 0.9097 - val_loss: 0.5867 - val_accuracy: 0.7917 - 132ms/epoch - 15ms/step
# Epoch 257/300
#
# Epoch 257: val_loss did not improve from 0.48975
# 9/9 - 0s - loss: 0.2689 - accuracy: 0.9514 - val_loss: 0.5857 - val_accuracy: 0.7500 - 129ms/epoch - 14ms/step
# Epoch 258/300
#
# Epoch 258: val_loss did not improve from 0.48975
# 9/9 - 0s - loss: 0.2778 - accuracy: 0.9444 - val_loss: 0.5404 - val_accuracy: 0.8333 - 134ms/epoch - 15ms/step
# Epoch 259/300
#
# Epoch 259: val_loss did not improve from 0.48975
# 9/9 - 0s - loss: 0.2995 - accuracy: 0.9167 - val_loss: 0.4984 - val_accuracy: 0.8472 - 158ms/epoch - 18ms/step
# Epoch 260/300
#
# Epoch 260: val_loss did not improve from 0.48975
# 9/9 - 0s - loss: 0.2803 - accuracy: 0.9375 - val_loss: 0.5532 - val_accuracy: 0.8194 - 133ms/epoch - 15ms/step
# Epoch 261/300
#
# Epoch 261: val_loss improved from 0.48975 to 0.48270, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.2892 - accuracy: 0.9236 - val_loss: 0.4827 - val_accuracy: 0.8750 - 139ms/epoch - 15ms/step
# Epoch 262/300
#
# Epoch 262: val_loss did not improve from 0.48270
# 9/9 - 0s - loss: 0.2979 - accuracy: 0.9306 - val_loss: 0.5362 - val_accuracy: 0.7917 - 133ms/epoch - 15ms/step
# Epoch 263/300
#
# Epoch 263: val_loss did not improve from 0.48270
# 9/9 - 0s - loss: 0.3178 - accuracy: 0.9236 - val_loss: 0.5133 - val_accuracy: 0.8056 - 133ms/epoch - 15ms/step
# Epoch 264/300
#
# Epoch 264: val_loss improved from 0.48270 to 0.47672, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.2934 - accuracy: 0.9583 - val_loss: 0.4767 - val_accuracy: 0.8750 - 137ms/epoch - 15ms/step
# Epoch 265/300
#
# Epoch 265: val_loss did not improve from 0.47672
# 9/9 - 0s - loss: 0.3053 - accuracy: 0.9167 - val_loss: 0.5728 - val_accuracy: 0.8194 - 135ms/epoch - 15ms/step
# Epoch 266/300
#
# Epoch 266: val_loss did not improve from 0.47672
# 9/9 - 0s - loss: 0.2948 - accuracy: 0.9375 - val_loss: 0.4780 - val_accuracy: 0.8472 - 136ms/epoch - 15ms/step
# Epoch 267/300
#
# Epoch 267: val_loss improved from 0.47672 to 0.46523, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.2600 - accuracy: 0.9444 - val_loss: 0.4652 - val_accuracy: 0.8889 - 140ms/epoch - 16ms/step
# Epoch 268/300
#
# Epoch 268: val_loss did not improve from 0.46523
# 9/9 - 0s - loss: 0.2789 - accuracy: 0.9444 - val_loss: 0.5434 - val_accuracy: 0.7917 - 135ms/epoch - 15ms/step
# Epoch 269/300
#
# Epoch 269: val_loss improved from 0.46523 to 0.46311, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.2619 - accuracy: 0.9583 - val_loss: 0.4631 - val_accuracy: 0.8611 - 138ms/epoch - 15ms/step
# Epoch 270/300
#
# Epoch 270: val_loss did not improve from 0.46311
# 9/9 - 0s - loss: 0.2544 - accuracy: 0.9514 - val_loss: 0.5248 - val_accuracy: 0.8611 - 133ms/epoch - 15ms/step
# Epoch 271/300
#
# Epoch 271: val_loss did not improve from 0.46311
# 9/9 - 0s - loss: 0.2591 - accuracy: 0.9583 - val_loss: 0.5179 - val_accuracy: 0.8333 - 137ms/epoch - 15ms/step
# Epoch 272/300
#
# Epoch 272: val_loss did not improve from 0.46311
# 9/9 - 0s - loss: 0.2460 - accuracy: 0.9514 - val_loss: 0.5246 - val_accuracy: 0.8333 - 133ms/epoch - 15ms/step
# Epoch 273/300
#
# Epoch 273: val_loss did not improve from 0.46311
# 9/9 - 0s - loss: 0.2705 - accuracy: 0.9375 - val_loss: 0.5239 - val_accuracy: 0.8333 - 137ms/epoch - 15ms/step
# Epoch 274/300
#
# Epoch 274: val_loss did not improve from 0.46311
# 9/9 - 0s - loss: 0.2424 - accuracy: 0.9792 - val_loss: 0.5445 - val_accuracy: 0.8194 - 135ms/epoch - 15ms/step
# Epoch 275/300
#
# Epoch 275: val_loss did not improve from 0.46311
# 9/9 - 0s - loss: 0.3018 - accuracy: 0.9444 - val_loss: 0.5356 - val_accuracy: 0.8194 - 135ms/epoch - 15ms/step
# Epoch 276/300
#
# Epoch 276: val_loss did not improve from 0.46311
# 9/9 - 0s - loss: 0.3290 - accuracy: 0.9097 - val_loss: 0.5542 - val_accuracy: 0.7917 - 136ms/epoch - 15ms/step
# Epoch 277/300
#
# Epoch 277: val_loss did not improve from 0.46311
# 9/9 - 0s - loss: 0.2990 - accuracy: 0.9028 - val_loss: 0.4877 - val_accuracy: 0.8333 - 134ms/epoch - 15ms/step
# Epoch 278/300
#
# Epoch 278: val_loss did not improve from 0.46311
# 9/9 - 0s - loss: 0.2278 - accuracy: 0.9722 - val_loss: 0.5762 - val_accuracy: 0.8611 - 137ms/epoch - 15ms/step
# Epoch 279/300
#
# Epoch 279: val_loss did not improve from 0.46311
# 9/9 - 0s - loss: 0.2488 - accuracy: 0.9444 - val_loss: 0.4742 - val_accuracy: 0.8472 - 135ms/epoch - 15ms/step
# Epoch 280/300
#
# Epoch 280: val_loss did not improve from 0.46311
# 9/9 - 0s - loss: 0.2416 - accuracy: 0.9514 - val_loss: 0.4678 - val_accuracy: 0.8750 - 135ms/epoch - 15ms/step
# Epoch 281/300
#
# Epoch 281: val_loss did not improve from 0.46311
# 9/9 - 0s - loss: 0.1947 - accuracy: 0.9792 - val_loss: 0.4640 - val_accuracy: 0.9028 - 137ms/epoch - 15ms/step
# Epoch 282/300
#
# Epoch 282: val_loss did not improve from 0.46311
# 9/9 - 0s - loss: 0.2165 - accuracy: 0.9514 - val_loss: 0.4792 - val_accuracy: 0.8194 - 136ms/epoch - 15ms/step
# Epoch 283/300
#
# Epoch 283: val_loss did not improve from 0.46311
# 9/9 - 0s - loss: 0.2376 - accuracy: 0.9653 - val_loss: 0.4667 - val_accuracy: 0.8611 - 134ms/epoch - 15ms/step
# Epoch 284/300
#
# Epoch 284: val_loss improved from 0.46311 to 0.44216, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.2728 - accuracy: 0.9444 - val_loss: 0.4422 - val_accuracy: 0.8889 - 155ms/epoch - 17ms/step
# Epoch 285/300
#
# Epoch 285: val_loss did not improve from 0.44216
# 9/9 - 0s - loss: 0.2617 - accuracy: 0.9653 - val_loss: 0.4616 - val_accuracy: 0.8611 - 138ms/epoch - 15ms/step
# Epoch 286/300
#
# Epoch 286: val_loss improved from 0.44216 to 0.44181, saving model to ./tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.2617 - accuracy: 0.9722 - val_loss: 0.4418 - val_accuracy: 0.8611 - 138ms/epoch - 15ms/step
# Epoch 287/300
#
# Epoch 287: val_loss did not improve from 0.44181
# 9/9 - 0s - loss: 0.2486 - accuracy: 0.9444 - val_loss: 0.4628 - val_accuracy: 0.8472 - 134ms/epoch - 15ms/step
# Epoch 288/300
#
# Epoch 288: val_loss did not improve from 0.44181
# 9/9 - 0s - loss: 0.2330 - accuracy: 0.9583 - val_loss: 0.4973 - val_accuracy: 0.8056 - 134ms/epoch - 15ms/step
# Epoch 289/300
#
# Epoch 289: val_loss did not improve from 0.44181
# 9/9 - 0s - loss: 0.2307 - accuracy: 0.9792 - val_loss: 0.4692 - val_accuracy: 0.8056 - 153ms/epoch - 17ms/step
# Epoch 290/300
#
# Epoch 290: val_loss did not improve from 0.44181
# 9/9 - 0s - loss: 0.2053 - accuracy: 0.9722 - val_loss: 0.4883 - val_accuracy: 0.8472 - 133ms/epoch - 15ms/step
# Epoch 291/300
#
# Epoch 291: val_loss did not improve from 0.44181
# 9/9 - 0s - loss: 0.2467 - accuracy: 0.9514 - val_loss: 0.4451 - val_accuracy: 0.8750 - 131ms/epoch - 15ms/step
# Epoch 292/300
#
# Epoch 292: val_loss did not improve from 0.44181
# 9/9 - 0s - loss: 0.2721 - accuracy: 0.9375 - val_loss: 0.5386 - val_accuracy: 0.8056 - 135ms/epoch - 15ms/step
# Epoch 293/300
#
# Epoch 293: val_loss did not improve from 0.44181
# 9/9 - 0s - loss: 0.2444 - accuracy: 0.9514 - val_loss: 0.5802 - val_accuracy: 0.7778 - 134ms/epoch - 15ms/step
# Epoch 294/300
#
# Epoch 294: val_loss did not improve from 0.44181
# 9/9 - 0s - loss: 0.2583 - accuracy: 0.9583 - val_loss: 0.5358 - val_accuracy: 0.7778 - 136ms/epoch - 15ms/step
# Epoch 295/300
#
# Epoch 295: val_loss did not improve from 0.44181
# 9/9 - 0s - loss: 0.2100 - accuracy: 0.9583 - val_loss: 0.4991 - val_accuracy: 0.7778 - 132ms/epoch - 15ms/step
# Epoch 296/300
#
# Epoch 296: val_loss did not improve from 0.44181
# 9/9 - 0s - loss: 0.2240 - accuracy: 0.9514 - val_loss: 0.5463 - val_accuracy: 0.7778 - 135ms/epoch - 15ms/step
# Epoch 297/300
#
# Epoch 297: val_loss did not improve from 0.44181
# 9/9 - 0s - loss: 0.2505 - accuracy: 0.9306 - val_loss: 0.4849 - val_accuracy: 0.8194 - 131ms/epoch - 15ms/step
# Epoch 298/300
#
# Epoch 298: val_loss did not improve from 0.44181
# 9/9 - 0s - loss: 0.2669 - accuracy: 0.9444 - val_loss: 0.5263 - val_accuracy: 0.7778 - 130ms/epoch - 14ms/step
# Epoch 299/300
#
# Epoch 299: val_loss did not improve from 0.44181
# 9/9 - 0s - loss: 0.2208 - accuracy: 0.9583 - val_loss: 0.5625 - val_accuracy: 0.7917 - 130ms/epoch - 14ms/step
# Epoch 300/300
#
# Epoch 300: val_loss did not improve from 0.44181
# 9/9 - 0s - loss: 0.2381 - accuracy: 0.9375 - val_loss: 0.5586 - val_accuracy: 0.8056 - 135ms/epoch - 15ms/step

# %%
# load optimal weights
model.load_weights('./tmp/checkpoint.h5')

###############################################################################
# can alternatively used the weights provided in the repo. If so it should get
# you 93% accuracy. Change the WEIGHTS_PATH variable to wherever it is on your
# system.
###############################################################################

# WEIGHTS_PATH = /path/to/EEGNet-8-2-weights.h5 
# model.load_weights(WEIGHTS_PATH)

###############################################################################
# make prediction on test set.
###############################################################################

probs       = model.predict(X_test)
preds       = probs.argmax(axis = -1)  
acc         = np.mean(preds == Y_test.argmax(axis=-1))
print("Classification accuracy: %f " % (acc))


############################# PyRiemann Portion ##############################

# code is taken from PyRiemann's ERP sample script, which is decoding in 
# the tangent space with a logistic regression

n_components = 2  # pick some components

# set up sklearn pipeline
clf = make_pipeline(XdawnCovariances(n_components),
                    TangentSpace(metric='riemann'),
                    LogisticRegression())

preds_rg     = np.zeros(len(Y_test))

# reshape back to (trials, channels, samples)
X_train      = X_train.reshape(X_train.shape[0], chans, samples)
X_test       = X_test.reshape(X_test.shape[0], chans, samples)

# train a classifier with xDAWN spatial filtering + Riemannian Geometry (RG)
# labels need to be back in single-column format
clf.fit(X_train, Y_train.argmax(axis = -1))
preds_rg     = clf.predict(X_test)

# Printing the results
acc2         = np.mean(preds_rg == Y_test.argmax(axis = -1))
print("Classification accuracy: %f " % (acc2))
# Out:
# 3/3 [==============================] - 0s 4ms/step
# Classification accuracy: 0.902778
# Classification accuracy: 0.944444

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
# plot the confusion matrices for both classifiers
names        = ['audio left', 'audio right', 'vis left', 'vis right']
# plt.figure(0)
confusion_matrix_1 = confusion_matrix(preds, Y_test.argmax(axis = -1))

# plt.figure(1)
confusion_matrix_2 = confusion_matrix(preds_rg, Y_test.argmax(axis = -1))

# %%
confusion_matrix_1
# Out:
# array([[14,  1,  0,  0],
#        [ 2, 18,  0,  1],
#        [ 0,  0, 17,  1],
#        [ 1,  0,  1, 16]])

# %%
disp1 = ConfusionMatrixDisplay(confusion_matrix_1, display_labels = names)
disp1.plot()

# ConfusionMatrixDisplay(confusion_matrix_2, display_labels = names)

# %%
disp2 = ConfusionMatrixDisplay(confusion_matrix_2, display_labels = names)
disp2.plot()
